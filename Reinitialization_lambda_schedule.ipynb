# %% [markdown]
# Testing multiple choices for lambda_pen on ER([500, 600, ..., 1000], [0.3, 0.5, 0.7], seed = 0 to 49)

# %%
import torch
import networkx as nx
import numpy as np
import time

"""
Extended experiments: loop over graph sizes, edge probabilities, and lambda penalties.
- Graph sizes: 500, 600, 700, 800, 900, 1000
- Edge probabilities: 0.3, 0.5, 0.7
- Lambda_pen values: 0.0, 0.1, 0.2, ..., 1.0
- Seeds: 0 to 49 (50 instances per combination)
- Measure per seed: runs, mean/min/max MIS size, runtime
- Compute average runtime across seeds for each config
"""

# Experiment parameters
graph_sizes = list(range(900, 1001, 100)) # Output 一次只能做兩個100，之前有700 800，現在做500 600，之後再做900 1000
ps          = [0.3, 0.5, 0.7]
lambda_vals = [i/10 for i in range(11)]
seeds       = range(50)

# Algorithm parameters
beta      = 0.8
alpha     = 0.0001
ITER_T    = 150
NUM_INITS = 50
eta       = 2.0

# Parameters
gamma_c = 1

# Initialization penalty decay
decay_rate = 1
BATCH_SIZE = 10

# Efficient MIS checker
def MIS_checker_efficient_3(X, A, Abar):
    N = X.shape[0]
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones(N) + (N * A) @ Xb)
    Xb_up.clamp_(0, 1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

# Degree-based init vector
def make_degree_init(G):
    deg = dict(G.degree())
    max_deg_node = max(deg.values())
    d = torch.tensor([1 - deg[i] / max_deg_node for i in range(len(deg))], dtype=torch.float32)
    return d / d.max()

# Run single seed experiment
def run_seed_experiment(n, p, seed, lambda_pen):
    # Build graph
    G = nx.fast_gnp_random_graph(n, p, seed=seed)
    comp = nx.complement(G)
    max_deg = max(dict(comp.degree()).values())
    gamma = 2 + max_deg

    A    = torch.tensor(nx.adjacency_matrix(G).todense(), dtype=torch.float32)
    Abar = torch.tensor(nx.adjacency_matrix(comp).todense(), dtype=torch.float32)
    d    = make_degree_init(G)
    cov  = eta * torch.eye(n)

    penalty_count = np.zeros(n, dtype=int)
    found_sizes = []

    start_time = time.time()
    for init in range(NUM_INITS):
        bias   = 1.0 / (1 + lambda_pen * penalty_count)
        bias_t = torch.from_numpy(bias).float()
        if init == 0:
            x = d.clone() * bias_t
        else:
            torch.manual_seed(init)
            base = torch.normal(mean=d, std=torch.sqrt(torch.diag(cov)))
            x = (base * bias_t).clamp(0, 1)
        v = torch.zeros(n)

        done = False
        for _ in range(ITER_T):
            grad = -torch.ones(n) + (gamma * A - gamma_c * Abar) @ x
            v    = beta * v + alpha * grad
            x    = (x - v).clamp(0, 1)
            done, MIS = MIS_checker_efficient_3(x, A, Abar)
            if done:
                break

        if done:
            found_sizes.append(len(MIS))
            penalty_count[MIS.tolist()] += 1

        if init > 0 and init % BATCH_SIZE == 0:
            penalty_count = np.maximum(penalty_count - decay_rate, 0)
    runtime = time.time() - start_time

    if found_sizes:
        return len(found_sizes), np.mean(found_sizes), np.min(found_sizes), np.max(found_sizes), runtime
    else:
        return 0, 0.0, 0, 0, runtime

# Main experimental loop
for n in graph_sizes:
    for p in ps:
        print(f"\n=== Graph ER({n}, {p}) ===")
        for lam in lambda_vals:
            seed_results = []
            for seed in seeds:
                runs, mean_s, min_s, max_s, rt = run_seed_experiment(n, p, seed, lam)
                seed_results.append((seed, runs, mean_s, min_s, max_s, rt))
                print(f"λ={lam:.1f} Seed {seed:2d}: runs={runs}, mean={mean_s:.2f}, min={min_s}, max={max_s}, time={rt:.1f}s")
            avg_rt = np.mean([r[5] for r in seed_results])
            print(f"  → λ={lam:.1f} avg runtime per seed: {avg_rt:.1f}s")
# Out:
# === Graph ER(900, 0.3) ===
# λ=0.0 Seed  0: runs=50, mean=18.32, min=15, max=22, time=8.7s
# λ=0.0 Seed  1: runs=50, mean=18.60, min=15, max=21, time=10.5s
# λ=0.0 Seed  2: runs=50, mean=18.66, min=15, max=22, time=11.7s
# λ=0.0 Seed  3: runs=50, mean=18.58, min=16, max=21, time=11.0s
# λ=0.0 Seed  4: runs=50, mean=18.68, min=16, max=21, time=10.3s
# λ=0.0 Seed  5: runs=50, mean=18.30, min=16, max=21, time=10.5s
# λ=0.0 Seed  6: runs=50, mean=18.78, min=15, max=22, time=30.5s
# λ=0.0 Seed  7: runs=50, mean=18.24, min=16, max=20, time=11.5s
# λ=0.0 Seed  8: runs=50, mean=18.16, min=16, max=21, time=27.0s
# λ=0.0 Seed  9: runs=50, mean=18.12, min=16, max=20, time=12.0s
# λ=0.0 Seed 10: runs=50, mean=18.38, min=15, max=21, time=11.3s
# λ=0.0 Seed 11: runs=50, mean=18.40, min=16, max=22, time=10.9s
# λ=0.0 Seed 12: runs=50, mean=18.26, min=16, max=21, time=8.8s
# λ=0.0 Seed 13: runs=50, mean=18.26, min=16, max=21, time=9.9s
# λ=0.0 Seed 14: runs=50, mean=18.44, min=16, max=21, time=10.0s
# λ=0.0 Seed 15: runs=50, mean=18.82, min=15, max=22, time=9.2s
# λ=0.0 Seed 16: runs=50, mean=18.24, min=16, max=20, time=10.7s
# λ=0.0 Seed 17: runs=50, mean=18.46, min=17, max=21, time=9.6s
# λ=0.0 Seed 18: runs=50, mean=18.56, min=17, max=21, time=10.3s
# λ=0.0 Seed 19: runs=50, mean=18.18, min=16, max=20, time=10.8s
# λ=0.0 Seed 20: runs=50, mean=18.54, min=16, max=21, time=9.2s
# λ=0.0 Seed 21: runs=50, mean=18.14, min=16, max=21, time=9.8s
# λ=0.0 Seed 22: runs=50, mean=18.26, min=15, max=21, time=10.2s
# λ=0.0 Seed 23: runs=50, mean=18.16, min=16, max=20, time=9.2s
# λ=0.0 Seed 24: runs=50, mean=18.20, min=15, max=21, time=10.3s
# λ=0.0 Seed 25: runs=50, mean=18.60, min=16, max=20, time=10.1s
# λ=0.0 Seed 26: runs=50, mean=18.40, min=16, max=21, time=10.5s
# λ=0.0 Seed 27: runs=50, mean=18.88, min=16, max=21, time=8.8s
# λ=0.0 Seed 28: runs=50, mean=18.76, min=16, max=22, time=9.1s
# λ=0.0 Seed 29: runs=50, mean=18.30, min=16, max=20, time=26.6s
# λ=0.0 Seed 30: runs=50, mean=18.46, min=16, max=21, time=28.9s
# λ=0.0 Seed 31: runs=50, mean=18.56, min=16, max=22, time=30.2s
# λ=0.0 Seed 32: runs=50, mean=18.44, min=16, max=21, time=30.6s
# λ=0.0 Seed 33: runs=50, mean=18.88, min=16, max=22, time=28.4s
# λ=0.0 Seed 34: runs=50, mean=18.52, min=16, max=21, time=30.2s
# λ=0.0 Seed 35: runs=50, mean=18.20, min=15, max=21, time=30.8s
# λ=0.0 Seed 36: runs=50, mean=18.56, min=16, max=21, time=13.9s
# λ=0.0 Seed 37: runs=50, mean=18.90, min=16, max=21, time=29.5s
# λ=0.0 Seed 38: runs=50, mean=18.62, min=16, max=21, time=28.2s
# λ=0.0 Seed 39: runs=50, mean=18.16, min=16, max=21, time=28.6s
# λ=0.0 Seed 40: runs=50, mean=18.66, min=17, max=21, time=12.9s
# λ=0.0 Seed 41: runs=50, mean=18.30, min=16, max=21, time=27.9s
# λ=0.0 Seed 42: runs=50, mean=18.66, min=16, max=22, time=15.5s
# λ=0.0 Seed 43: runs=50, mean=18.34, min=16, max=21, time=14.0s
# λ=0.0 Seed 44: runs=50, mean=19.04, min=16, max=22, time=18.5s
# λ=0.0 Seed 45: runs=50, mean=18.48, min=16, max=21, time=16.9s
# λ=0.0 Seed 46: runs=50, mean=18.52, min=17, max=21, time=26.4s
# λ=0.0 Seed 47: runs=50, mean=18.70, min=16, max=21, time=13.6s
# λ=0.0 Seed 48: runs=50, mean=18.62, min=15, max=21, time=12.7s
# λ=0.0 Seed 49: runs=50, mean=18.22, min=16, max=21, time=11.1s
#   → λ=0.0 avg runtime per seed: 16.2s
# λ=0.1 Seed  0: runs=50, mean=18.02, min=15, max=22, time=11.4s
# λ=0.1 Seed  1: runs=50, mean=18.42, min=15, max=21, time=10.1s
# λ=0.1 Seed  2: runs=50, mean=18.74, min=17, max=22, time=9.7s
# λ=0.1 Seed  3: runs=50, mean=18.56, min=16, max=21, time=9.5s
# λ=0.1 Seed  4: runs=50, mean=18.44, min=16, max=21, time=10.4s
# λ=0.1 Seed  5: runs=50, mean=18.10, min=16, max=21, time=12.2s
# λ=0.1 Seed  6: runs=50, mean=18.58, min=15, max=21, time=11.1s
# λ=0.1 Seed  7: runs=50, mean=18.54, min=17, max=21, time=11.7s
# λ=0.1 Seed  8: runs=50, mean=18.00, min=16, max=20, time=11.9s
# λ=0.1 Seed  9: runs=50, mean=18.10, min=16, max=20, time=12.0s
# λ=0.1 Seed 10: runs=50, mean=18.32, min=15, max=21, time=11.7s
# λ=0.1 Seed 11: runs=50, mean=18.54, min=14, max=22, time=12.4s
# λ=0.1 Seed 12: runs=50, mean=18.36, min=16, max=21, time=11.1s
# λ=0.1 Seed 13: runs=50, mean=18.12, min=15, max=21, time=11.4s
# λ=0.1 Seed 14: runs=50, mean=18.46, min=16, max=21, time=11.9s
# λ=0.1 Seed 15: runs=50, mean=19.02, min=16, max=22, time=10.8s
# λ=0.1 Seed 16: runs=50, mean=18.16, min=16, max=20, time=13.6s
# λ=0.1 Seed 17: runs=50, mean=18.22, min=16, max=21, time=11.5s
# λ=0.1 Seed 18: runs=50, mean=18.50, min=16, max=21, time=9.7s
# λ=0.1 Seed 19: runs=50, mean=18.16, min=16, max=21, time=10.2s
# λ=0.1 Seed 20: runs=50, mean=18.52, min=15, max=21, time=12.0s
# λ=0.1 Seed 21: runs=50, mean=18.38, min=16, max=21, time=12.2s
# λ=0.1 Seed 22: runs=50, mean=18.36, min=16, max=22, time=11.3s
# λ=0.1 Seed 23: runs=50, mean=18.28, min=16, max=21, time=11.4s
# λ=0.1 Seed 24: runs=50, mean=18.28, min=16, max=20, time=11.5s
# λ=0.1 Seed 25: runs=50, mean=18.48, min=16, max=21, time=11.1s
# λ=0.1 Seed 26: runs=50, mean=18.50, min=16, max=21, time=10.3s
# λ=0.1 Seed 27: runs=50, mean=18.54, min=16, max=21, time=8.5s
# λ=0.1 Seed 28: runs=50, mean=18.44, min=16, max=22, time=10.7s
# λ=0.1 Seed 29: runs=50, mean=18.12, min=15, max=21, time=10.5s
# λ=0.1 Seed 30: runs=50, mean=18.30, min=16, max=21, time=9.8s
# λ=0.1 Seed 31: runs=50, mean=18.40, min=15, max=22, time=12.6s
# λ=0.1 Seed 32: runs=50, mean=18.52, min=16, max=20, time=10.1s
# λ=0.1 Seed 33: runs=50, mean=18.86, min=16, max=22, time=11.1s
# λ=0.1 Seed 34: runs=50, mean=18.30, min=16, max=20, time=10.4s
# λ=0.1 Seed 35: runs=50, mean=18.28, min=16, max=21, time=9.0s
# λ=0.1 Seed 36: runs=50, mean=18.70, min=16, max=22, time=10.1s
# λ=0.1 Seed 37: runs=50, mean=18.78, min=16, max=21, time=10.6s
# λ=0.1 Seed 38: runs=50, mean=18.58, min=16, max=21, time=10.2s
# λ=0.1 Seed 39: runs=50, mean=18.48, min=16, max=21, time=11.3s
# λ=0.1 Seed 40: runs=50, mean=18.50, min=16, max=21, time=13.1s
# λ=0.1 Seed 41: runs=50, mean=18.28, min=16, max=21, time=11.0s
# λ=0.1 Seed 42: runs=50, mean=18.50, min=16, max=22, time=10.4s
# λ=0.1 Seed 43: runs=50, mean=18.44, min=16, max=21, time=11.7s
# λ=0.1 Seed 44: runs=50, mean=18.86, min=17, max=22, time=10.7s
# λ=0.1 Seed 45: runs=50, mean=18.26, min=16, max=21, time=14.1s
# λ=0.1 Seed 46: runs=50, mean=18.26, min=16, max=20, time=14.4s
# λ=0.1 Seed 47: runs=50, mean=18.76, min=17, max=21, time=12.0s
# λ=0.1 Seed 48: runs=50, mean=18.64, min=16, max=21, time=12.3s
# λ=0.1 Seed 49: runs=50, mean=18.28, min=16, max=21, time=11.8s
#   → λ=0.1 avg runtime per seed: 11.2s
# λ=0.2 Seed  0: runs=50, mean=18.20, min=16, max=22, time=12.6s
# λ=0.2 Seed  1: runs=50, mean=18.34, min=15, max=22, time=11.2s
# λ=0.2 Seed  2: runs=50, mean=18.62, min=16, max=21, time=12.2s
# λ=0.2 Seed  3: runs=50, mean=18.50, min=16, max=21, time=10.3s
# λ=0.2 Seed  4: runs=50, mean=18.54, min=16, max=22, time=10.1s
# λ=0.2 Seed  5: runs=50, mean=18.08, min=16, max=21, time=10.2s
# λ=0.2 Seed  6: runs=50, mean=18.54, min=15, max=21, time=11.2s
# λ=0.2 Seed  7: runs=50, mean=18.30, min=16, max=21, time=10.2s
# λ=0.2 Seed  8: runs=50, mean=17.96, min=16, max=20, time=11.0s
# λ=0.2 Seed  9: runs=50, mean=18.22, min=15, max=20, time=12.3s
# λ=0.2 Seed 10: runs=50, mean=18.06, min=15, max=21, time=10.2s
# λ=0.2 Seed 11: runs=50, mean=18.44, min=16, max=21, time=10.5s
# λ=0.2 Seed 12: runs=50, mean=18.64, min=16, max=22, time=11.4s
# λ=0.2 Seed 13: runs=50, mean=18.48, min=16, max=22, time=12.3s
# λ=0.2 Seed 14: runs=50, mean=18.64, min=16, max=22, time=10.3s
# λ=0.2 Seed 15: runs=50, mean=18.98, min=16, max=22, time=10.3s
# λ=0.2 Seed 16: runs=50, mean=18.26, min=16, max=20, time=12.3s
# λ=0.2 Seed 17: runs=50, mean=18.40, min=16, max=22, time=11.8s
# λ=0.2 Seed 18: runs=50, mean=18.44, min=16, max=21, time=11.1s
# λ=0.2 Seed 19: runs=50, mean=18.40, min=16, max=20, time=10.8s
# λ=0.2 Seed 20: runs=50, mean=18.60, min=16, max=21, time=12.0s
# λ=0.2 Seed 21: runs=50, mean=18.32, min=16, max=22, time=9.4s
# λ=0.2 Seed 22: runs=50, mean=18.42, min=16, max=21, time=9.4s
# λ=0.2 Seed 23: runs=50, mean=18.36, min=16, max=21, time=9.6s
# λ=0.2 Seed 24: runs=50, mean=18.26, min=15, max=21, time=10.2s
# λ=0.2 Seed 25: runs=50, mean=18.38, min=16, max=20, time=11.4s
# λ=0.2 Seed 26: runs=50, mean=18.52, min=16, max=21, time=10.1s
# λ=0.2 Seed 27: runs=50, mean=18.70, min=16, max=22, time=12.9s
# λ=0.2 Seed 28: runs=50, mean=18.44, min=16, max=22, time=12.6s
# λ=0.2 Seed 29: runs=50, mean=18.40, min=16, max=21, time=12.8s
# λ=0.2 Seed 30: runs=50, mean=18.50, min=16, max=21, time=12.3s
# λ=0.2 Seed 31: runs=50, mean=18.42, min=16, max=21, time=13.9s
# λ=0.2 Seed 32: runs=50, mean=18.90, min=17, max=21, time=10.7s
# λ=0.2 Seed 33: runs=50, mean=18.44, min=16, max=22, time=12.3s
# λ=0.2 Seed 34: runs=50, mean=18.40, min=16, max=21, time=13.7s
# λ=0.2 Seed 35: runs=50, mean=18.24, min=16, max=21, time=10.1s
# λ=0.2 Seed 36: runs=50, mean=18.44, min=16, max=21, time=13.0s
# λ=0.2 Seed 37: runs=50, mean=18.96, min=16, max=22, time=11.6s
# λ=0.2 Seed 38: runs=50, mean=18.38, min=16, max=21, time=11.5s
# λ=0.2 Seed 39: runs=50, mean=18.36, min=17, max=22, time=11.0s
# λ=0.2 Seed 40: runs=50, mean=18.46, min=16, max=21, time=10.6s
# λ=0.2 Seed 41: runs=50, mean=18.28, min=16, max=22, time=12.8s
# λ=0.2 Seed 42: runs=50, mean=18.26, min=16, max=22, time=11.6s
# λ=0.2 Seed 43: runs=50, mean=18.28, min=16, max=21, time=10.4s
# λ=0.2 Seed 44: runs=50, mean=18.72, min=15, max=22, time=13.2s
# λ=0.2 Seed 45: runs=50, mean=18.22, min=16, max=21, time=12.9s
# λ=0.2 Seed 46: runs=50, mean=18.22, min=16, max=20, time=12.4s
# λ=0.2 Seed 47: runs=50, mean=18.54, min=16, max=21, time=12.3s
# λ=0.2 Seed 48: runs=50, mean=18.20, min=16, max=21, time=11.4s
# λ=0.2 Seed 49: runs=50, mean=18.26, min=16, max=21, time=11.9s
#   → λ=0.2 avg runtime per seed: 11.4s
# λ=0.3 Seed  0: runs=50, mean=18.10, min=15, max=21, time=12.4s
# λ=0.3 Seed  1: runs=50, mean=18.54, min=16, max=21, time=13.8s
# λ=0.3 Seed  2: runs=50, mean=18.38, min=15, max=21, time=11.8s
# λ=0.3 Seed  3: runs=50, mean=18.32, min=16, max=20, time=11.4s
# λ=0.3 Seed  4: runs=50, mean=18.50, min=16, max=22, time=12.0s
# λ=0.3 Seed  5: runs=50, mean=17.90, min=16, max=21, time=12.0s
# λ=0.3 Seed  6: runs=50, mean=18.60, min=16, max=21, time=12.6s
# λ=0.3 Seed  7: runs=50, mean=18.64, min=16, max=22, time=11.8s
# λ=0.3 Seed  8: runs=50, mean=17.94, min=16, max=20, time=11.5s
# λ=0.3 Seed  9: runs=50, mean=18.14, min=16, max=21, time=12.6s
# λ=0.3 Seed 10: runs=50, mean=18.14, min=15, max=22, time=12.0s
# λ=0.3 Seed 11: runs=50, mean=18.42, min=16, max=22, time=10.5s
# λ=0.3 Seed 12: runs=50, mean=18.52, min=16, max=22, time=11.4s
# λ=0.3 Seed 13: runs=50, mean=18.38, min=16, max=21, time=11.4s
# λ=0.3 Seed 14: runs=50, mean=18.52, min=15, max=21, time=10.9s
# λ=0.3 Seed 15: runs=50, mean=19.00, min=16, max=22, time=9.9s
# λ=0.3 Seed 16: runs=50, mean=18.52, min=16, max=21, time=10.9s
# λ=0.3 Seed 17: runs=50, mean=18.44, min=16, max=21, time=9.4s
# λ=0.3 Seed 18: runs=50, mean=18.26, min=16, max=21, time=9.5s
# λ=0.3 Seed 19: runs=50, mean=18.28, min=17, max=22, time=10.5s
# λ=0.3 Seed 20: runs=50, mean=18.44, min=16, max=22, time=11.2s
# λ=0.3 Seed 21: runs=50, mean=18.46, min=16, max=22, time=10.4s
# λ=0.3 Seed 22: runs=50, mean=18.38, min=16, max=21, time=10.6s
# λ=0.3 Seed 23: runs=50, mean=18.48, min=16, max=20, time=12.4s
# λ=0.3 Seed 24: runs=50, mean=18.02, min=16, max=20, time=11.5s
# λ=0.3 Seed 25: runs=50, mean=18.40, min=16, max=20, time=10.6s
# λ=0.3 Seed 26: runs=50, mean=18.34, min=16, max=21, time=10.7s
# λ=0.3 Seed 27: runs=50, mean=18.70, min=16, max=22, time=11.3s
# λ=0.3 Seed 28: runs=50, mean=18.38, min=16, max=21, time=10.8s
# λ=0.3 Seed 29: runs=50, mean=18.00, min=16, max=20, time=11.3s
# λ=0.3 Seed 30: runs=50, mean=18.26, min=16, max=21, time=11.6s
# λ=0.3 Seed 31: runs=50, mean=18.56, min=16, max=21, time=9.7s
# λ=0.3 Seed 32: runs=50, mean=18.96, min=16, max=23, time=9.8s
# λ=0.3 Seed 33: runs=50, mean=18.50, min=16, max=22, time=10.7s
# λ=0.3 Seed 34: runs=50, mean=18.60, min=16, max=21, time=10.5s
# λ=0.3 Seed 35: runs=50, mean=18.26, min=16, max=21, time=13.7s
# λ=0.3 Seed 36: runs=50, mean=18.32, min=16, max=22, time=12.8s
# λ=0.3 Seed 37: runs=50, mean=18.58, min=16, max=22, time=13.1s
# λ=0.3 Seed 38: runs=50, mean=18.24, min=15, max=21, time=11.9s
# λ=0.3 Seed 39: runs=50, mean=18.36, min=16, max=22, time=13.7s
# λ=0.3 Seed 40: runs=50, mean=18.80, min=16, max=21, time=11.0s
# λ=0.3 Seed 41: runs=50, mean=18.50, min=16, max=21, time=12.2s
# λ=0.3 Seed 42: runs=50, mean=18.28, min=16, max=21, time=14.0s
# λ=0.3 Seed 43: runs=50, mean=18.04, min=16, max=21, time=12.7s
# λ=0.3 Seed 44: runs=50, mean=18.74, min=17, max=22, time=12.7s
# λ=0.3 Seed 45: runs=50, mean=18.28, min=17, max=21, time=12.1s
# λ=0.3 Seed 46: runs=50, mean=18.30, min=15, max=21, time=16.9s
# λ=0.3 Seed 47: runs=50, mean=18.76, min=17, max=21, time=12.6s
# λ=0.3 Seed 48: runs=50, mean=18.12, min=16, max=21, time=11.8s
# λ=0.3 Seed 49: runs=50, mean=18.24, min=16, max=21, time=12.7s
#   → λ=0.3 avg runtime per seed: 11.7s
# λ=0.4 Seed  0: runs=50, mean=18.10, min=15, max=20, time=12.2s
# λ=0.4 Seed  1: runs=50, mean=18.40, min=15, max=22, time=11.6s
# λ=0.4 Seed  2: runs=50, mean=18.52, min=17, max=21, time=11.6s
# λ=0.4 Seed  3: runs=50, mean=18.46, min=16, max=21, time=11.1s
# λ=0.4 Seed  4: runs=50, mean=18.42, min=15, max=22, time=14.3s
# λ=0.4 Seed  5: runs=50, mean=18.12, min=16, max=21, time=12.2s
# λ=0.4 Seed  6: runs=50, mean=18.50, min=16, max=21, time=13.0s
# λ=0.4 Seed  7: runs=50, mean=18.44, min=16, max=21, time=13.2s
# λ=0.4 Seed  8: runs=50, mean=18.06, min=16, max=20, time=12.5s
# λ=0.4 Seed  9: runs=50, mean=18.28, min=16, max=22, time=11.3s
# λ=0.4 Seed 10: runs=50, mean=18.36, min=16, max=22, time=11.8s
# λ=0.4 Seed 11: runs=50, mean=18.42, min=16, max=22, time=11.3s
# λ=0.4 Seed 12: runs=50, mean=18.50, min=15, max=22, time=9.7s
# λ=0.4 Seed 13: runs=50, mean=18.06, min=16, max=21, time=10.8s
# λ=0.4 Seed 14: runs=50, mean=18.36, min=16, max=21, time=9.8s
# λ=0.4 Seed 15: runs=50, mean=18.94, min=17, max=22, time=12.8s
# λ=0.4 Seed 16: runs=50, mean=18.34, min=16, max=20, time=11.3s
# λ=0.4 Seed 17: runs=50, mean=18.44, min=16, max=21, time=13.1s
# λ=0.4 Seed 18: runs=50, mean=18.18, min=16, max=20, time=13.7s
# λ=0.4 Seed 19: runs=50, mean=18.28, min=16, max=22, time=11.8s
# λ=0.4 Seed 20: runs=50, mean=18.30, min=15, max=21, time=13.1s
# λ=0.4 Seed 21: runs=50, mean=18.32, min=16, max=21, time=11.0s
# λ=0.4 Seed 22: runs=50, mean=18.30, min=16, max=21, time=15.3s
# λ=0.4 Seed 23: runs=50, mean=18.30, min=16, max=21, time=12.2s
# λ=0.4 Seed 24: runs=50, mean=18.08, min=15, max=21, time=12.9s
# λ=0.4 Seed 25: runs=50, mean=18.24, min=16, max=20, time=11.8s
# λ=0.4 Seed 26: runs=50, mean=18.28, min=16, max=21, time=11.7s
# λ=0.4 Seed 27: runs=50, mean=18.54, min=16, max=22, time=13.6s
# λ=0.4 Seed 28: runs=50, mean=18.40, min=16, max=21, time=13.1s
# λ=0.4 Seed 29: runs=50, mean=18.20, min=16, max=20, time=12.2s
# λ=0.4 Seed 30: runs=50, mean=18.18, min=16, max=21, time=12.4s
# λ=0.4 Seed 31: runs=50, mean=18.46, min=16, max=21, time=15.0s
# λ=0.4 Seed 32: runs=50, mean=18.92, min=17, max=21, time=12.8s
# λ=0.4 Seed 33: runs=50, mean=18.90, min=17, max=22, time=12.7s
# λ=0.4 Seed 34: runs=50, mean=18.50, min=17, max=21, time=13.4s
# λ=0.4 Seed 35: runs=50, mean=18.20, min=15, max=21, time=13.4s
# λ=0.4 Seed 36: runs=50, mean=18.44, min=16, max=22, time=12.1s
# λ=0.4 Seed 37: runs=50, mean=18.48, min=16, max=21, time=13.4s
# λ=0.4 Seed 38: runs=50, mean=18.04, min=16, max=20, time=14.3s
# λ=0.4 Seed 39: runs=50, mean=18.10, min=16, max=20, time=15.2s
# λ=0.4 Seed 40: runs=50, mean=18.34, min=15, max=21, time=14.2s
# λ=0.4 Seed 41: runs=50, mean=18.32, min=16, max=21, time=11.8s
# λ=0.4 Seed 42: runs=50, mean=18.40, min=15, max=21, time=11.9s
# λ=0.4 Seed 43: runs=50, mean=18.20, min=15, max=21, time=13.1s
# λ=0.4 Seed 44: runs=50, mean=18.40, min=16, max=22, time=11.7s
# λ=0.4 Seed 45: runs=50, mean=18.06, min=15, max=21, time=11.9s
# λ=0.4 Seed 46: runs=50, mean=18.34, min=17, max=21, time=10.3s
# λ=0.4 Seed 47: runs=50, mean=18.70, min=17, max=21, time=12.3s
# λ=0.4 Seed 48: runs=50, mean=18.70, min=16, max=21, time=12.5s
# λ=0.4 Seed 49: runs=50, mean=18.28, min=16, max=21, time=10.9s
#   → λ=0.4 avg runtime per seed: 12.4s
# λ=0.5 Seed  0: runs=50, mean=18.04, min=15, max=22, time=13.2s
# λ=0.5 Seed  1: runs=50, mean=18.40, min=16, max=21, time=13.3s
# λ=0.5 Seed  2: runs=50, mean=18.70, min=17, max=21, time=12.2s
# λ=0.5 Seed  3: runs=50, mean=18.34, min=15, max=21, time=10.8s
# λ=0.5 Seed  4: runs=50, mean=18.60, min=17, max=20, time=12.0s
# λ=0.5 Seed  5: runs=50, mean=17.96, min=15, max=21, time=13.3s
# λ=0.5 Seed  6: runs=50, mean=18.62, min=16, max=21, time=12.6s
# λ=0.5 Seed  7: runs=50, mean=18.36, min=16, max=21, time=11.3s
# λ=0.5 Seed  8: runs=50, mean=18.04, min=16, max=22, time=12.0s
# λ=0.5 Seed  9: runs=50, mean=18.38, min=17, max=21, time=12.2s
# λ=0.5 Seed 10: runs=50, mean=18.30, min=16, max=21, time=12.4s
# λ=0.5 Seed 11: runs=50, mean=18.44, min=16, max=22, time=13.5s
# λ=0.5 Seed 12: runs=50, mean=18.26, min=16, max=21, time=13.6s
# λ=0.5 Seed 13: runs=50, mean=18.36, min=16, max=20, time=12.8s
# λ=0.5 Seed 14: runs=50, mean=18.24, min=16, max=20, time=11.0s
# λ=0.5 Seed 15: runs=50, mean=18.66, min=15, max=22, time=10.7s
# λ=0.5 Seed 16: runs=50, mean=18.60, min=16, max=22, time=11.0s
# λ=0.5 Seed 17: runs=50, mean=18.44, min=15, max=21, time=11.7s
# λ=0.5 Seed 18: runs=50, mean=18.20, min=16, max=22, time=12.4s
# λ=0.5 Seed 19: runs=50, mean=18.24, min=16, max=20, time=10.4s
# λ=0.5 Seed 20: runs=50, mean=18.38, min=15, max=21, time=12.8s
# λ=0.5 Seed 21: runs=50, mean=18.14, min=15, max=21, time=12.7s
# λ=0.5 Seed 22: runs=50, mean=18.48, min=17, max=21, time=10.9s
# λ=0.5 Seed 23: runs=50, mean=18.32, min=16, max=21, time=10.6s
# λ=0.5 Seed 24: runs=50, mean=18.28, min=16, max=21, time=11.4s
# λ=0.5 Seed 25: runs=50, mean=18.38, min=16, max=21, time=10.9s
# λ=0.5 Seed 26: runs=50, mean=18.52, min=16, max=21, time=10.3s
# λ=0.5 Seed 27: runs=50, mean=18.52, min=16, max=22, time=12.5s
# λ=0.5 Seed 28: runs=50, mean=18.32, min=16, max=20, time=13.5s
# λ=0.5 Seed 29: runs=50, mean=18.32, min=16, max=21, time=11.5s
# λ=0.5 Seed 30: runs=50, mean=18.38, min=16, max=21, time=11.2s
# λ=0.5 Seed 31: runs=50, mean=18.62, min=16, max=21, time=11.7s
# λ=0.5 Seed 32: runs=50, mean=18.94, min=16, max=21, time=11.8s
# λ=0.5 Seed 33: runs=50, mean=18.64, min=16, max=22, time=11.2s
# λ=0.5 Seed 34: runs=50, mean=18.34, min=16, max=22, time=12.0s
# λ=0.5 Seed 35: runs=50, mean=18.32, min=16, max=21, time=12.6s
# λ=0.5 Seed 36: runs=50, mean=18.30, min=16, max=21, time=11.3s
# λ=0.5 Seed 37: runs=50, mean=18.68, min=16, max=21, time=10.6s
# λ=0.5 Seed 38: runs=50, mean=18.26, min=16, max=21, time=10.9s
# λ=0.5 Seed 39: runs=50, mean=17.94, min=16, max=21, time=10.8s
# λ=0.5 Seed 40: runs=50, mean=18.78, min=16, max=21, time=10.9s
# λ=0.5 Seed 41: runs=50, mean=18.38, min=16, max=21, time=9.4s
# λ=0.5 Seed 42: runs=50, mean=18.62, min=17, max=21, time=9.6s
# λ=0.5 Seed 43: runs=50, mean=18.02, min=16, max=21, time=10.9s
# λ=0.5 Seed 44: runs=50, mean=18.40, min=16, max=20, time=10.9s
# λ=0.5 Seed 45: runs=50, mean=18.18, min=16, max=20, time=10.2s
# λ=0.5 Seed 46: runs=50, mean=18.34, min=16, max=21, time=30.5s
# λ=0.5 Seed 47: runs=50, mean=18.84, min=16, max=21, time=12.6s
# λ=0.5 Seed 48: runs=50, mean=18.48, min=16, max=22, time=10.4s
# λ=0.5 Seed 49: runs=50, mean=18.16, min=16, max=21, time=12.6s
#   → λ=0.5 avg runtime per seed: 12.0s
# λ=0.6 Seed  0: runs=50, mean=18.12, min=16, max=21, time=12.4s
# λ=0.6 Seed  1: runs=50, mean=18.66, min=16, max=22, time=13.2s
# λ=0.6 Seed  2: runs=50, mean=18.46, min=16, max=21, time=11.0s
# λ=0.6 Seed  3: runs=50, mean=18.26, min=15, max=22, time=12.1s
# λ=0.6 Seed  4: runs=50, mean=18.60, min=16, max=21, time=13.1s
# λ=0.6 Seed  5: runs=50, mean=18.08, min=15, max=21, time=13.8s
# λ=0.6 Seed  6: runs=50, mean=18.30, min=17, max=21, time=14.2s
# λ=0.6 Seed  7: runs=50, mean=18.44, min=17, max=20, time=12.1s
# λ=0.6 Seed  8: runs=50, mean=18.08, min=15, max=22, time=10.7s
# λ=0.6 Seed  9: runs=50, mean=18.18, min=15, max=22, time=11.3s
# λ=0.6 Seed 10: runs=50, mean=18.32, min=16, max=21, time=11.4s
# λ=0.6 Seed 11: runs=50, mean=18.42, min=16, max=22, time=11.6s
# λ=0.6 Seed 12: runs=50, mean=18.22, min=16, max=21, time=11.4s
# λ=0.6 Seed 13: runs=50, mean=18.30, min=16, max=22, time=14.0s
# λ=0.6 Seed 14: runs=50, mean=18.10, min=15, max=20, time=13.1s
# λ=0.6 Seed 15: runs=50, mean=18.40, min=15, max=22, time=12.1s
# λ=0.6 Seed 16: runs=50, mean=18.46, min=16, max=22, time=12.1s
# λ=0.6 Seed 17: runs=50, mean=18.46, min=15, max=22, time=13.4s
# λ=0.6 Seed 18: runs=50, mean=18.58, min=17, max=21, time=13.1s
# λ=0.6 Seed 19: runs=50, mean=18.30, min=16, max=21, time=11.6s
# λ=0.6 Seed 20: runs=50, mean=18.52, min=16, max=21, time=12.0s
# λ=0.6 Seed 21: runs=50, mean=18.28, min=15, max=22, time=13.0s
# λ=0.6 Seed 22: runs=50, mean=18.56, min=16, max=21, time=13.0s
# λ=0.6 Seed 23: runs=50, mean=18.38, min=16, max=21, time=11.0s
# λ=0.6 Seed 24: runs=50, mean=18.18, min=17, max=20, time=11.1s
# λ=0.6 Seed 25: runs=50, mean=18.34, min=16, max=21, time=12.1s
# λ=0.6 Seed 26: runs=50, mean=18.44, min=17, max=21, time=11.2s
# λ=0.6 Seed 27: runs=50, mean=18.40, min=16, max=22, time=12.7s
# λ=0.6 Seed 28: runs=50, mean=18.36, min=16, max=20, time=12.9s
# λ=0.6 Seed 29: runs=50, mean=18.30, min=16, max=20, time=13.3s
# λ=0.6 Seed 30: runs=50, mean=18.22, min=16, max=20, time=13.2s
# λ=0.6 Seed 31: runs=50, mean=18.46, min=16, max=21, time=12.5s
# λ=0.6 Seed 32: runs=50, mean=18.92, min=16, max=21, time=12.3s
# λ=0.6 Seed 33: runs=50, mean=18.72, min=16, max=22, time=11.8s
# λ=0.6 Seed 34: runs=50, mean=18.58, min=15, max=21, time=11.7s
# λ=0.6 Seed 35: runs=50, mean=18.16, min=15, max=21, time=13.1s
# λ=0.6 Seed 36: runs=50, mean=18.56, min=16, max=21, time=11.7s
# λ=0.6 Seed 37: runs=50, mean=18.96, min=16, max=21, time=11.1s
# λ=0.6 Seed 38: runs=50, mean=18.30, min=16, max=21, time=12.4s
# λ=0.6 Seed 39: runs=50, mean=18.20, min=15, max=21, time=12.8s
# λ=0.6 Seed 40: runs=50, mean=18.60, min=16, max=21, time=11.8s
# λ=0.6 Seed 41: runs=50, mean=18.20, min=16, max=21, time=11.2s
# λ=0.6 Seed 42: runs=50, mean=18.28, min=15, max=20, time=13.4s
# λ=0.6 Seed 43: runs=50, mean=18.12, min=16, max=21, time=11.3s
# λ=0.6 Seed 44: runs=50, mean=18.40, min=16, max=21, time=12.4s
# λ=0.6 Seed 45: runs=50, mean=18.28, min=16, max=20, time=12.8s
# λ=0.6 Seed 46: runs=50, mean=18.50, min=16, max=21, time=12.1s
# λ=0.6 Seed 47: runs=50, mean=18.70, min=15, max=22, time=12.3s
# λ=0.6 Seed 48: runs=50, mean=18.32, min=17, max=21, time=12.4s
# λ=0.6 Seed 49: runs=50, mean=18.12, min=16, max=21, time=13.3s
#   → λ=0.6 avg runtime per seed: 12.3s
# λ=0.7 Seed  0: runs=50, mean=17.96, min=15, max=22, time=13.1s
# λ=0.7 Seed  1: runs=50, mean=18.34, min=16, max=21, time=12.7s
# λ=0.7 Seed  2: runs=50, mean=18.68, min=16, max=22, time=13.6s
# λ=0.7 Seed  3: runs=50, mean=18.44, min=15, max=21, time=14.6s
# λ=0.7 Seed  4: runs=50, mean=18.26, min=15, max=21, time=12.7s
# λ=0.7 Seed  5: runs=50, mean=18.00, min=16, max=21, time=15.1s
# λ=0.7 Seed  6: runs=50, mean=18.34, min=16, max=21, time=13.8s
# λ=0.7 Seed  7: runs=50, mean=18.48, min=16, max=21, time=12.7s
# λ=0.7 Seed  8: runs=50, mean=18.06, min=16, max=22, time=12.4s
# λ=0.7 Seed  9: runs=50, mean=18.36, min=16, max=22, time=12.8s
# λ=0.7 Seed 10: runs=50, mean=18.44, min=16, max=21, time=11.7s
# λ=0.7 Seed 11: runs=50, mean=18.48, min=16, max=22, time=13.7s
# λ=0.7 Seed 12: runs=50, mean=18.40, min=16, max=21, time=11.2s
# λ=0.7 Seed 13: runs=50, mean=18.28, min=15, max=21, time=12.3s
# λ=0.7 Seed 14: runs=50, mean=18.32, min=16, max=21, time=11.9s
# λ=0.7 Seed 15: runs=50, mean=18.78, min=17, max=22, time=12.6s
# λ=0.7 Seed 16: runs=50, mean=18.36, min=16, max=21, time=11.8s
# λ=0.7 Seed 17: runs=50, mean=18.02, min=15, max=21, time=11.8s
# λ=0.7 Seed 18: runs=50, mean=18.26, min=16, max=20, time=12.8s
# λ=0.7 Seed 19: runs=50, mean=17.98, min=16, max=20, time=10.8s
# λ=0.7 Seed 20: runs=50, mean=18.70, min=16, max=21, time=13.6s
# λ=0.7 Seed 21: runs=50, mean=18.42, min=15, max=21, time=12.1s
# λ=0.7 Seed 22: runs=50, mean=18.56, min=15, max=22, time=12.9s
# λ=0.7 Seed 23: runs=50, mean=18.40, min=15, max=21, time=12.6s
# λ=0.7 Seed 24: runs=50, mean=18.26, min=16, max=20, time=16.0s
# λ=0.7 Seed 25: runs=50, mean=18.02, min=16, max=20, time=12.6s
# λ=0.7 Seed 26: runs=50, mean=18.36, min=16, max=21, time=12.2s
# λ=0.7 Seed 27: runs=50, mean=18.34, min=15, max=22, time=12.6s
# λ=0.7 Seed 28: runs=50, mean=18.30, min=16, max=22, time=12.2s
# λ=0.7 Seed 29: runs=50, mean=18.52, min=16, max=20, time=11.9s
# λ=0.7 Seed 30: runs=50, mean=18.36, min=16, max=21, time=12.1s
# λ=0.7 Seed 31: runs=50, mean=18.58, min=16, max=21, time=11.4s
# λ=0.7 Seed 32: runs=50, mean=18.94, min=16, max=21, time=12.3s
# λ=0.7 Seed 33: runs=50, mean=18.90, min=17, max=22, time=13.0s
# λ=0.7 Seed 34: runs=50, mean=18.20, min=16, max=21, time=11.6s
# λ=0.7 Seed 35: runs=50, mean=18.32, min=16, max=21, time=12.7s
# λ=0.7 Seed 36: runs=50, mean=18.48, min=16, max=21, time=11.8s
# λ=0.7 Seed 37: runs=50, mean=19.06, min=16, max=21, time=12.3s
# λ=0.7 Seed 38: runs=50, mean=18.20, min=15, max=20, time=11.3s
# λ=0.7 Seed 39: runs=50, mean=18.04, min=16, max=21, time=11.5s
# λ=0.7 Seed 40: runs=50, mean=18.28, min=15, max=21, time=12.5s
# λ=0.7 Seed 41: runs=50, mean=18.58, min=17, max=21, time=11.2s
# λ=0.7 Seed 42: runs=50, mean=18.38, min=16, max=21, time=12.0s
# λ=0.7 Seed 43: runs=50, mean=18.20, min=15, max=21, time=12.2s
# λ=0.7 Seed 44: runs=50, mean=18.50, min=16, max=21, time=11.7s
# λ=0.7 Seed 45: runs=50, mean=18.38, min=16, max=21, time=11.1s
# λ=0.7 Seed 46: runs=50, mean=18.14, min=16, max=20, time=11.7s
# λ=0.7 Seed 47: runs=50, mean=18.78, min=16, max=22, time=12.6s
# λ=0.7 Seed 48: runs=50, mean=18.40, min=16, max=21, time=12.3s
# λ=0.7 Seed 49: runs=50, mean=18.10, min=16, max=21, time=12.3s
#   → λ=0.7 avg runtime per seed: 12.5s
# λ=0.8 Seed  0: runs=50, mean=18.02, min=16, max=21, time=13.4s
# λ=0.8 Seed  1: runs=50, mean=18.50, min=17, max=21, time=11.8s
# λ=0.8 Seed  2: runs=50, mean=18.48, min=16, max=22, time=11.3s
# λ=0.8 Seed  3: runs=50, mean=18.38, min=16, max=20, time=11.6s
# λ=0.8 Seed  4: runs=50, mean=18.48, min=17, max=21, time=12.0s
# λ=0.8 Seed  5: runs=50, mean=18.50, min=16, max=21, time=10.9s
# λ=0.8 Seed  6: runs=50, mean=18.42, min=16, max=21, time=11.1s
# λ=0.8 Seed  7: runs=50, mean=18.38, min=16, max=22, time=11.9s
# λ=0.8 Seed  8: runs=50, mean=18.06, min=16, max=21, time=12.2s
# λ=0.8 Seed  9: runs=50, mean=18.10, min=15, max=21, time=11.0s
# λ=0.8 Seed 10: runs=50, mean=18.14, min=16, max=21, time=11.0s
# λ=0.8 Seed 11: runs=50, mean=18.32, min=16, max=21, time=11.3s
# λ=0.8 Seed 12: runs=50, mean=18.28, min=16, max=21, time=12.1s
# λ=0.8 Seed 13: runs=50, mean=18.18, min=16, max=22, time=11.5s
# λ=0.8 Seed 14: runs=50, mean=18.30, min=16, max=21, time=12.7s
# λ=0.8 Seed 15: runs=50, mean=18.68, min=15, max=22, time=11.7s
# λ=0.8 Seed 16: runs=50, mean=18.40, min=16, max=23, time=11.4s
# λ=0.8 Seed 17: runs=50, mean=18.30, min=15, max=21, time=10.9s
# λ=0.8 Seed 18: runs=50, mean=18.12, min=16, max=21, time=10.4s
# λ=0.8 Seed 19: runs=50, mean=18.20, min=16, max=21, time=12.5s
# λ=0.8 Seed 20: runs=50, mean=18.72, min=16, max=21, time=11.0s
# λ=0.8 Seed 21: runs=50, mean=18.48, min=16, max=21, time=12.5s
# λ=0.8 Seed 22: runs=50, mean=18.14, min=16, max=21, time=11.8s
# λ=0.8 Seed 23: runs=50, mean=18.16, min=16, max=21, time=12.0s
# λ=0.8 Seed 24: runs=50, mean=18.08, min=16, max=21, time=10.7s
# λ=0.8 Seed 25: runs=50, mean=18.08, min=16, max=21, time=12.4s
# λ=0.8 Seed 26: runs=50, mean=18.58, min=16, max=21, time=12.0s
# λ=0.8 Seed 27: runs=50, mean=18.48, min=16, max=22, time=11.4s
# λ=0.8 Seed 28: runs=50, mean=18.36, min=16, max=20, time=11.4s
# λ=0.8 Seed 29: runs=50, mean=18.32, min=16, max=20, time=12.5s
# λ=0.8 Seed 30: runs=50, mean=18.48, min=15, max=21, time=12.2s
# λ=0.8 Seed 31: runs=50, mean=18.42, min=16, max=21, time=11.4s
# λ=0.8 Seed 32: runs=50, mean=18.94, min=16, max=21, time=12.9s
# λ=0.8 Seed 33: runs=50, mean=18.74, min=17, max=22, time=12.0s
# λ=0.8 Seed 34: runs=50, mean=18.60, min=17, max=21, time=13.4s
# λ=0.8 Seed 35: runs=50, mean=18.38, min=16, max=21, time=12.3s
# λ=0.8 Seed 36: runs=50, mean=18.54, min=16, max=21, time=12.1s
# λ=0.8 Seed 37: runs=50, mean=18.70, min=15, max=21, time=13.1s
# λ=0.8 Seed 38: runs=50, mean=18.34, min=16, max=21, time=12.0s
# λ=0.8 Seed 39: runs=50, mean=17.88, min=15, max=20, time=14.2s
# λ=0.8 Seed 40: runs=50, mean=18.52, min=16, max=21, time=12.0s
# λ=0.8 Seed 41: runs=50, mean=18.38, min=17, max=21, time=9.8s
# λ=0.8 Seed 42: runs=50, mean=18.46, min=17, max=21, time=11.5s
# λ=0.8 Seed 43: runs=50, mean=18.04, min=15, max=20, time=11.6s
# λ=0.8 Seed 44: runs=50, mean=18.36, min=17, max=21, time=11.6s
# λ=0.8 Seed 45: runs=50, mean=18.34, min=16, max=21, time=12.3s
# λ=0.8 Seed 46: runs=50, mean=18.40, min=16, max=22, time=13.5s
# λ=0.8 Seed 47: runs=50, mean=18.52, min=16, max=21, time=13.1s
# λ=0.8 Seed 48: runs=50, mean=18.68, min=16, max=21, time=12.2s
# λ=0.8 Seed 49: runs=50, mean=17.96, min=16, max=20, time=13.6s
#   → λ=0.8 avg runtime per seed: 11.9s
# λ=0.9 Seed  0: runs=50, mean=18.04, min=16, max=21, time=13.6s
# λ=0.9 Seed  1: runs=50, mean=18.62, min=16, max=21, time=12.7s
# λ=0.9 Seed  2: runs=50, mean=18.62, min=16, max=22, time=13.0s
# λ=0.9 Seed  3: runs=50, mean=18.12, min=16, max=20, time=12.3s
# λ=0.9 Seed  4: runs=50, mean=18.48, min=17, max=21, time=12.6s
# λ=0.9 Seed  5: runs=50, mean=18.28, min=16, max=21, time=12.3s
# λ=0.9 Seed  6: runs=50, mean=18.52, min=16, max=21, time=11.5s
# λ=0.9 Seed  7: runs=50, mean=18.36, min=16, max=21, time=11.7s
# λ=0.9 Seed  8: runs=50, mean=18.26, min=16, max=22, time=12.3s
# λ=0.9 Seed  9: runs=50, mean=18.02, min=16, max=21, time=13.2s
# λ=0.9 Seed 10: runs=50, mean=18.22, min=16, max=21, time=11.4s
# λ=0.9 Seed 11: runs=50, mean=18.26, min=16, max=21, time=12.5s
# λ=0.9 Seed 12: runs=50, mean=18.62, min=16, max=22, time=12.4s
# λ=0.9 Seed 13: runs=50, mean=18.20, min=16, max=21, time=13.8s
# λ=0.9 Seed 14: runs=50, mean=18.14, min=16, max=20, time=12.9s
# λ=0.9 Seed 15: runs=50, mean=18.58, min=16, max=22, time=12.5s
# λ=0.9 Seed 16: runs=50, mean=18.40, min=16, max=22, time=11.4s
# λ=0.9 Seed 17: runs=50, mean=18.26, min=16, max=21, time=10.7s
# λ=0.9 Seed 18: runs=50, mean=18.06, min=15, max=21, time=13.0s
# λ=0.9 Seed 19: runs=50, mean=18.46, min=16, max=21, time=11.3s
# λ=0.9 Seed 20: runs=50, mean=18.80, min=16, max=22, time=12.2s
# λ=0.9 Seed 21: runs=50, mean=18.26, min=16, max=20, time=11.6s
# λ=0.9 Seed 22: runs=50, mean=18.34, min=16, max=21, time=11.8s
# λ=0.9 Seed 23: runs=50, mean=18.16, min=16, max=22, time=11.3s
# λ=0.9 Seed 24: runs=50, mean=18.20, min=15, max=21, time=12.3s
# λ=0.9 Seed 25: runs=50, mean=18.24, min=16, max=21, time=12.0s
# λ=0.9 Seed 26: runs=50, mean=18.54, min=16, max=21, time=11.0s
# λ=0.9 Seed 27: runs=50, mean=18.44, min=15, max=21, time=12.0s
# λ=0.9 Seed 28: runs=50, mean=18.56, min=17, max=20, time=11.9s
# λ=0.9 Seed 29: runs=50, mean=18.22, min=17, max=20, time=11.3s
# λ=0.9 Seed 30: runs=50, mean=18.30, min=16, max=21, time=12.0s
# λ=0.9 Seed 31: runs=50, mean=18.40, min=16, max=21, time=11.3s
# λ=0.9 Seed 32: runs=50, mean=18.90, min=16, max=21, time=11.9s
# λ=0.9 Seed 33: runs=50, mean=18.72, min=17, max=22, time=11.3s
# λ=0.9 Seed 34: runs=50, mean=18.42, min=17, max=21, time=11.4s
# λ=0.9 Seed 35: runs=50, mean=18.34, min=16, max=21, time=11.8s
# λ=0.9 Seed 36: runs=50, mean=18.38, min=16, max=21, time=11.2s
# λ=0.9 Seed 37: runs=50, mean=18.68, min=16, max=21, time=12.5s
# λ=0.9 Seed 38: runs=50, mean=18.28, min=16, max=20, time=12.7s
# λ=0.9 Seed 39: runs=50, mean=18.18, min=16, max=21, time=12.1s
# λ=0.9 Seed 40: runs=50, mean=18.62, min=16, max=21, time=12.6s
# λ=0.9 Seed 41: runs=50, mean=18.42, min=16, max=21, time=11.2s
# λ=0.9 Seed 42: runs=50, mean=18.20, min=16, max=20, time=12.1s
# λ=0.9 Seed 43: runs=50, mean=18.24, min=16, max=21, time=12.8s
# λ=0.9 Seed 44: runs=50, mean=18.46, min=17, max=21, time=13.1s
# λ=0.9 Seed 45: runs=50, mean=18.38, min=16, max=21, time=11.8s
# λ=0.9 Seed 46: runs=50, mean=18.58, min=16, max=22, time=12.4s
# λ=0.9 Seed 47: runs=50, mean=18.64, min=16, max=21, time=12.1s
# λ=0.9 Seed 48: runs=50, mean=18.66, min=16, max=22, time=12.3s
# λ=0.9 Seed 49: runs=50, mean=18.08, min=16, max=21, time=11.9s
#   → λ=0.9 avg runtime per seed: 12.1s
# λ=1.0 Seed  0: runs=50, mean=18.36, min=16, max=22, time=12.1s
# λ=1.0 Seed  1: runs=50, mean=18.36, min=17, max=21, time=12.4s
# λ=1.0 Seed  2: runs=50, mean=18.38, min=16, max=21, time=12.3s
# λ=1.0 Seed  3: runs=50, mean=17.96, min=15, max=20, time=12.1s
# λ=1.0 Seed  4: runs=50, mean=18.44, min=15, max=21, time=11.5s
# λ=1.0 Seed  5: runs=50, mean=18.00, min=16, max=20, time=13.1s
# λ=1.0 Seed  6: runs=50, mean=18.30, min=16, max=21, time=10.9s
# λ=1.0 Seed  7: runs=50, mean=18.44, min=16, max=21, time=10.7s
# λ=1.0 Seed  8: runs=50, mean=18.06, min=15, max=21, time=11.8s
# λ=1.0 Seed  9: runs=50, mean=18.06, min=16, max=22, time=11.4s
# λ=1.0 Seed 10: runs=50, mean=18.26, min=15, max=21, time=12.0s
# λ=1.0 Seed 11: runs=50, mean=18.42, min=16, max=22, time=11.5s
# λ=1.0 Seed 12: runs=50, mean=18.22, min=17, max=21, time=12.5s
# λ=1.0 Seed 13: runs=50, mean=18.24, min=16, max=22, time=13.0s
# λ=1.0 Seed 14: runs=50, mean=18.30, min=16, max=20, time=12.6s
# λ=1.0 Seed 15: runs=50, mean=18.78, min=17, max=21, time=11.7s
# λ=1.0 Seed 16: runs=50, mean=18.44, min=15, max=23, time=11.6s
# λ=1.0 Seed 17: runs=50, mean=18.12, min=15, max=21, time=12.9s
# λ=1.0 Seed 18: runs=50, mean=18.32, min=16, max=20, time=13.1s
# λ=1.0 Seed 19: runs=50, mean=18.32, min=16, max=21, time=12.1s
# λ=1.0 Seed 20: runs=50, mean=18.74, min=16, max=22, time=14.1s
# λ=1.0 Seed 21: runs=50, mean=18.44, min=16, max=20, time=10.9s
# λ=1.0 Seed 22: runs=50, mean=18.46, min=16, max=21, time=12.5s
# λ=1.0 Seed 23: runs=50, mean=18.42, min=16, max=21, time=12.2s
# λ=1.0 Seed 24: runs=50, mean=18.16, min=16, max=21, time=12.0s
# λ=1.0 Seed 25: runs=50, mean=18.02, min=16, max=21, time=12.2s
# λ=1.0 Seed 26: runs=50, mean=18.70, min=17, max=21, time=12.0s
# λ=1.0 Seed 27: runs=50, mean=18.76, min=16, max=21, time=11.4s
# λ=1.0 Seed 28: runs=50, mean=18.32, min=16, max=21, time=11.4s
# λ=1.0 Seed 29: runs=50, mean=18.18, min=16, max=20, time=10.6s
# λ=1.0 Seed 30: runs=50, mean=18.26, min=16, max=21, time=13.2s
# λ=1.0 Seed 31: runs=50, mean=18.26, min=15, max=21, time=10.7s
# λ=1.0 Seed 32: runs=50, mean=18.80, min=16, max=21, time=11.8s
# λ=1.0 Seed 33: runs=50, mean=18.52, min=15, max=22, time=11.1s
# λ=1.0 Seed 34: runs=50, mean=18.46, min=15, max=21, time=12.2s
# λ=1.0 Seed 35: runs=50, mean=17.98, min=15, max=21, time=11.3s
# λ=1.0 Seed 36: runs=50, mean=18.52, min=16, max=21, time=11.5s
# λ=1.0 Seed 37: runs=50, mean=18.80, min=17, max=21, time=11.5s
# λ=1.0 Seed 38: runs=50, mean=18.32, min=16, max=21, time=11.0s
# λ=1.0 Seed 39: runs=50, mean=18.16, min=16, max=21, time=12.7s
# λ=1.0 Seed 40: runs=50, mean=18.62, min=16, max=21, time=10.8s
# λ=1.0 Seed 41: runs=50, mean=18.52, min=16, max=22, time=10.9s
# λ=1.0 Seed 42: runs=50, mean=18.44, min=16, max=21, time=10.3s
# λ=1.0 Seed 43: runs=50, mean=18.06, min=16, max=20, time=10.1s
# λ=1.0 Seed 44: runs=50, mean=18.52, min=16, max=22, time=12.9s
# λ=1.0 Seed 45: runs=50, mean=18.24, min=16, max=21, time=10.8s
# λ=1.0 Seed 46: runs=50, mean=18.42, min=16, max=21, time=29.3s
# λ=1.0 Seed 47: runs=50, mean=18.64, min=16, max=20, time=11.9s
# λ=1.0 Seed 48: runs=50, mean=18.48, min=16, max=21, time=13.0s
# λ=1.0 Seed 49: runs=50, mean=18.38, min=16, max=22, time=12.1s
#   → λ=1.0 avg runtime per seed: 12.2s
#
# === Graph ER(900, 0.5) ===
# λ=0.0 Seed  0: runs=50, mean=10.66, min=9, max=13, time=14.9s
# λ=0.0 Seed  1: runs=49, mean=10.49, min=8, max=12, time=13.0s
# λ=0.0 Seed  2: runs=49, mean=10.51, min=8, max=12, time=12.6s
# λ=0.0 Seed  3: runs=48, mean=10.71, min=9, max=12, time=14.2s
# λ=0.0 Seed  4: runs=50, mean=10.64, min=9, max=13, time=13.9s
# λ=0.0 Seed  5: runs=49, mean=10.51, min=9, max=12, time=16.6s
# λ=0.0 Seed  6: runs=50, mean=10.92, min=9, max=12, time=12.5s
# λ=0.0 Seed  7: runs=49, mean=10.76, min=9, max=12, time=14.0s
# λ=0.0 Seed  8: runs=50, mean=10.72, min=9, max=12, time=14.8s
# λ=0.0 Seed  9: runs=50, mean=10.64, min=9, max=13, time=13.5s
# λ=0.0 Seed 10: runs=47, mean=11.06, min=10, max=12, time=15.6s
# λ=0.0 Seed 11: runs=50, mean=10.88, min=9, max=13, time=12.0s
# λ=0.0 Seed 12: runs=50, mean=11.22, min=9, max=13, time=13.4s
# λ=0.0 Seed 13: runs=50, mean=10.72, min=9, max=12, time=13.0s
# λ=0.0 Seed 14: runs=47, mean=10.89, min=9, max=13, time=13.9s
# λ=0.0 Seed 15: runs=50, mean=10.52, min=9, max=12, time=13.8s
# λ=0.0 Seed 16: runs=50, mean=10.54, min=8, max=12, time=13.9s
# λ=0.0 Seed 17: runs=50, mean=10.52, min=9, max=13, time=13.5s
# λ=0.0 Seed 18: runs=49, mean=10.78, min=9, max=12, time=14.8s
# λ=0.0 Seed 19: runs=50, mean=10.36, min=9, max=12, time=15.3s
# λ=0.0 Seed 20: runs=48, mean=10.62, min=9, max=12, time=17.1s
# λ=0.0 Seed 21: runs=50, mean=10.60, min=9, max=12, time=14.1s
# λ=0.0 Seed 22: runs=49, mean=10.96, min=8, max=13, time=16.7s
# λ=0.0 Seed 23: runs=50, mean=10.60, min=9, max=12, time=14.2s
# λ=0.0 Seed 24: runs=50, mean=10.66, min=9, max=12, time=15.0s
# λ=0.0 Seed 25: runs=49, mean=10.37, min=9, max=12, time=15.8s
# λ=0.0 Seed 26: runs=49, mean=10.98, min=9, max=13, time=13.6s
# λ=0.0 Seed 27: runs=50, mean=10.66, min=9, max=13, time=14.0s
# λ=0.0 Seed 28: runs=49, mean=10.51, min=9, max=12, time=14.1s
# λ=0.0 Seed 29: runs=50, mean=11.10, min=9, max=13, time=16.5s
# λ=0.0 Seed 30: runs=50, mean=10.52, min=9, max=12, time=13.7s
# λ=0.0 Seed 31: runs=50, mean=10.64, min=8, max=12, time=15.0s
# λ=0.0 Seed 32: runs=49, mean=10.33, min=9, max=13, time=14.7s
# λ=0.0 Seed 33: runs=50, mean=11.12, min=10, max=12, time=13.5s
# λ=0.0 Seed 34: runs=47, mean=10.72, min=9, max=12, time=14.9s
# λ=0.0 Seed 35: runs=50, mean=11.46, min=9, max=13, time=16.5s
# λ=0.0 Seed 36: runs=49, mean=10.76, min=9, max=13, time=16.4s
# λ=0.0 Seed 37: runs=48, mean=10.75, min=9, max=13, time=12.9s
# λ=0.0 Seed 38: runs=50, mean=10.74, min=9, max=13, time=13.1s
# λ=0.0 Seed 39: runs=48, mean=10.42, min=9, max=13, time=16.1s
# λ=0.0 Seed 40: runs=49, mean=10.49, min=9, max=13, time=12.9s
# λ=0.0 Seed 41: runs=49, mean=10.27, min=9, max=12, time=14.4s
# λ=0.0 Seed 42: runs=49, mean=10.98, min=10, max=13, time=12.5s
# λ=0.0 Seed 43: runs=48, mean=10.60, min=9, max=12, time=14.1s
# λ=0.0 Seed 44: runs=49, mean=10.57, min=9, max=13, time=13.8s
# λ=0.0 Seed 45: runs=49, mean=10.76, min=9, max=12, time=15.6s
# λ=0.0 Seed 46: runs=50, mean=10.88, min=9, max=13, time=14.5s
# λ=0.0 Seed 47: runs=49, mean=10.86, min=10, max=12, time=13.5s
# λ=0.0 Seed 48: runs=49, mean=10.88, min=9, max=12, time=15.4s
# λ=0.0 Seed 49: runs=48, mean=10.88, min=9, max=12, time=13.7s
#   → λ=0.0 avg runtime per seed: 14.3s
# λ=0.1 Seed  0: runs=48, mean=10.58, min=9, max=12, time=15.3s
# λ=0.1 Seed  1: runs=50, mean=10.74, min=8, max=12, time=14.6s
# λ=0.1 Seed  2: runs=48, mean=10.38, min=9, max=12, time=15.2s
# λ=0.1 Seed  3: runs=48, mean=10.75, min=9, max=12, time=17.6s
# λ=0.1 Seed  4: runs=49, mean=10.67, min=9, max=13, time=15.9s
# λ=0.1 Seed  5: runs=49, mean=10.55, min=9, max=12, time=16.0s
# λ=0.1 Seed  6: runs=50, mean=10.66, min=9, max=13, time=12.4s
# λ=0.1 Seed  7: runs=47, mean=10.66, min=9, max=12, time=14.9s
# λ=0.1 Seed  8: runs=50, mean=10.68, min=9, max=13, time=12.9s
# λ=0.1 Seed  9: runs=50, mean=10.60, min=9, max=12, time=14.2s
# λ=0.1 Seed 10: runs=48, mean=11.00, min=9, max=13, time=15.4s
# λ=0.1 Seed 11: runs=49, mean=10.76, min=9, max=12, time=13.7s
# λ=0.1 Seed 12: runs=49, mean=11.24, min=10, max=13, time=13.4s
# λ=0.1 Seed 13: runs=49, mean=10.67, min=9, max=13, time=14.9s
# λ=0.1 Seed 14: runs=50, mean=10.88, min=9, max=12, time=13.1s
# λ=0.1 Seed 15: runs=50, mean=10.40, min=9, max=13, time=14.3s
# λ=0.1 Seed 16: runs=48, mean=10.83, min=9, max=13, time=14.3s
# λ=0.1 Seed 17: runs=49, mean=10.69, min=9, max=12, time=13.9s
# λ=0.1 Seed 18: runs=49, mean=10.47, min=9, max=12, time=14.3s
# λ=0.1 Seed 19: runs=50, mean=10.38, min=9, max=12, time=16.0s
# λ=0.1 Seed 20: runs=49, mean=10.61, min=9, max=12, time=13.6s
# λ=0.1 Seed 21: runs=50, mean=10.50, min=9, max=12, time=13.3s
# λ=0.1 Seed 22: runs=49, mean=10.78, min=9, max=12, time=14.3s
# λ=0.1 Seed 23: runs=50, mean=10.52, min=9, max=12, time=13.3s
# λ=0.1 Seed 24: runs=49, mean=10.63, min=9, max=12, time=14.5s
# λ=0.1 Seed 25: runs=50, mean=10.60, min=9, max=12, time=15.6s
# λ=0.1 Seed 26: runs=48, mean=10.73, min=9, max=12, time=14.7s
# λ=0.1 Seed 27: runs=49, mean=10.73, min=9, max=13, time=13.5s
# λ=0.1 Seed 28: runs=48, mean=10.46, min=8, max=12, time=12.1s
# λ=0.1 Seed 29: runs=50, mean=10.92, min=10, max=12, time=14.5s
# λ=0.1 Seed 30: runs=49, mean=10.59, min=9, max=13, time=14.1s
# λ=0.1 Seed 31: runs=50, mean=10.56, min=9, max=13, time=13.6s
# λ=0.1 Seed 32: runs=50, mean=10.58, min=9, max=12, time=14.0s
# λ=0.1 Seed 33: runs=50, mean=11.08, min=10, max=13, time=12.8s
# λ=0.1 Seed 34: runs=49, mean=10.57, min=9, max=12, time=13.5s
# λ=0.1 Seed 35: runs=50, mean=11.18, min=9, max=12, time=14.5s
# λ=0.1 Seed 36: runs=50, mean=10.60, min=9, max=12, time=14.6s
# λ=0.1 Seed 37: runs=49, mean=10.67, min=9, max=12, time=13.7s
# λ=0.1 Seed 38: runs=50, mean=10.70, min=9, max=13, time=12.2s
# λ=0.1 Seed 39: runs=45, mean=10.24, min=9, max=12, time=15.1s
# λ=0.1 Seed 40: runs=49, mean=10.63, min=9, max=13, time=13.2s
# λ=0.1 Seed 41: runs=48, mean=10.31, min=9, max=12, time=13.0s
# λ=0.1 Seed 42: runs=49, mean=11.06, min=9, max=13, time=13.4s
# λ=0.1 Seed 43: runs=46, mean=10.43, min=9, max=12, time=14.7s
# λ=0.1 Seed 44: runs=48, mean=10.60, min=9, max=13, time=14.1s
# λ=0.1 Seed 45: runs=48, mean=10.71, min=9, max=12, time=14.1s
# λ=0.1 Seed 46: runs=48, mean=10.79, min=9, max=13, time=13.0s
# λ=0.1 Seed 47: runs=50, mean=10.78, min=9, max=12, time=11.9s
# λ=0.1 Seed 48: runs=47, mean=10.89, min=9, max=13, time=15.6s
# λ=0.1 Seed 49: runs=49, mean=10.84, min=9, max=12, time=14.0s
#   → λ=0.1 avg runtime per seed: 14.1s
# λ=0.2 Seed  0: runs=47, mean=10.68, min=9, max=12, time=14.8s
# λ=0.2 Seed  1: runs=48, mean=10.81, min=9, max=13, time=13.5s
# λ=0.2 Seed  2: runs=48, mean=10.46, min=8, max=12, time=14.2s
# λ=0.2 Seed  3: runs=49, mean=10.43, min=9, max=12, time=14.0s
# λ=0.2 Seed  4: runs=49, mean=10.96, min=9, max=13, time=15.7s
# λ=0.2 Seed  5: runs=46, mean=10.59, min=9, max=12, time=15.3s
# λ=0.2 Seed  6: runs=49, mean=10.61, min=9, max=12, time=14.1s
# λ=0.2 Seed  7: runs=47, mean=10.77, min=9, max=13, time=14.2s
# λ=0.2 Seed  8: runs=50, mean=10.62, min=8, max=12, time=13.6s
# λ=0.2 Seed  9: runs=49, mean=10.59, min=9, max=13, time=12.1s
# λ=0.2 Seed 10: runs=48, mean=10.96, min=9, max=12, time=13.1s
# λ=0.2 Seed 11: runs=50, mean=10.68, min=9, max=12, time=12.2s
# λ=0.2 Seed 12: runs=47, mean=11.06, min=10, max=12, time=13.7s
# λ=0.2 Seed 13: runs=48, mean=10.65, min=9, max=12, time=14.1s
# λ=0.2 Seed 14: runs=48, mean=10.94, min=9, max=13, time=14.9s
# λ=0.2 Seed 15: runs=48, mean=10.48, min=9, max=13, time=13.4s
# λ=0.2 Seed 16: runs=50, mean=10.74, min=9, max=13, time=14.0s
# λ=0.2 Seed 17: runs=50, mean=10.56, min=9, max=12, time=12.8s
# λ=0.2 Seed 18: runs=50, mean=10.54, min=8, max=12, time=13.7s
# λ=0.2 Seed 19: runs=48, mean=10.19, min=9, max=12, time=14.5s
# λ=0.2 Seed 20: runs=48, mean=10.62, min=9, max=12, time=14.5s
# λ=0.2 Seed 21: runs=49, mean=10.55, min=9, max=12, time=13.2s
# λ=0.2 Seed 22: runs=48, mean=10.79, min=9, max=12, time=14.0s
# λ=0.2 Seed 23: runs=46, mean=10.67, min=9, max=13, time=13.1s
# λ=0.2 Seed 24: runs=50, mean=10.52, min=9, max=12, time=14.5s
# λ=0.2 Seed 25: runs=47, mean=10.45, min=9, max=12, time=13.6s
# λ=0.2 Seed 26: runs=45, mean=10.56, min=9, max=13, time=14.5s
# λ=0.2 Seed 27: runs=49, mean=10.63, min=9, max=13, time=13.8s
# λ=0.2 Seed 28: runs=49, mean=10.59, min=9, max=12, time=13.7s
# λ=0.2 Seed 29: runs=49, mean=10.90, min=9, max=12, time=13.7s
# λ=0.2 Seed 30: runs=50, mean=10.50, min=9, max=13, time=12.1s
# λ=0.2 Seed 31: runs=50, mean=10.60, min=9, max=13, time=13.3s
# λ=0.2 Seed 32: runs=50, mean=10.24, min=9, max=12, time=14.2s
# λ=0.2 Seed 33: runs=48, mean=11.25, min=9, max=14, time=13.7s
# λ=0.2 Seed 34: runs=48, mean=10.60, min=8, max=12, time=12.9s
# λ=0.2 Seed 35: runs=50, mean=11.06, min=9, max=12, time=14.4s
# λ=0.2 Seed 36: runs=50, mean=10.54, min=9, max=13, time=13.8s
# λ=0.2 Seed 37: runs=50, mean=10.78, min=9, max=13, time=14.0s
# λ=0.2 Seed 38: runs=50, mean=10.66, min=9, max=12, time=12.4s
# λ=0.2 Seed 39: runs=48, mean=10.44, min=8, max=12, time=16.1s
# λ=0.2 Seed 40: runs=50, mean=10.54, min=8, max=12, time=12.6s
# λ=0.2 Seed 41: runs=47, mean=10.26, min=9, max=12, time=12.7s
# λ=0.2 Seed 42: runs=49, mean=11.06, min=9, max=13, time=13.5s
# λ=0.2 Seed 43: runs=50, mean=10.44, min=8, max=12, time=14.8s
# λ=0.2 Seed 44: runs=47, mean=10.72, min=8, max=12, time=13.5s
# λ=0.2 Seed 45: runs=46, mean=10.63, min=9, max=12, time=14.3s
# λ=0.2 Seed 46: runs=48, mean=11.08, min=9, max=13, time=14.0s
# λ=0.2 Seed 47: runs=49, mean=10.63, min=9, max=12, time=14.4s
# λ=0.2 Seed 48: runs=46, mean=10.76, min=9, max=13, time=14.8s
# λ=0.2 Seed 49: runs=50, mean=10.78, min=9, max=12, time=13.1s
#   → λ=0.2 avg runtime per seed: 13.8s
# λ=0.3 Seed  0: runs=50, mean=10.74, min=9, max=13, time=12.9s
# λ=0.3 Seed  1: runs=49, mean=10.69, min=9, max=13, time=14.5s
# λ=0.3 Seed  2: runs=50, mean=10.40, min=9, max=12, time=14.5s
# λ=0.3 Seed  3: runs=50, mean=10.86, min=9, max=13, time=13.0s
# λ=0.3 Seed  4: runs=50, mean=10.70, min=9, max=12, time=15.1s
# λ=0.3 Seed  5: runs=48, mean=10.52, min=9, max=12, time=14.1s
# λ=0.3 Seed  6: runs=50, mean=10.78, min=9, max=12, time=13.7s
# λ=0.3 Seed  7: runs=50, mean=10.72, min=9, max=12, time=14.6s
# λ=0.3 Seed  8: runs=49, mean=10.47, min=8, max=12, time=14.4s
# λ=0.3 Seed  9: runs=48, mean=10.54, min=10, max=12, time=13.0s
# λ=0.3 Seed 10: runs=47, mean=10.62, min=9, max=12, time=13.9s
# λ=0.3 Seed 11: runs=50, mean=10.68, min=9, max=12, time=13.2s
# λ=0.3 Seed 12: runs=49, mean=11.31, min=10, max=13, time=13.9s
# λ=0.3 Seed 13: runs=47, mean=10.53, min=9, max=12, time=13.8s
# λ=0.3 Seed 14: runs=50, mean=10.78, min=9, max=13, time=14.7s
# λ=0.3 Seed 15: runs=50, mean=10.38, min=9, max=12, time=13.0s
# λ=0.3 Seed 16: runs=49, mean=10.57, min=9, max=13, time=13.5s
# λ=0.3 Seed 17: runs=50, mean=10.56, min=9, max=12, time=13.9s
# λ=0.3 Seed 18: runs=47, mean=10.51, min=9, max=13, time=15.0s
# λ=0.3 Seed 19: runs=50, mean=10.20, min=9, max=12, time=13.8s
# λ=0.3 Seed 20: runs=48, mean=10.58, min=9, max=12, time=15.4s
# λ=0.3 Seed 21: runs=50, mean=10.46, min=9, max=12, time=13.5s
# λ=0.3 Seed 22: runs=50, mean=11.06, min=9, max=12, time=13.9s
# λ=0.3 Seed 23: runs=50, mean=10.60, min=9, max=12, time=13.4s
# λ=0.3 Seed 24: runs=48, mean=10.60, min=9, max=12, time=15.2s
# λ=0.3 Seed 25: runs=49, mean=10.47, min=9, max=12, time=15.7s
# λ=0.3 Seed 26: runs=46, mean=10.54, min=9, max=12, time=17.5s
# λ=0.3 Seed 27: runs=50, mean=10.72, min=10, max=12, time=16.2s
# λ=0.3 Seed 28: runs=50, mean=10.64, min=9, max=13, time=14.7s
# λ=0.3 Seed 29: runs=50, mean=10.82, min=9, max=12, time=18.4s
# λ=0.3 Seed 30: runs=50, mean=10.66, min=9, max=13, time=16.0s
# λ=0.3 Seed 31: runs=48, mean=10.62, min=9, max=12, time=17.2s
# λ=0.3 Seed 32: runs=49, mean=10.45, min=9, max=12, time=15.2s
# λ=0.3 Seed 33: runs=49, mean=11.04, min=9, max=13, time=15.3s
# λ=0.3 Seed 34: runs=49, mean=10.59, min=9, max=12, time=14.2s
# λ=0.3 Seed 35: runs=49, mean=11.10, min=9, max=12, time=15.3s
# λ=0.3 Seed 36: runs=50, mean=10.72, min=9, max=13, time=14.4s
# λ=0.3 Seed 37: runs=50, mean=10.84, min=9, max=12, time=11.9s
# λ=0.3 Seed 38: runs=50, mean=10.82, min=9, max=13, time=12.4s
# λ=0.3 Seed 39: runs=49, mean=10.43, min=9, max=12, time=14.9s
# λ=0.3 Seed 40: runs=49, mean=10.73, min=9, max=13, time=13.9s
# λ=0.3 Seed 41: runs=47, mean=10.51, min=9, max=12, time=14.2s
# λ=0.3 Seed 42: runs=47, mean=11.06, min=10, max=13, time=14.4s
# λ=0.3 Seed 43: runs=45, mean=10.60, min=9, max=13, time=15.9s
# λ=0.3 Seed 44: runs=47, mean=10.70, min=9, max=13, time=14.7s
# λ=0.3 Seed 45: runs=49, mean=10.59, min=9, max=12, time=15.8s
# λ=0.3 Seed 46: runs=48, mean=11.06, min=9, max=13, time=14.9s
# λ=0.3 Seed 47: runs=49, mean=10.65, min=9, max=12, time=14.8s
# λ=0.3 Seed 48: runs=47, mean=10.66, min=9, max=12, time=14.7s
# λ=0.3 Seed 49: runs=50, mean=10.84, min=9, max=12, time=13.1s
#   → λ=0.3 avg runtime per seed: 14.5s
# λ=0.4 Seed  0: runs=49, mean=10.63, min=9, max=13, time=14.5s
# λ=0.4 Seed  1: runs=50, mean=10.66, min=9, max=12, time=13.2s
# λ=0.4 Seed  2: runs=48, mean=10.62, min=9, max=12, time=13.0s
# λ=0.4 Seed  3: runs=50, mean=10.86, min=9, max=13, time=14.8s
# λ=0.4 Seed  4: runs=50, mean=10.84, min=9, max=13, time=13.9s
# ...
# λ=0.5 Seed 34: runs=8, mean=6.75, min=6, max=9, time=23.3s
# λ=0.5 Seed 35: runs=3, mean=7.67, min=7, max=8, time=23.5s
# λ=0.5 Seed 36: runs=8, mean=6.38, min=6, max=7, time=22.0s
# λ=0.5 Seed 37: runs=2, mean=6.50, min=6, max=7, time=23.9s
# λ=0.5 Seed 38: runs=10, mean=6.80, min=6, max=7, time=21.7s
# λ=0.5 Seed 39: runs=7, mean=7.14, min=6, max=8, time=26.5s
# λ=0.5 Seed 40: runs=9, mean=7.22, min=6, max=8, time=25.8s
# λ=0.5 Seed 41: runs=10, mean=7.40, min=6, max=8, time=22.3s
# λ=0.5 Seed 42: runs=7, mean=7.14, min=7, max=8, time=24.2s
# λ=0.5 Seed 43: runs=4, mean=6.50, min=6, max=7, time=25.7s
# λ=0.5 Seed 44: runs=5, mean=6.40, min=6, max=7, time=26.5s
# λ=0.5 Seed 45: runs=5, mean=6.60, min=6, max=7, time=26.1s
# λ=0.5 Seed 46: runs=7, mean=7.00, min=6, max=8, time=24.9s
# λ=0.5 Seed 47: runs=8, mean=6.88, min=6, max=7, time=23.6s
# λ=0.5 Seed 48: runs=9, mean=6.33, min=6, max=7, time=23.0s
# λ=0.5 Seed 49: runs=10, mean=6.70, min=6, max=7, time=24.4s
#   → λ=0.5 avg runtime per seed: 24.7s
# λ=0.6 Seed  0: runs=1, mean=9.00, min=9, max=9, time=24.9s
# λ=0.6 Seed  1: runs=7, mean=6.86, min=6, max=7, time=24.1s
# λ=0.6 Seed  2: runs=11, mean=6.64, min=6, max=7, time=24.2s
# λ=0.6 Seed  3: runs=6, mean=7.00, min=7, max=7, time=26.9s
# λ=0.6 Seed  4: runs=4, mean=6.75, min=6, max=7, time=26.4s
# λ=0.6 Seed  5: runs=4, mean=6.25, min=6, max=7, time=25.5s
# λ=0.6 Seed  6: runs=8, mean=6.75, min=6, max=8, time=25.1s
# λ=0.6 Seed  7: runs=11, mean=6.82, min=6, max=7, time=28.3s
# λ=0.6 Seed  8: runs=2, mean=6.50, min=6, max=7, time=25.5s
# λ=0.6 Seed  9: runs=6, mean=6.50, min=6, max=7, time=23.8s
# λ=0.6 Seed 10: runs=4, mean=7.25, min=6, max=8, time=24.3s
# λ=0.6 Seed 11: runs=6, mean=6.67, min=6, max=7, time=24.7s
# λ=0.6 Seed 12: runs=5, mean=6.60, min=6, max=8, time=27.7s
# λ=0.6 Seed 13: runs=5, mean=6.80, min=6, max=7, time=25.0s
# λ=0.6 Seed 14: runs=7, mean=6.43, min=6, max=7, time=25.5s
# λ=0.6 Seed 15: runs=1, mean=7.00, min=7, max=7, time=23.1s
# λ=0.6 Seed 16: runs=11, mean=6.45, min=6, max=7, time=23.0s
# λ=0.6 Seed 17: runs=3, mean=7.00, min=6, max=8, time=25.7s
# λ=0.6 Seed 18: runs=6, mean=7.00, min=6, max=8, time=25.2s
# λ=0.6 Seed 19: runs=10, mean=6.90, min=6, max=8, time=25.5s
# λ=0.6 Seed 20: runs=6, mean=6.67, min=6, max=7, time=26.3s
# λ=0.6 Seed 21: runs=7, mean=6.86, min=6, max=8, time=24.3s
# λ=0.6 Seed 22: runs=4, mean=6.75, min=6, max=7, time=26.1s
# λ=0.6 Seed 23: runs=7, mean=6.29, min=6, max=7, time=25.3s
# λ=0.6 Seed 24: runs=10, mean=7.20, min=6, max=8, time=24.1s
# λ=0.6 Seed 25: runs=5, mean=6.80, min=6, max=7, time=26.0s
# λ=0.6 Seed 26: runs=7, mean=7.00, min=7, max=7, time=25.1s
# λ=0.6 Seed 27: runs=7, mean=6.71, min=6, max=7, time=23.9s
# λ=0.6 Seed 28: runs=7, mean=7.14, min=6, max=8, time=23.5s
# λ=0.6 Seed 29: runs=11, mean=7.00, min=6, max=8, time=26.2s
# λ=0.6 Seed 30: runs=9, mean=6.22, min=6, max=7, time=26.1s
# λ=0.6 Seed 31: runs=11, mean=6.73, min=6, max=8, time=23.2s
# λ=0.6 Seed 32: runs=1, mean=8.00, min=8, max=8, time=27.3s
# λ=0.6 Seed 33: runs=9, mean=6.56, min=6, max=8, time=26.1s
# λ=0.6 Seed 34: runs=5, mean=8.00, min=6, max=9, time=27.7s
# λ=0.6 Seed 35: runs=6, mean=7.33, min=7, max=8, time=24.4s
# λ=0.6 Seed 36: runs=8, mean=6.75, min=6, max=7, time=26.3s
# λ=0.6 Seed 37: runs=2, mean=6.50, min=6, max=7, time=28.5s
# λ=0.6 Seed 38: runs=8, mean=6.88, min=6, max=7, time=26.6s
# λ=0.6 Seed 39: runs=3, mean=6.67, min=6, max=7, time=27.7s
# λ=0.6 Seed 40: runs=9, mean=6.67, min=6, max=7, time=24.6s
# λ=0.6 Seed 41: runs=13, mean=7.69, min=6, max=8, time=24.0s
# λ=0.6 Seed 42: runs=8, mean=6.88, min=6, max=7, time=26.3s
# λ=0.6 Seed 43: runs=5, mean=6.00, min=6, max=6, time=28.7s
# λ=0.6 Seed 44: runs=9, mean=6.67, min=6, max=7, time=27.1s
# λ=0.6 Seed 45: runs=6, mean=6.33, min=6, max=7, time=25.7s
# λ=0.6 Seed 46: runs=11, mean=6.36, min=6, max=7, time=30.1s
# λ=0.6 Seed 47: runs=7, mean=7.00, min=7, max=7, time=31.1s
# λ=0.6 Seed 48: runs=13, mean=6.38, min=6, max=7, time=25.9s
# λ=0.6 Seed 49: runs=9, mean=6.89, min=6, max=8, time=25.5s
#   → λ=0.6 avg runtime per seed: 25.8s
# λ=0.7 Seed  0: runs=1, mean=9.00, min=9, max=9, time=28.1s
# λ=0.7 Seed  1: runs=9, mean=6.67, min=5, max=7, time=26.0s
# λ=0.7 Seed  2: runs=10, mean=6.40, min=6, max=7, time=26.4s
# λ=0.7 Seed  3: runs=10, mean=7.00, min=7, max=7, time=26.4s
# λ=0.7 Seed  4: runs=7, mean=6.86, min=6, max=7, time=28.1s
# λ=0.7 Seed  5: runs=6, mean=6.33, min=6, max=7, time=26.5s
# λ=0.7 Seed  6: runs=9, mean=6.89, min=6, max=8, time=25.0s
# λ=0.7 Seed  7: runs=9, mean=6.78, min=6, max=7, time=26.7s
# λ=0.7 Seed  8: runs=5, mean=6.20, min=6, max=7, time=26.5s
# λ=0.7 Seed  9: runs=5, mean=6.40, min=6, max=7, time=27.4s
# λ=0.7 Seed 10: runs=11, mean=7.00, min=6, max=8, time=25.2s
# λ=0.7 Seed 11: runs=8, mean=6.62, min=6, max=7, time=25.1s
# λ=0.7 Seed 12: runs=7, mean=7.14, min=6, max=8, time=26.3s
# λ=0.7 Seed 13: runs=10, mean=6.50, min=6, max=7, time=24.8s
# λ=0.7 Seed 14: runs=5, mean=6.60, min=6, max=7, time=26.1s
# λ=0.7 Seed 15: runs=1, mean=7.00, min=7, max=7, time=24.9s
# λ=0.7 Seed 16: runs=7, mean=6.86, min=6, max=7, time=26.2s
# λ=0.7 Seed 17: runs=5, mean=6.80, min=6, max=7, time=28.6s
# λ=0.7 Seed 18: runs=5, mean=7.20, min=7, max=8, time=25.6s
# λ=0.7 Seed 19: runs=6, mean=6.67, min=6, max=7, time=26.9s
# λ=0.7 Seed 20: runs=8, mean=6.75, min=6, max=7, time=23.5s
# λ=0.7 Seed 21: runs=5, mean=6.80, min=6, max=7, time=25.7s
# λ=0.7 Seed 22: runs=7, mean=6.86, min=6, max=7, time=29.1s
# λ=0.7 Seed 23: runs=7, mean=6.57, min=6, max=7, time=24.9s
# λ=0.7 Seed 24: runs=11, mean=7.09, min=6, max=9, time=25.7s
# λ=0.7 Seed 25: runs=7, mean=6.86, min=6, max=7, time=26.3s
# λ=0.7 Seed 26: runs=4, mean=7.25, min=7, max=8, time=29.9s
# λ=0.7 Seed 27: runs=7, mean=7.14, min=7, max=8, time=26.0s
# λ=0.7 Seed 28: runs=6, mean=7.50, min=7, max=8, time=26.2s
# λ=0.7 Seed 29: runs=10, mean=7.40, min=7, max=8, time=25.7s
# λ=0.7 Seed 30: runs=2, mean=6.50, min=6, max=7, time=26.5s
# λ=0.7 Seed 31: runs=5, mean=7.00, min=6, max=8, time=26.2s
# λ=0.7 Seed 32: runs=1, mean=8.00, min=8, max=8, time=26.3s
# λ=0.7 Seed 33: runs=11, mean=6.64, min=6, max=8, time=24.4s
# λ=0.7 Seed 34: runs=5, mean=7.00, min=6, max=8, time=26.3s
# λ=0.7 Seed 35: runs=2, mean=7.50, min=7, max=8, time=25.8s
# λ=0.7 Seed 36: runs=9, mean=6.56, min=6, max=7, time=25.8s
# λ=0.7 Seed 37: runs=2, mean=6.50, min=6, max=7, time=29.2s
# λ=0.7 Seed 38: runs=6, mean=6.83, min=6, max=7, time=25.4s
# λ=0.7 Seed 39: runs=6, mean=6.50, min=6, max=7, time=26.6s
# λ=0.7 Seed 40: runs=14, mean=6.93, min=6, max=8, time=25.8s
# λ=0.7 Seed 41: runs=8, mean=7.50, min=7, max=8, time=25.7s
# λ=0.7 Seed 42: runs=8, mean=6.75, min=6, max=7, time=28.5s
# λ=0.7 Seed 43: runs=4, mean=6.50, min=6, max=7, time=27.9s
# λ=0.7 Seed 44: runs=6, mean=6.67, min=6, max=7, time=27.7s
# λ=0.7 Seed 45: runs=12, mean=6.67, min=6, max=8, time=26.6s
# λ=0.7 Seed 46: runs=7, mean=6.14, min=6, max=7, time=29.6s
# λ=0.7 Seed 47: runs=7, mean=7.00, min=7, max=7, time=29.6s
# λ=0.7 Seed 48: runs=8, mean=6.62, min=6, max=8, time=26.3s
# λ=0.7 Seed 49: runs=8, mean=6.88, min=6, max=7, time=27.0s
#   → λ=0.7 avg runtime per seed: 26.5s
# λ=0.8 Seed  0: runs=1, mean=9.00, min=9, max=9, time=26.6s
# λ=0.8 Seed  1: runs=12, mean=7.08, min=6, max=8, time=25.7s
# λ=0.8 Seed  2: runs=12, mean=6.67, min=6, max=7, time=25.7s
# λ=0.8 Seed  3: runs=9, mean=6.78, min=6, max=7, time=28.3s
# λ=0.8 Seed  4: runs=4, mean=7.00, min=7, max=7, time=25.5s
# λ=0.8 Seed  5: runs=4, mean=6.25, min=6, max=7, time=25.1s
# λ=0.8 Seed  6: runs=8, mean=6.88, min=6, max=8, time=25.1s
# λ=0.8 Seed  7: runs=11, mean=6.73, min=6, max=7, time=26.3s
# λ=0.8 Seed  8: runs=3, mean=6.33, min=6, max=7, time=29.2s
# λ=0.8 Seed  9: runs=7, mean=6.29, min=6, max=7, time=28.5s
# λ=0.8 Seed 10: runs=7, mean=8.00, min=8, max=8, time=28.5s
# λ=0.8 Seed 11: runs=5, mean=6.60, min=6, max=7, time=27.2s
# λ=0.8 Seed 12: runs=5, mean=6.40, min=6, max=8, time=27.3s
# λ=0.8 Seed 13: runs=9, mean=6.78, min=6, max=7, time=27.5s
# λ=0.8 Seed 14: runs=6, mean=6.83, min=6, max=7, time=27.1s
# λ=0.8 Seed 15: runs=1, mean=7.00, min=7, max=7, time=26.4s
# λ=0.8 Seed 16: runs=10, mean=6.80, min=6, max=8, time=27.5s
# λ=0.8 Seed 17: runs=4, mean=6.50, min=6, max=7, time=23.8s
# λ=0.8 Seed 18: runs=3, mean=7.00, min=7, max=7, time=26.1s
# λ=0.8 Seed 19: runs=8, mean=6.62, min=6, max=8, time=25.3s
# λ=0.8 Seed 20: runs=9, mean=6.56, min=6, max=7, time=23.4s
# λ=0.8 Seed 21: runs=10, mean=6.70, min=6, max=7, time=27.5s
# λ=0.8 Seed 22: runs=6, mean=6.83, min=6, max=7, time=27.9s
# λ=0.8 Seed 23: runs=6, mean=6.50, min=6, max=7, time=24.8s
# λ=0.8 Seed 24: runs=4, mean=8.00, min=6, max=9, time=25.9s
# λ=0.8 Seed 25: runs=8, mean=7.25, min=6, max=8, time=26.4s
# λ=0.8 Seed 26: runs=4, mean=7.25, min=7, max=8, time=26.5s
# λ=0.8 Seed 27: runs=5, mean=7.20, min=7, max=8, time=23.9s
# λ=0.8 Seed 28: runs=8, mean=7.25, min=6, max=8, time=24.8s
# λ=0.8 Seed 29: runs=5, mean=7.40, min=7, max=8, time=28.4s
# λ=0.8 Seed 30: runs=10, mean=6.40, min=6, max=7, time=27.5s
# λ=0.8 Seed 31: runs=7, mean=6.71, min=6, max=8, time=24.8s
# λ=0.8 Seed 32: runs=1, mean=8.00, min=8, max=8, time=26.1s
# λ=0.8 Seed 33: runs=6, mean=6.50, min=6, max=7, time=26.2s
# λ=0.8 Seed 34: runs=7, mean=7.71, min=6, max=9, time=27.0s
# λ=0.8 Seed 35: runs=4, mean=7.50, min=7, max=8, time=27.5s
# λ=0.8 Seed 36: runs=11, mean=6.55, min=6, max=8, time=24.5s
# λ=0.8 Seed 37: runs=4, mean=6.75, min=6, max=7, time=27.4s
# λ=0.8 Seed 38: runs=9, mean=6.78, min=6, max=7, time=24.4s
# λ=0.8 Seed 39: runs=4, mean=7.00, min=6, max=8, time=27.7s
# λ=0.8 Seed 40: runs=8, mean=6.62, min=6, max=7, time=26.6s
# λ=0.8 Seed 41: runs=10, mean=7.80, min=7, max=8, time=25.9s
# λ=0.8 Seed 42: runs=7, mean=6.71, min=6, max=7, time=25.0s
# λ=0.8 Seed 43: runs=5, mean=6.20, min=6, max=7, time=25.0s
# λ=0.8 Seed 44: runs=8, mean=6.62, min=6, max=7, time=24.3s
# λ=0.8 Seed 45: runs=10, mean=6.50, min=6, max=7, time=25.1s
# λ=0.8 Seed 46: runs=9, mean=6.22, min=6, max=7, time=24.4s
# λ=0.8 Seed 47: runs=14, mean=6.93, min=6, max=7, time=25.9s
# λ=0.8 Seed 48: runs=10, mean=6.50, min=6, max=7, time=23.6s
# λ=0.8 Seed 49: runs=9, mean=6.78, min=5, max=8, time=25.8s
#   → λ=0.8 avg runtime per seed: 26.1s
# λ=0.9 Seed  0: runs=1, mean=9.00, min=9, max=9, time=24.3s
# λ=0.9 Seed  1: runs=9, mean=6.78, min=6, max=7, time=24.2s
# λ=0.9 Seed  2: runs=12, mean=6.75, min=6, max=7, time=24.4s
# λ=0.9 Seed  3: runs=6, mean=7.00, min=7, max=7, time=26.3s
# λ=0.9 Seed  4: runs=5, mean=6.80, min=6, max=7, time=27.4s
# λ=0.9 Seed  5: runs=4, mean=6.25, min=6, max=7, time=23.6s
# λ=0.9 Seed  6: runs=6, mean=6.67, min=6, max=7, time=25.7s
# λ=0.9 Seed  7: runs=9, mean=6.78, min=6, max=7, time=28.9s
# λ=0.9 Seed  8: runs=8, mean=6.38, min=6, max=7, time=25.3s
# λ=0.9 Seed  9: runs=7, mean=6.29, min=6, max=7, time=24.2s
# λ=0.9 Seed 10: runs=10, mean=7.30, min=6, max=8, time=27.1s
# λ=0.9 Seed 11: runs=7, mean=6.43, min=6, max=7, time=27.2s
# λ=0.9 Seed 12: runs=5, mean=6.40, min=6, max=8, time=27.8s
# λ=0.9 Seed 13: runs=9, mean=6.56, min=6, max=8, time=23.6s
# λ=0.9 Seed 14: runs=7, mean=6.86, min=6, max=7, time=22.8s
# λ=0.9 Seed 15: runs=1, mean=7.00, min=7, max=7, time=25.6s
# λ=0.9 Seed 16: runs=9, mean=6.89, min=6, max=7, time=25.9s
# λ=0.9 Seed 17: runs=4, mean=6.75, min=6, max=7, time=26.6s
# λ=0.9 Seed 18: runs=4, mean=7.00, min=7, max=7, time=25.9s
# λ=0.9 Seed 19: runs=7, mean=6.43, min=6, max=8, time=26.5s
# λ=0.9 Seed 20: runs=5, mean=6.40, min=6, max=7, time=27.4s
# λ=0.9 Seed 21: runs=6, mean=6.67, min=6, max=7, time=25.8s
# λ=0.9 Seed 22: runs=4, mean=7.00, min=7, max=7, time=24.5s
# λ=0.9 Seed 23: runs=6, mean=6.33, min=6, max=7, time=26.0s
# λ=0.9 Seed 24: runs=9, mean=7.22, min=6, max=9, time=24.6s
# λ=0.9 Seed 25: runs=6, mean=6.83, min=6, max=7, time=23.4s
# λ=0.9 Seed 26: runs=6, mean=7.00, min=6, max=8, time=23.6s
# λ=0.9 Seed 27: runs=8, mean=6.62, min=6, max=7, time=23.0s
# λ=0.9 Seed 28: runs=6, mean=6.83, min=6, max=8, time=25.4s
# λ=0.9 Seed 29: runs=9, mean=7.22, min=6, max=8, time=24.9s
# λ=0.9 Seed 30: runs=9, mean=6.56, min=6, max=7, time=24.1s
# λ=0.9 Seed 31: runs=8, mean=7.12, min=6, max=8, time=25.4s
# λ=0.9 Seed 32: runs=2, mean=7.50, min=7, max=8, time=24.7s
# λ=0.9 Seed 33: runs=8, mean=6.88, min=6, max=8, time=23.8s
# λ=0.9 Seed 34: runs=8, mean=7.12, min=6, max=9, time=26.3s
# λ=0.9 Seed 35: runs=8, mean=7.50, min=6, max=8, time=25.2s
# λ=0.9 Seed 36: runs=6, mean=6.67, min=6, max=8, time=25.9s
# λ=0.9 Seed 37: runs=3, mean=6.67, min=6, max=7, time=28.0s
# λ=0.9 Seed 38: runs=7, mean=6.86, min=6, max=7, time=23.9s
# λ=0.9 Seed 39: runs=5, mean=6.60, min=6, max=7, time=26.8s
# λ=0.9 Seed 40: runs=8, mean=6.75, min=6, max=8, time=24.8s
# λ=0.9 Seed 41: runs=12, mean=7.67, min=7, max=8, time=24.2s
# λ=0.9 Seed 42: runs=13, mean=6.69, min=6, max=7, time=26.2s
# λ=0.9 Seed 43: runs=6, mean=6.33, min=6, max=7, time=23.9s
# λ=0.9 Seed 44: runs=5, mean=6.40, min=6, max=7, time=26.0s
# λ=0.9 Seed 45: runs=8, mean=6.50, min=6, max=7, time=25.2s
# λ=0.9 Seed 46: runs=7, mean=6.57, min=6, max=8, time=24.4s
# λ=0.9 Seed 47: runs=6, mean=7.00, min=7, max=7, time=27.2s
# λ=0.9 Seed 48: runs=8, mean=6.75, min=6, max=9, time=25.2s
# λ=0.9 Seed 49: runs=9, mean=6.89, min=6, max=8, time=25.0s
#   → λ=0.9 avg runtime per seed: 25.4s
# λ=1.0 Seed  0: runs=1, mean=9.00, min=9, max=9, time=24.8s
# λ=1.0 Seed  1: runs=8, mean=6.75, min=6, max=7, time=23.2s
# λ=1.0 Seed  2: runs=11, mean=6.73, min=6, max=8, time=24.0s
# λ=1.0 Seed  3: runs=6, mean=6.83, min=6, max=7, time=25.4s
# λ=1.0 Seed  4: runs=4, mean=6.75, min=6, max=7, time=26.1s
# λ=1.0 Seed  5: runs=5, mean=6.20, min=6, max=7, time=25.3s
# λ=1.0 Seed  6: runs=6, mean=6.50, min=6, max=7, time=26.5s
# λ=1.0 Seed  7: runs=8, mean=6.75, min=6, max=7, time=29.7s
# λ=1.0 Seed  8: runs=3, mean=6.33, min=6, max=7, time=31.6s
# λ=1.0 Seed  9: runs=6, mean=6.00, min=5, max=7, time=27.9s
# λ=1.0 Seed 10: runs=7, mean=7.14, min=6, max=8, time=27.1s
# λ=1.0 Seed 11: runs=5, mean=6.40, min=6, max=7, time=26.7s
# λ=1.0 Seed 12: runs=10, mean=6.20, min=6, max=8, time=26.7s
# λ=1.0 Seed 13: runs=6, mean=6.50, min=6, max=7, time=27.1s
# λ=1.0 Seed 14: runs=9, mean=6.89, min=6, max=8, time=25.1s
# λ=1.0 Seed 15: runs=1, mean=7.00, min=7, max=7, time=25.9s
# λ=1.0 Seed 16: runs=6, mean=6.33, min=6, max=7, time=27.1s
# λ=1.0 Seed 17: runs=3, mean=7.00, min=6, max=8, time=27.8s
# λ=1.0 Seed 18: runs=5, mean=6.60, min=6, max=7, time=25.1s
# λ=1.0 Seed 19: runs=6, mean=6.67, min=6, max=8, time=25.5s
# λ=1.0 Seed 20: runs=7, mean=6.71, min=6, max=7, time=23.5s
# λ=1.0 Seed 21: runs=5, mean=6.60, min=6, max=7, time=24.1s
# λ=1.0 Seed 22: runs=9, mean=7.22, min=7, max=8, time=22.3s
# λ=1.0 Seed 23: runs=5, mean=6.80, min=6, max=8, time=23.9s
# λ=1.0 Seed 24: runs=17, mean=7.12, min=6, max=9, time=24.7s
# λ=1.0 Seed 25: runs=8, mean=7.12, min=7, max=8, time=26.7s
# λ=1.0 Seed 26: runs=4, mean=7.25, min=7, max=8, time=27.4s
# λ=1.0 Seed 27: runs=8, mean=6.88, min=6, max=8, time=25.1s
# λ=1.0 Seed 28: runs=7, mean=7.29, min=6, max=8, time=26.2s
# λ=1.0 Seed 29: runs=6, mean=7.50, min=7, max=8, time=25.9s
# λ=1.0 Seed 30: runs=3, mean=6.33, min=6, max=7, time=29.5s
# λ=1.0 Seed 31: runs=5, mean=6.80, min=6, max=7, time=27.1s
# λ=1.0 Seed 32: runs=1, mean=8.00, min=8, max=8, time=27.1s
# λ=1.0 Seed 33: runs=5, mean=6.60, min=6, max=8, time=28.3s
# λ=1.0 Seed 34: runs=8, mean=7.62, min=6, max=9, time=25.6s
# λ=1.0 Seed 35: runs=12, mean=7.50, min=6, max=8, time=24.2s
# λ=1.0 Seed 36: runs=8, mean=6.62, min=6, max=8, time=24.3s
# λ=1.0 Seed 37: runs=2, mean=6.50, min=6, max=7, time=25.8s
# λ=1.0 Seed 38: runs=6, mean=7.00, min=7, max=7, time=26.0s
# λ=1.0 Seed 39: runs=8, mean=6.50, min=6, max=8, time=25.4s
# λ=1.0 Seed 40: runs=9, mean=6.78, min=6, max=7, time=24.0s
# λ=1.0 Seed 41: runs=9, mean=7.78, min=7, max=8, time=23.5s
# λ=1.0 Seed 42: runs=15, mean=6.80, min=6, max=8, time=24.4s
# λ=1.0 Seed 43: runs=3, mean=6.33, min=6, max=7, time=25.2s
# λ=1.0 Seed 44: runs=6, mean=6.50, min=6, max=7, time=25.8s
# λ=1.0 Seed 45: runs=6, mean=7.00, min=6, max=8, time=25.4s
# λ=1.0 Seed 46: runs=7, mean=6.29, min=5, max=7, time=23.5s
# λ=1.0 Seed 47: runs=9, mean=6.89, min=6, max=7, time=25.1s
# λ=1.0 Seed 48: runs=7, mean=6.57, min=6, max=8, time=23.3s
# λ=1.0 Seed 49: runs=9, mean=6.56, min=6, max=8, time=27.5s
#   → λ=1.0 avg runtime per seed: 25.8s

# %% [markdown]
# Decreasing lambda_pen schedule testing on ER(800, 0.5, seed 0 to 49)

# %%
import torch
import networkx as nx
import numpy as np

'''
Multi-seed MIS runs with a decreasing initialization penalty schedule:
lambda_pen = 1.0 - 0.1 * (init // 5)
- Loops over graph seeds 0 to 49.
- For each graph, runs NUM_INITS restarts with degree-based initialization bias.
- Reports summary statistics for each seed.
'''

# Graph and algorithm parameters
n = 800
p = 0.5
gamma_c   = 1
beta      = 0.8
alpha     = 0.0001
ITER_T    = 150
NUM_INITS = 50
eta       = 2.0  # exploration noise scale

# Decay parameters
decay_rate = 1
BATCH_SIZE = 10

def make_degree_init(G):
    deg = dict(G.degree())
    max_deg_node = max(deg.values())
    d = torch.tensor([1 - deg[i] / max_deg_node for i in range(len(deg))],
                     dtype=torch.float32)
    return d / d.max()

def MIS_checker_efficient_3(X, A, Abar):
    n = X.shape[0]
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones(n) + (n * A) @ Xb)
    Xb_up.clamp_(0, 1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

def run_on_seed(seed):
    # build graph and its complement
    G     = nx.gnp_random_graph(n, p, seed=seed)
    Gbar  = nx.complement(G)

    # adjacency tensors
    A     = torch.tensor(nx.adjacency_matrix(G).todense(), dtype=torch.float32)
    Abar  = torch.tensor(nx.adjacency_matrix(Gbar).todense(),
                         dtype=torch.float32)

    # compute gamma = 2 + max degree in complement graph
    max_deg_bar = max(dict(Gbar.degree()).values())
    gamma       = 2 + max_deg_bar

    # degree‐based init vector
    d            = make_degree_init(G)
    cov_matrix   = eta * torch.eye(n)

    penalty_count = np.zeros(n, dtype=int)
    found_sizes   = []

    for init in range(NUM_INITS):
        # decreasing lambda_pen schedule
        lambda_pen = max(0.0, 1.0 - 0.1 * (init // 5))

        # initialization bias
        bias   = 1.0 / (1 + lambda_pen * penalty_count)
        bias_t = torch.from_numpy(bias).float()

        if init == 0:
            x = d.clone() * bias_t
        else:
            torch.manual_seed(init)
            base = torch.normal(mean=d, std=torch.sqrt(torch.diag(cov_matrix)))
            x    = base * bias_t

        v    = torch.zeros(n)
        done = False

        # gradient‐descent loop
        for _ in range(ITER_T):
            grad = -torch.ones(n) + (gamma * A - gamma_c * Abar) @ x
            v    = beta * v + alpha * grad
            x    = (x - v).clamp(0, 1)
            done, MIS = MIS_checker_efficient_3(x, A, Abar)
            if done:
                break

        if done:
            nodes = MIS.tolist()
            found_sizes.append(len(nodes))
            penalty_count[nodes] += 1

        # decay penalty counters every BATCH_SIZE inits
        if init > 0 and init % BATCH_SIZE == 0:
            penalty_count = np.maximum(penalty_count - decay_rate, 0)

    # print summary
    if found_sizes:
        mean_size = np.mean(found_sizes)
        min_size  = np.min(found_sizes)
        max_size  = np.max(found_sizes)
    else:
        mean_size = min_size = max_size = 0

    print(f"Seed {seed:2d}: runs={len(found_sizes)}, "
          f"mean={mean_size:.2f}, min={min_size}, max={max_size}")

# Main loop
print(f"Running MIS with decreasing init penalty schedule "
      f"and gamma from complement graph max‐degree:")
for seed in range(50):
    run_on_seed(seed)
# Out:
# Running MIS with decreasing init penalty schedule and gamma from complement graph max‐degree:
# Seed  0: runs=50, mean=10.18, min=8, max=13
# Seed  1: runs=50, mean=10.36, min=8, max=13
# Seed  2: runs=50, mean=9.92, min=8, max=11
# Seed  3: runs=50, mean=9.98, min=7, max=12
# Seed  4: runs=50, mean=10.20, min=8, max=12
# Seed  5: runs=50, mean=10.14, min=8, max=12
# Seed  6: runs=50, mean=9.94, min=8, max=11
# Seed  7: runs=50, mean=10.08, min=9, max=13
# Seed  8: runs=50, mean=9.94, min=8, max=12
# Seed  9: runs=50, mean=10.36, min=9, max=12
# Seed 10: runs=50, mean=9.94, min=8, max=12
# Seed 11: runs=50, mean=10.18, min=9, max=12
# Seed 12: runs=50, mean=10.00, min=8, max=12
# Seed 13: runs=50, mean=10.16, min=8, max=12
# Seed 14: runs=50, mean=10.26, min=8, max=13
# Seed 15: runs=50, mean=9.84, min=8, max=12
# Seed 16: runs=50, mean=10.02, min=8, max=11
# Seed 17: runs=50, mean=10.04, min=8, max=12
# Seed 18: runs=50, mean=10.34, min=9, max=13
# Seed 19: runs=50, mean=10.24, min=8, max=13
# Seed 20: runs=50, mean=10.26, min=9, max=12
# Seed 21: runs=50, mean=10.24, min=9, max=13
# Seed 22: runs=50, mean=10.38, min=8, max=12
# Seed 23: runs=50, mean=10.12, min=8, max=12
# Seed 24: runs=50, mean=10.10, min=9, max=13
# Seed 25: runs=50, mean=9.90, min=8, max=11
# Seed 26: runs=50, mean=10.30, min=9, max=13
# Seed 27: runs=50, mean=10.22, min=8, max=12
# Seed 28: runs=50, mean=10.02, min=9, max=12
# Seed 29: runs=50, mean=10.30, min=9, max=12
# Seed 30: runs=50, mean=10.14, min=9, max=13
# Seed 31: runs=50, mean=9.92, min=8, max=12
# Seed 32: runs=50, mean=9.96, min=8, max=12
# Seed 33: runs=50, mean=10.12, min=9, max=12
# Seed 34: runs=50, mean=10.14, min=9, max=12
# Seed 35: runs=50, mean=10.00, min=8, max=12
# Seed 36: runs=50, mean=10.18, min=9, max=13
# Seed 37: runs=50, mean=10.14, min=9, max=12
# Seed 38: runs=50, mean=10.38, min=9, max=12
# Seed 39: runs=50, mean=10.16, min=8, max=12
# Seed 40: runs=50, mean=10.14, min=9, max=12
# Seed 41: runs=50, mean=10.12, min=8, max=12
# Seed 42: runs=50, mean=10.40, min=9, max=13
# Seed 43: runs=50, mean=10.10, min=8, max=13
# Seed 44: runs=50, mean=10.08, min=8, max=12
# Seed 45: runs=50, mean=10.34, min=9, max=12
# Seed 46: runs=50, mean=9.88, min=8, max=12
# Seed 47: runs=50, mean=10.00, min=8, max=12
# Seed 48: runs=50, mean=10.16, min=8, max=13
# Seed 49: runs=50, mean=10.14, min=9, max=11

# %%
import torch
import networkx as nx
import numpy as np
import pandas as pd

# Algorithm parameters (common)
gamma_c   = 1
beta      = 0.8
alpha     = 0.0001
ITER_T    = 150
NUM_INITS = 50
eta       = 2.0

decay_rate = 1
BATCH_SIZE = 10

# Graph categories to test: (n, p)
graph_params = [
    (500, 0.3),
    (500, 0.7),
    (800, 0.3),
    (800, 0.7),
]

def make_degree_init(G):
    deg = dict(G.degree())
    max_deg_node = max(deg.values())
    d = torch.tensor([1 - deg[i] / max_deg_node for i in range(len(deg))],
                     dtype=torch.float32)
    return d / d.max()

def MIS_checker_efficient_3(X, A, Abar):
    n = X.shape[0]
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones(n) + (n * A) @ Xb)
    Xb_up.clamp_(0, 1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

def run_variant(n, p, seed, use_schedule):
    # build G and Gbar
    G    = nx.gnp_random_graph(n, p, seed=seed)
    Gbar = nx.complement(G)

    A    = torch.tensor(nx.adjacency_matrix(G).todense(), dtype=torch.float32)
    Abar = torch.tensor(nx.adjacency_matrix(Gbar).todense(),
                        dtype=torch.float32)

    # gamma = 2 + max_deg(Gbar)
    max_deg_bar = max(dict(Gbar.degree()).values())
    gamma       = 2 + max_deg_bar

    d            = make_degree_init(G)
    cov_matrix   = eta * torch.eye(n)
    penalty_count = np.zeros(n, dtype=int)
    found_sizes   = []

    for init in range(NUM_INITS):
        # dynamic lambda schedule vs. no penalty
        if use_schedule:
            lambda_pen = max(0.0, 1.0 - 0.1 * (init // 5))
        else:
            lambda_pen = 0.0

        bias   = 1.0 / (1 + lambda_pen * penalty_count)
        bias_t = torch.from_numpy(bias).float()

        if init == 0:
            x = d.clone() * bias_t
        else:
            torch.manual_seed(init)
            base = torch.normal(mean=d,
                                std=torch.sqrt(torch.diag(cov_matrix)))
            x    = base * bias_t

        v, done = torch.zeros(n), False
        for _ in range(ITER_T):
            grad = -torch.ones(n) + (gamma * A - gamma_c * Abar) @ x
            v    = beta * v + alpha * grad
            x    = (x - v).clamp(0, 1)
            done, MIS = MIS_checker_efficient_3(x, A, Abar)
            if done:
                break

        if done:
            nodes = MIS.tolist()
            found_sizes.append(len(nodes))
            penalty_count[nodes] += 1

        if init > 0 and init % BATCH_SIZE == 0:
            penalty_count = np.maximum(penalty_count - decay_rate, 0)

    return np.array(found_sizes)

# Run comparisons across all graph classes:
results = []
for (n, p) in graph_params:
    # track per-seed outcomes
    seed_outcomes = []
    for seed in range(50):
        sched_sizes = run_variant(n, p, seed, use_schedule=True)
        nopen_sizes = run_variant(n, p, seed, use_schedule=False)

        best_sched = sched_sizes.max() if sched_sizes.size else 0
        best_nopen = nopen_sizes.max() if nopen_sizes.size else 0

        if best_sched > best_nopen:
            outcome = 'schedule win'
        elif best_sched < best_nopen:
            outcome = 'no_penalty win'
        else:
            outcome = 'tie'
        seed_outcomes.append(outcome)

    # summarize
    counts = pd.Series(seed_outcomes).value_counts()
    results.append({
        'n':               n,
        'p':               p,
        'schedule wins':   int(counts.get('schedule win', 0)),
        'no_penalty wins': int(counts.get('no_penalty win', 0)),
        'ties':            int(counts.get('tie', 0)),
    })

# display as DataFrame
df_summary = pd.DataFrame(results)
print(df_summary.to_string(index=False))
