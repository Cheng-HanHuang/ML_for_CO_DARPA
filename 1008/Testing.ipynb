# %% [markdown]
# Baselines Integer Programming for MIS with time limitation based experiments
#
# New: Also gradient based solver has been added

# %% [markdown]
# Set Up and Shared Setting

# %%
import time
import networkx as nx
from ortools.sat.python import cp_model
import torch
import numpy as np
import pandas as pd
# import gurobipy as gp
# from gurobipy import GRB
from scipy.optimize import minimize
import pulp as pl

# %%
n = 500
p = 0.5
time_limit = 5     # seconds per instance
workers   = 192      # parallel threads
instances = 10
m_it = 300

# %% [markdown]
# CP-SAT

# %%
def solve_mis(n, p, seed, time_limit=50, num_workers=192):
    # 1) Generate graph
    G = nx.gnp_random_graph(n, p, seed=seed)
    
    # 2) Build model
    model = cp_model.CpModel()
    x = [model.NewBoolVar(f'x[{i}]') for i in range(n)]
    for u, v in G.edges():
        model.Add(x[u] + x[v] <= 1)
    model.Maximize(sum(x))
    
    # 3) Configure solver
    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = time_limit
    solver.parameters.num_search_workers = num_workers
    solver.parameters.log_search_progress = False  # turn off per-node logs
    
    # 4) Solve and time it
    start = time.time()
    status = solver.Solve(model)
    elapsed = time.time() - start
    
    # 5) Extract result
    if status in (cp_model.OPTIMAL, cp_model.FEASIBLE):
        size = sum(1 for i in range(n) if solver.Value(x[i]))
    else:
        size = None
    
    return {
        'seed': seed,
        'status': solver.StatusName(status),
        'size': size,
        'time_sec': elapsed
    }
    
results = []
for seed in range(instances):
    print(f"Solving seed={seed}...", end=' ', flush=True)
    res = solve_mis(n, p, seed, time_limit, workers)
    print(f"{res['status']}, size={res['size']}, time={res['time_sec']:.1f}s")
    results.append(res)
    
# Summary
sizes = [r['size'] for r in results if r['size'] is not None]
avg_size = sum(sizes) / len(sizes) if sizes else 0
print("\nPer-seed results: ER(", n, ',', p, ') with time limit ', time_limit)
for r in results:
    print(f"  seed={r['seed']:>2}  status={r['status']:<8}  size={r['size']!s:<3}  time={r['time_sec']:.1f}s")
print(f"\nAverage independent set size (over feasible runs): {avg_size:.2f}")
# Out:
# Solving seed=0... UNKNOWN, size=None, time=54.2s
# Solving seed=1... UNKNOWN, size=None, time=55.2s
# Solving seed=2... UNKNOWN, size=None, time=54.0s
# Solving seed=3... UNKNOWN, size=None, time=54.2s
# Solving seed=4... UNKNOWN, size=None, time=53.4s
# Solving seed=5... UNKNOWN, size=None, time=53.3s
# Solving seed=6... UNKNOWN, size=None, time=53.7s
# Solving seed=7... UNKNOWN, size=None, time=53.6s
# Solving seed=8... UNKNOWN, size=None, time=53.6s
# Solving seed=9... UNKNOWN, size=None, time=54.7s
#
# Per-seed results: ER( 5000 , 0.5 ) with time limit  50
#   seed= 0  status=UNKNOWN   size=None  time=54.2s
#   seed= 1  status=UNKNOWN   size=None  time=55.2s
#   seed= 2  status=UNKNOWN   size=None  time=54.0s
#   seed= 3  status=UNKNOWN   size=None  time=54.2s
#   seed= 4  status=UNKNOWN   size=None  time=53.4s
#   seed= 5  status=UNKNOWN   size=None  time=53.3s
#   seed= 6  status=UNKNOWN   size=None  time=53.7s
#   seed= 7  status=UNKNOWN   size=None  time=53.6s
#   seed= 8  status=UNKNOWN   size=None  time=53.6s
#   seed= 9  status=UNKNOWN   size=None  time=54.7s
#
# Average independent set size (over feasible runs): 0.00

# %% [markdown]
# Gurobi

# %%
def solve_mis_gurobi(n, p, seed, time_limit=10, verbose=False):
    """Builds and solves MIS on G(n,p) using Gurobi, returns result dict."""
    # Generate graph
    G = nx.gnp_random_graph(n, p, seed=seed)
    # Create Gurobi model
    model = gp.Model(f"mis_seed_{seed}")
    # Add binary variables
    x = model.addVars(n, vtype=GRB.BINARY, name="x")
    # Edge constraints
    for u, v in G.edges():
        model.addConstr(x[u] + x[v] <= 1)
    # Objective
    model.setObjective(gp.quicksum(x[i] for i in range(n)), GRB.MAXIMIZE)
    # Parameters
    model.Params.TimeLimit = time_limit
    if not verbose:
        model.Params.OutputFlag = 0
    # Solve
    start = time.time()
    model.optimize()
    elapsed = time.time() - start
    # Extract result
    status = model.Status
    size = None
    if status in (GRB.OPTIMAL, GRB.TIME_LIMIT):
        size = sum(1 for i in range(n) if x[i].X > 0.5)
    status_str = (
        "OPTIMAL" if status == GRB.OPTIMAL
        else "TIME_LIMIT" if status == GRB.TIME_LIMIT
        else str(status)
    )
    return {
        'seed': seed,
        'status': status_str,
        'size': size,
        'time_sec': elapsed
    }

# Batch execution over seeds 0–9
verbose = False

results = []
for seed in range(instances):
    print(f"Solving seed={seed}...", end=' ', flush=True)
    res = solve_mis_gurobi(n, p, seed, time_limit, verbose)
    print(f"{res['status']}, size={res['size']}, time={res['time_sec']:.1f}s")
    results.append(res)

# Summary statistics
sizes = [r['size'] for r in results if r['size'] is not None]
avg_size = sum(sizes) / len(sizes) if sizes else 0

# print("\nPer-seed results:")
print("\nPer-seed results: ER(", n, ',', p, ') with time limit ', time_limit)
for r in results:
    print(f"  seed={r['seed']:>2}  status={r['status']:<10}  size={r['size']!s:<3}  time={r['time_sec']:.1f}s")

print(f"\nAverage independent set size (over feasible runs): {avg_size:.2f}")
# Out:
# Solving seed=0...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 45
#      43 for seed in range(instances):
#      44     print(f"Solving seed={seed}...", end=' ', flush=True)
# ---> 45     res = solve_mis_gurobi(n, p, seed, time_limit, verbose)
#      46     print(f"{res['status']}, size={res['size']}, time={res['time_sec']:.1f}s")
#      47     results.append(res)
#
# Cell In[5], line 6, in solve_mis_gurobi(n, p, seed, time_limit, verbose)
#       4 G = nx.gnp_random_graph(n, p, seed=seed)
#       5 # Create Gurobi model
# ----> 6 model = gp.Model(f"mis_seed_{seed}")
#       7 # Add binary variables
#       8 x = model.addVars(n, vtype=GRB.BINARY, name="x")
#
# NameError: name 'gp' is not defined

# %%
def solve_mis_pulp_gurobi(n, p, seed, time_limit=10, verbose=False,
                          prefer_cmd=True, gurobi_path=None, extra_params=None):
    """
    Builds and solves MIS on G(n,p) using PuLP with Gurobi, returns result dict.

    prefer_cmd=True  -> use GUROBI_CMD (calls gurobi_cl), good for HPC module setups
    prefer_cmd=False -> use GUROBI (requires gurobipy available in the env)
    gurobi_path: optional path to gurobi_cl for GUROBI_CMD
    extra_params: dict of extra Gurobi params, e.g. {"MIPGap": 0.01}
    """
    extra_params = extra_params or {}

    # --- Generate graph
    G = nx.gnp_random_graph(n, p, seed=seed)

    # --- Build model
    prob = pl.LpProblem(f"mis_seed_{seed}", pl.LpMaximize)

    # Binary vars x_i in {0,1}
    x = {i: pl.LpVariable(f"x_{i}", lowBound=0, upBound=1, cat=pl.LpBinary) for i in range(n)}

    # Edge constraints: x_u + x_v <= 1
    for u, v in G.edges():
        prob += x[u] + x[v] <= 1

    # Objective: maximize sum_i x_i
    prob += pl.lpSum(x[i] for i in range(n))

    # --- Choose solver (Gurobi via PuLP)
    solver = None
    if prefer_cmd:
        # GUROBI_CMD → uses gurobi_cl (good for license/site-managed installs)
        # Time limit passed via the "TimeLimit" parameter.
        # You can add more params via extra_params.
        options = [("TimeLimit", time_limit)] + [(k, v) for k, v in extra_params.items()]
        solver = pl.GUROBI_CMD(path=gurobi_path, msg=verbose, options=options)
    else:
        # GUROBI (Python API via gurobipy)
        # timeLimit argument is accepted by PuLP GUROBI; also push extra params.
        solver = pl.GUROBI(msg=verbose, timeLimit=time_limit)
        for k, v in extra_params.items():
            solver.options[k] = v

    # --- Solve
    start = time.time()
    prob.solve(solver)
    elapsed = time.time() - start

    # --- Extract result
    pulp_status = pl.LpStatus[prob.status]
    # Heuristic: if not proven optimal but values exist, likely a feasible incumbent (often time limit)
    has_values = any(v.varValue is not None for v in x.values())
    if pulp_status == "Optimal":
        status_str = "OPTIMAL"
    elif has_values:
        # PuLP doesn't always propagate TIME_LIMIT as a distinct status for CMD; mark as such if feasible sol exists.
        status_str = "TIME_LIMIT"
    else:
        status_str = pulp_status.upper()

    size = None
    if has_values:
        size = sum(1 for i in range(n) if (x[i].varValue or 0.0) > 0.5)

    return {
        'seed': seed,
        'status': status_str,
        'size': size,
        'time_sec': elapsed
    }


# ================= Example batch run (matches your printing style) =================
if __name__ == "__main__":
    n = 500
    p = 0.5
    time_limit = 10
    instances = 10  # number of seeds (0..instances-1)
    verbose = False

    # prefer_cmd=True to use gurobi_cl via site module; set gurobi_path if needed (often not required if on $PATH)
    prefer_cmd = True
    gurobi_path = None  # e.g., "/path/to/gurobi_cl" if needed
    extra_params = {}   # e.g., {"MIPGap": 0.01}

    results = []
    for seed in range(instances):
        print(f"Solving seed={seed}...", end=' ', flush=True)
        res = solve_mis_pulp_gurobi(n, p, seed, time_limit, verbose,
                                    prefer_cmd=prefer_cmd, gurobi_path=gurobi_path,
                                    extra_params=extra_params)
        print(f"{res['status']}, size={res['size']}, time={res['time_sec']:.1f}s")
        results.append(res)

    sizes = [r['size'] for r in results if r['size'] is not None]
    avg_size = sum(sizes) / len(sizes) if sizes else 0

    print("\nPer-seed results: ER(", n, ',', p, ') with time limit ', time_limit)
    for r in results:
        print(f"  seed={r['seed']:>2}  status={r['status']:<10}  size={str(r['size']):<3}  time={r['time_sec']:.1f}s")

    print(f"\nAverage independent set size (over feasible runs): {avg_size:.2f}")
# Out:
# Solving seed=0...
# ---------------------------------------------------------------------------
# PulpSolverError                           Traceback (most recent call last)
# Cell In[4], line 89
#      87 for seed in range(instances):
#      88     print(f"Solving seed={seed}...", end=' ', flush=True)
# ---> 89     res = solve_mis_pulp_gurobi(n, p, seed, time_limit, verbose,
#      90                                 prefer_cmd=prefer_cmd, gurobi_path=gurobi_path,
#      91                                 extra_params=extra_params)
#      92     print(f"{res['status']}, size={res['size']}, time={res['time_sec']:.1f}s")
#      93     results.append(res)
#
# Cell In[4], line 46, in solve_mis_pulp_gurobi(n, p, seed, time_limit, verbose, prefer_cmd, gurobi_path, extra_params)
#      44 # --- Solve
#      45 start = time.time()
# ---> 46 prob.solve(solver)
#      47 elapsed = time.time() - start
#      49 # --- Extract result
#
# File /opt/software-current/2023.06/x86_64/generic/software/PuLP/2.8.0-foss-2023a/lib/python3.11/site-packages/pulp/pulp.py:1883, in LpProblem.solve(self, solver, **kwargs)
#    1881 # time it
#    1882 self.startClock()
# -> 1883 status = solver.actualSolve(self, **kwargs)
#    1884 self.stopClock()
#    1885 self.restoreObjective(wasNone, dummyVar)
#
# File /opt/software-current/2023.06/x86_64/generic/software/PuLP/2.8.0-foss-2023a/lib/python3.11/site-packages/pulp/apis/gurobi_api.py:450, in GUROBI_CMD.actualSolve(self, lp)
#     447 """Solve a well formulated lp problem"""
#     449 if not self.executable(self.path):
# --> 450     raise PulpSolverError("PuLP: cannot execute " + self.path)
#     451 tmpLp, tmpSol, tmpMst = self.create_tmp_files(lp.name, "lp", "sol", "mst")
#     452 vs = lp.writeLP(tmpLp, writeSOS=1)
#
# PulpSolverError: PuLP: cannot execute gurobi_cl

# %% [markdown]
# pCQO (MGD)

# %%
# ===== problem & method settings =====
gamma_c = 1.01
beta    = 0.8
alpha   = 0.0001
ITERATION_T = m_it      # max inner iterations per init

exploration_parameter_eta = 2.0
covariance_matrix = exploration_parameter_eta * torch.eye(n)

# time budget per seed (seconds)
TIME_LIMIT = time_limit

# which seeds to run
SEEDS = range(instances)      # e.g. 0–9; expand as desired

def MIS_checker_efficient_3(X, A, A_bar):
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones_like(Xb) + (n * A) @ Xb)
    Xb_up.clamp_(0, 1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

# store best per seed
best_per_seed = []

for seed in SEEDS:
    # build ER graph
    G = nx.gnp_random_graph(n, p, seed=seed)
    A     = torch.tensor(nx.adjacency_matrix(G).todense(), dtype=torch.float32)
    A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(G)).todense(), dtype=torch.float32)

    # compute gamma from complement degrees
    max_deg_c = max(dict(nx.complement(G).degree()).values())
    gamma = 2 + max_deg_c

    # degree-based init vector d
    degs = dict(G.degree())
    max_deg = max(degs.values())
    d = torch.tensor([1 - degs[i]/max_deg for i in range(n)], dtype=torch.float32)
    d = d / d.max()

    print(f"\nSeed {seed}: running MGD for up to {TIME_LIMIT}s")

    seed_start = time.time()
    trial = 0
    best_size = 0

    while time.time() - seed_start < TIME_LIMIT:
        # prepare initialization
        if trial == 0:
            x = d.clone()
        else:
            torch.manual_seed((seed << 16) + trial)
            x = torch.normal(mean=d, std=torch.sqrt(torch.diag(covariance_matrix)))
            x.clamp_(0, 1)

        v = torch.zeros(n)  # velocity
        # run momentum gradient descent
        for it in range(ITERATION_T):
            grad = -torch.ones(n) + (gamma * A - gamma_c * A_bar) @ x
            v = beta * v + alpha * grad
            x = torch.clamp(x - v, 0, 1)

            checker, MIS = MIS_checker_efficient_3(x, A, A_bar)
            if checker:
                size = MIS.numel()
                if size > best_size:
                    best_size = size
                # print(f" trial {trial:2d} iters {it+1:4d} → MIS size {size}")
                break
        else:
            # reached ITERATION_T without finding MIS
            # print(f" trial {trial:2d} iters {ITERATION_T:4d} → no MIS")
            pass

        trial += 1

    print(f"→ Seed {seed} best MIS size = {best_size}")
    best_per_seed.append(best_size)

# overall average
avg_best = np.mean(best_per_seed)
print(f"\nAverage of best MIS size across seeds: {avg_best:.2f}")
# Out:
# Seed 0: running MGD for up to 50s
# → Seed 0 best MIS size = 13
#
# Seed 1: running MGD for up to 50s
# → Seed 1 best MIS size = 14
#
# Seed 2: running MGD for up to 50s
# → Seed 2 best MIS size = 13
#
# Seed 3: running MGD for up to 50s
# → Seed 3 best MIS size = 14
#
# Seed 4: running MGD for up to 50s
# → Seed 4 best MIS size = 13
#
# Seed 5: running MGD for up to 50s
# → Seed 5 best MIS size = 14
#
# Seed 6: running MGD for up to 50s
# → Seed 6 best MIS size = 12
#
# Seed 7: running MGD for up to 50s
# → Seed 7 best MIS size = 13
#
# Seed 8: running MGD for up to 50s
# → Seed 8 best MIS size = 13
#
# Seed 9: running MGD for up to 50s
# → Seed 9 best MIS size = 14
#
# Average of best MIS size across seeds: 13.30

# %% [markdown]
# Newton

# %%
# Fixed method parameters
gamma_c = 1
exploration_parameter_eta = 2.0
max_iters = 300
tol = 1e-8
damping0 = 1e-3
ls_iters = 10
alpha0 = 900   # fixed learning rate
beta = 0.6    # fixed backtracking scale

# Instead of N_TRIALS, run up to this many seconds per seed:
TIME_LIMIT = time_limit

# Functions
def objective(x, H):
    return -x.sum() + 0.5 * x @ (H @ x)

def gradient(x, H):
    return -torch.ones_like(x) + H @ x

def MIS_checker_efficient_3(X, A, A_bar):
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones_like(Xb) + (n * A) @ Xb)
    Xb_up.clamp_(0,1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

def projected_newton(H, A, A_bar, x0):
    x = x0.clone()
    damping = damping0
    I = torch.eye(n, dtype=H.dtype)
    H_damped = H + damping * I
    history = []
    is_MIS = False
    MIS = None

    for it in range(max_iters):
        g = gradient(x, H)
        g_norm = g.norm().item()
        f0 = objective(x, H).item()
        history.append((it, f0, g_norm))
        if g_norm < tol:
            break

        try:
            p = torch.linalg.solve(H_damped, g)
        except RuntimeError:
            damping *= 10
            H_damped = H + damping * I
            continue

        alpha = alpha0
        accepted = False
        for _ in range(ls_iters):
            x_trial = torch.clamp(x - alpha * p, 0.0, 1.0)
            if objective(x_trial, H).item() < f0:
                x = x_trial
                accepted = True
                break
            alpha *= beta

        if not accepted:
            damping *= 10

        damping = max(damping * 0.5, 1e-7)
        H_damped = H + damping * I

        is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
        if is_MIS:
            break

    return x, history, is_MIS, MIS

# Main batch testing over seeds 0-9 with time‐limited trials
summaries = []
for seed in range(instances):
    # Build graph for this seed
    g = nx.gnp_random_graph(n, p, seed=seed)
    A = torch.tensor(nx.adjacency_matrix(g).todense(), dtype=torch.float32)
    A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(g)).todense(), dtype=torch.float32)

    # Build H
    degrees_c = dict(nx.complement(g).degree())
    gamma = 2 + max(degrees_c.values())
    H = gamma * A - gamma_c * A_bar

    # Degree init vector
    degrees = dict(g.degree())
    max_deg = max(degrees.values())
    d = torch.tensor([1 - degrees[i]/max_deg for i in range(n)], dtype=torch.float32)
    d_init = d / d.max()

    # Covariance
    cov = exploration_parameter_eta * torch.eye(n)

    # Run as many trials as will fit in TIME_LIMIT
    trial = 0
    trial_stats = []
    print(f"ER({n}, {p}, seed {seed}): Newton with MIS-check early exit, up to {TIME_LIMIT}s")
    seed_start = time.time()
    # print(f"\nSeed {seed}: running projected_newton for up to {TIME_LIMIT}s…")
    while True:
        # stop when time budget exceeded
        if time.time() - seed_start > TIME_LIMIT:
            break

        # prepare init
        if trial == 0:
            x0 = d_init.clone()
        else:
            torch.manual_seed((seed << 16) + trial)
            x0 = torch.normal(mean=d_init, std=torch.sqrt(torch.diag(cov)))
            x0.clamp_(0.0, 1.0)

        # run Newton
        t0 = time.time()
        x_opt, history, is_MIS, MIS = projected_newton(H, A, A_bar, x0)
        elapsed = time.time() - t0

        trial_stats.append({
            'iters': len(history),
            'time': elapsed,
            'MIS_size': MIS.numel() if is_MIS else 0
        })
        # print(f" trial {trial:2d} → iters {len(history):4d}, time {elapsed:7.4f}s, MIS_size {trial_stats[-1]['MIS_size']}")
        trial += 1

    # summarize for this seed
    df = pd.DataFrame(trial_stats)
    if not df.empty:
        summaries.append({
            'seed': seed,
            'n_trials':   len(df),
            'max_MIS_size': int(df.MIS_size.max()),
            'mean_iters': df.iters.mean(),
            'mean_time':  df.time.mean()
        })
    else:
        summaries.append({
            'seed': seed,
            'n_trials':   0,
            'max_MIS_size': 0,
            'mean_iters': 0.0,
            'mean_time':  0.0
        })

# Aggregate and display results
df_summary = pd.DataFrame(summaries)
print("\nDamped Projected Newton (time‐limited) summary:")
print(df_summary)

avg_best = df_summary['max_MIS_size'].mean()
print(f"ER({n}, {p}): Newton with MIS-check early exit, up to {TIME_LIMIT}s")
print(f"\nAverage of best MIS size across seeds: {avg_best:.2f}")
# Out:
# ER(5000, 0.5, seed 0): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 1): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 2): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 3): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 4): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 5): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 6): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 7): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 8): Newton with MIS-check early exit, up to 50s
# ER(5000, 0.5, seed 9): Newton with MIS-check early exit, up to 50s
#
# Damped Projected Newton (time‐limited) summary:
#    seed  n_trials  max_MIS_size  mean_iters   mean_time
# 0     0         1            13       280.0  172.358253
# 1     1         1             0       300.0  228.288355
# 2     2         1             0       300.0  226.139089
# 3     3         1             0       300.0  228.103144
# 4     4         1             0       300.0  229.779393
# 5     5         1            12       267.0  164.218339
# 6     6         1             0       300.0  186.093499
# 7     7         1            13       289.0  177.061132
# 8     8         1            13       210.0  159.508477
# 9     9         1             0       300.0  184.883486
# ER(5000, 0.5): Newton with MIS-check early exit, up to 50s
#
# Average of best MIS size across seeds: 5.10

# %% [markdown]
# Scipy's L-BFGS-B

# %%
# ===== your existing helper stays the same =====
class EarlyExit(Exception):
    pass

def MIS_checker_efficient_3(X_torch, adjacency_matrix_tensor, adjacency_matrix_tensor_comp):
    n_local = X_torch.shape[0]
    X_torch_binarized = X_torch.bool().float()
    X_torch_binarized_update = X_torch_binarized - 0.1 * (
        -torch.ones(n_local) + (n_local * adjacency_matrix_tensor) @ X_torch_binarized
    )
    X_torch_binarized_update = torch.clamp(X_torch_binarized_update, 0, 1)
    if torch.equal(X_torch_binarized, X_torch_binarized_update):
        MIS = torch.nonzero(X_torch_binarized).squeeze()
        return True, MIS
    return False, None

# ===== experiment settings =====
gamma_c = 1
beta = 0.8
alpha = 0.0001
ITERATION_T = m_it

# Instead of a fixed number of trials, run until this many seconds per seed:
TIME_LIMIT = time_limit  # seconds

SEEDS = range(instances)   # <- run 50 seeds

# for across-seed summary
best_size_per_seed = []
best_trial_per_seed = []
mean_runtime_per_seed = []
mean_iters_per_seed = []

for seed in SEEDS:
    # ---- build graph for this seed ----
    G = nx.gnp_random_graph(n, p, seed=seed)
    complement_G = nx.complement(G)

    num_components = nx.number_connected_components(G)
    print(f"\n================== Seed {seed} ==================")
    print("Number of connected components:", num_components)

    A = nx.adjacency_matrix(G).todense()
    A_t = torch.tensor(A, dtype=torch.float32)
    Acomp = nx.adjacency_matrix(complement_G).todense()
    Acomp_t = torch.tensor(Acomp, dtype=torch.float32)

    # gamma depends on complement degree
    max_degree = max(dict(complement_G.degree()).values())
    gamma = 2 + max_degree

    # degree-based init d
    degrees = dict(G.degree())
    max_degree_node = max(degrees.values())
    d = torch.tensor([1 - (degrees[i] / max_degree_node) for i in range(n)], dtype=torch.float32)
    d = d / d.max()

    # H and smooth objective/grad for SciPy
    # H_np = (gamma * A_t).numpy()
    H_np = (gamma * A_t - gamma_c * Acomp_t).numpy()

    def f_np(x):
        return -np.sum(x) + 0.5 * x.dot(H_np.dot(x))

    def grad_np(x):
        return -np.ones_like(x) + H_np.dot(x)

    bounds = [(0.0, 1.0)] * n

    # per-seed collectors
    MIS_size, Iter_NO, Run_time = [], [], []

    exploration_parameter_eta = 2.0
    covariance_matrix = exploration_parameter_eta * torch.eye(n)

    print(f"ER({n}, {p}, seed={seed}): L-BFGS-B with MIS-check early exit, up to {TIME_LIMIT}s")

    seed_start_time = time.time()
    trial = 0
    while True:
        # Check time budget
        if time.time() - seed_start_time > TIME_LIMIT:
            break

        # prepare init
        if trial == 0:
            x0_np = d.numpy()
        else:
            torch.manual_seed((seed << 16) + trial)
            noise = torch.normal(mean=d, std=torch.sqrt(torch.diag(covariance_matrix)))
            x0_np = noise.numpy()

        iter_counter = {"count": 0}
        last_x = {"xk": None}

        def lbfgs_callback(xk):
            iter_counter["count"] += 1
            last_x["xk"] = xk.copy()
            x_t = torch.tensor(xk, dtype=torch.float32)
            checker, mis = MIS_checker_efficient_3(x_t, A_t, Acomp_t)
            if checker:
                raise EarlyExit()

        start_time = time.time()
        try:
            res = minimize(
                fun      = f_np,
                x0       = x0_np,
                method   = "L-BFGS-B",
                jac      = grad_np,
                bounds   = bounds,
                callback = lbfgs_callback,
                options  = {
                    "maxiter": ITERATION_T,
                    "gtol":    0.0,
                    "ftol":    0.0,
                }
            )
            total_iters = res.nit
            x_final_np = res.x
        except EarlyExit:
            total_iters = iter_counter["count"]
            x_final_np = last_x["xk"]

        x_final = torch.tensor(x_final_np, dtype=torch.float32)
        checker, mis = MIS_checker_efficient_3(x_final, A_t, Acomp_t)

        elapsed = time.time() - start_time

        if mis is not None:
            # print(f" trial {trial:2d} → MIS size {len(mis):3d}, iters {total_iters:5d}, time {elapsed:7.4f}s")
            MIS_size.append(len(mis))
            Iter_NO.append(total_iters)
            Run_time.append(elapsed)
        else:
            # print(f" trial {trial:2d} → no MIS (iters {total_iters:4d}, time {elapsed:7.4f}s)")
            MIS_size.append(0)
            Iter_NO.append(total_iters)
            Run_time.append(elapsed)
            

        trial += 1

    # per-seed summary
    if MIS_size:
        mis_sizes   = np.array(MIS_size)
        runtimes    = np.array(Run_time)
        iter_counts = np.array(Iter_NO)

        best_size = mis_sizes.max()
        best_run  = mis_sizes.argmax()
        mean_rt   = runtimes.mean()
        mean_it   = iter_counts.mean()
        p2_5_rt, p97_5_rt = np.percentile(runtimes, [2.5, 97.5])
        p2_5_it, p97_5_it = np.percentile(iter_counts, [2.5, 97.5])
        
        '''print(f"— Seed {seed} summary —")
        print(f"Best MIS size: {best_size} (trial {best_run})")
        print(f"Runtime (s): mean={mean_rt:.4f}, min={runtimes.min():.4f}, max={runtimes.max():.4f}, "
              f"std={runtimes.std(ddof=1):.4f}, 95% CI=({p2_5_rt:.4f}, {p97_5_rt:.4f})")
        print(f"Iters: mean={mean_it:.1f}, min={iter_counts.min()}, max={iter_counts.max()}, "
              f"std={iter_counts.std(ddof=1):.1f}, 95% CI=({p2_5_it:.1f}, {p97_5_it:.1f})")'''

        best_size_per_seed.append(best_size)
        best_trial_per_seed.append(int(best_run))
        mean_runtime_per_seed.append(float(mean_rt))
        mean_iters_per_seed.append(float(mean_it))
    else:
        print(f"— Seed {seed} summary — no MIS flagged by checker.")
        '''best_size_per_seed.append(None)
        best_trial_per_seed.append(None)
        mean_runtime_per_seed.append(None)
        mean_iters_per_seed.append(None)'''

# across-seeds summary
print(f"ER({n}, {p}): L-BFGS-B with MIS-check early exit, up to {TIME_LIMIT}s")
vals = [v for v in best_size_per_seed if v is not None]
if vals:
    vals = np.array(vals)
    print("\n=========== Across-seeds summary (best per seed) ===========")
    print(f"Seeds with MIS: {len(vals)}/{len(SEEDS)}")
    # print(f"Best MIS size: max={vals.max()}, min={vals.min()}, mean={vals.mean():.2f}, std={vals.std(ddof=1):.2f}")
    print(f"Mean MIS size: {vals.mean():.2f}")
# Out:
# ================== Seed 0 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=0): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 1 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=1): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 2 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=2): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 3 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=3): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 4 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=4): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 5 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=5): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 6 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=6): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 7 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=7): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 8 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=8): L-BFGS-B with MIS-check early exit, up to 50s
#
# ================== Seed 9 ==================
# Number of connected components: 1
# ER(5000, 0.5, seed=9): L-BFGS-B with MIS-check early exit, up to 50s
# ER(5000, 0.5): L-BFGS-B with MIS-check early exit, up to 50s
#
# =========== Across-seeds summary (best per seed) ===========
# Seeds with MIS: 10/10
# Mean MIS size: 0.00

# %% [markdown]
# ## Free Mask Settings ##

# %%
import torch
import networkx as nx
import numpy as np
import time

# ===========================
# Helpers & MIS checker (same as your version)
# ===========================
class EarlyExit(Exception):
    pass

def MIS_checker_efficient_3(X_torch, adjacency_matrix_tensor, adjacency_matrix_tensor_comp):
    n_local = X_torch.shape[0]
    X_torch_binarized = X_torch.bool().float()
    X_torch_binarized_update = X_torch_binarized - 0.1 * (
        -torch.ones(n_local) + (n_local * adjacency_matrix_tensor) @ X_torch_binarized
    )
    X_torch_binarized_update = torch.clamp(X_torch_binarized_update, 0, 1)
    if torch.equal(X_torch_binarized, X_torch_binarized_update):
        MIS = torch.nonzero(X_torch_binarized).squeeze()
        return True, MIS
    return False, None

def project_box(x, lo=0.0, hi=1.0):
    return np.minimum(np.maximum(x, lo), hi)

def free_mask(x, g, lo=0.0, hi=1.0, eps=1e-8):
    inside = (x > lo + eps) & (x < hi - eps)
    at_lo_can_increase = (x <= lo + eps) & (g < 0)  # step -g increases x
    at_hi_can_decrease = (x >= hi - eps) & (g > 0)  # step -g decreases x
    return inside | at_lo_can_increase | at_hi_can_decrease

def lbfgs_two_loop_restricted(grad, S_list, Y_list, free):
    g = grad.copy()
    g[~free] = 0.0
    q = g.copy()
    alphas, rhos = [], []
    # reverse pass
    for s, y in reversed(list(zip(S_list, Y_list))):
        s_f = s.copy(); y_f = y.copy()
        s_f[~free] = 0.0; y_f[~free] = 0.0
        ys = float(y_f @ s_f)
        if ys <= 1e-16 or not np.isfinite(ys):
            alphas.append(0.0); rhos.append(1.0); continue
        rho = 1.0 / ys
        rhos.append(rho)
        alpha = rho * float(s_f @ q)
        alphas.append(alpha)
        q -= alpha * y_f
    # H0 scaling
    if len(S_list) > 0:
        y_last = Y_list[-1].copy(); s_last = S_list[-1].copy()
        y_last[~free] = 0.0; s_last[~free] = 0.0
        denom = float(y_last @ y_last)
        num   = float(s_last @ y_last)
        H0 = (num / denom) if (denom > 1e-16 and np.isfinite(num) and np.isfinite(denom)) else 1.0
        if H0 <= 1e-16: H0 = 1.0
    else:
        H0 = 1.0
    r = H0 * q
    # forward pass
    for (s, y), rho, alpha in zip(zip(S_list, Y_list), rhos[::-1], alphas[::-1]):
        s_f = s.copy(); y_f = y.copy()
        s_f[~free] = 0.0; y_f[~free] = 0.0
        ys = float(y_f @ s_f)
        if ys <= 1e-16 or not np.isfinite(ys):
            continue
        beta = rho * float(y_f @ r)
        r += s_f * (alpha - beta)
    p = -r
    p[~free] = 0.0
    return p

def backtracking_armijo_projected(f, x, fx, grad, p, proj_fn, c1=1e-4, tau=0.6, alpha0=1000.0, max_backtracks=80):
    gTp = float(grad @ p)
    if gTp >= 0:
        p = -grad
        gTp = float(grad @ p)
        if gTp >= 0:
            return 0.0, x, fx
    alpha = alpha0
    for _ in range(max_backtracks):
        x_trial = proj_fn(x + alpha * p)
        f_trial = f(x_trial)
        if f_trial <= fx + c1 * alpha * gTp:
            return alpha, x_trial, f_trial
        alpha *= tau
    return 0.0, x, fx

# ===========================
# Experiment settings (time-budgeted per seed)
# ===========================


gamma_c = 1.01             # we include gamma_c like your reference time-limit script
ITERATION_T = m_it

SEEDS = range(instances)       # adjust as you like

# L-BFGS knobs (same as your fast variant)
MEMORY_M = 10
ALPHA0   = 1000.0
TAU      = 0.6
PRINT_EVERY = 0         # set >0 for progress lines every k iters

# Across-seed collectors
best_size_per_seed = []
best_trial_per_seed = []
mean_runtime_per_seed = []
mean_iters_per_seed = []
trials_per_seed = []    # how many inits fit in the time budget

for seed in SEEDS:
    # ---- build graph for this seed ----
    G = nx.gnp_random_graph(n, p, seed=seed)
    complement_G = nx.complement(G)

    # adjacency (numpy + torch)
    A_np = np.asarray(nx.adjacency_matrix(G).astype(np.float32).todense(), dtype=np.float32)
    A_t  = torch.tensor(A_np)
    Acomp_np = np.asarray(nx.adjacency_matrix(complement_G).astype(np.float32).todense(), dtype=np.float32)
    Acomp_t  = torch.tensor(Acomp_np)

    # gamma from complement degree
    degrees_c = dict(complement_G.degree())
    max_degree_c = max(degrees_c.values()) if degrees_c else 0
    gamma = 2 + max_degree_c

    # degree-based init d
    degrees = dict(G.degree())
    max_degree_node = max(degrees.values()) if degrees else 1
    d = torch.zeros(n, dtype=torch.float32)
    for node, deg in G.degree():
        d[node] = 1.0 - (deg / max_degree_node if max_degree_node > 0 else 0.0)
    if d.max() > 0: d = d / d.max()

    # Quadratic model (match your SciPy time-limit reference: gamma*A - gamma_c*Acomp)
    H_np = (gamma * A_np - gamma_c * Acomp_np).astype(np.float32)

    def f_np(x):
        return float(-np.sum(x) + 0.5 * (x @ (H_np @ x)))

    def g_np(x):
        return (-np.ones_like(x) + H_np @ x).astype(np.float32)

    bounds_proj = lambda z: project_box(z, 0.0, 1.0)

    # per-seed stats
    MIS_size, Iter_NO, Run_time = [], [], []
    num_trials_done = 0

    # exploration noise
    exploration_parameter_eta = 2.0
    cov = exploration_parameter_eta * torch.eye(n)

    print(f"\n================== Seed {seed} ==================")
    print(f"ER({n}, {p}, seed={seed}): Handcrafted projected L-BFGS (no Cauchy), time budget = {time_limit}s")

    seed_start_time = time.time()
    trial = 0
    while True:
        # stop if time budget exceeded (strictly >, so the last finished trial counts)
        if time.time() - seed_start_time > time_limit:
            break

        # initialization
        if trial == 0:
            x0 = bounds_proj(d.numpy().astype(np.float32))
        else:
            torch.manual_seed((seed << 16) + trial)
            noise = torch.normal(mean=d, std=torch.sqrt(torch.diag(cov)))
            x0 = bounds_proj(noise.numpy().astype(np.float32))

        x = x0.copy()
        fx = f_np(x)
        g  = g_np(x)

        S_list, Y_list = [], []
        total_iters = 0
        start_time = time.time()
        mis_found = None

        for it in range(1, ITERATION_T + 1):
            total_iters = it

            # free set + direction
            free = free_mask(x, g, lo=0.0, hi=1.0, eps=1e-10)
            if not np.any(free):
                p_dir = -g
                p_dir[np.abs(p_dir) < 1e-12] = 0.0
            else:
                p_dir = lbfgs_two_loop_restricted(g, S_list, Y_list, free)
                if np.allclose(p_dir, 0.0):
                    p_dir = -g
                    p_dir[~free] = 0.0

            # line search (projected Armijo)
            alpha, x_new, f_new = backtracking_armijo_projected(
                f_np, x, fx, g, p_dir, bounds_proj,
                c1=1e-4, tau=TAU, alpha0=ALPHA0, max_backtracks=80
            )
            if alpha == 0.0:
                p_fb = -g; p_fb[~free] = 0.0
                if np.linalg.norm(p_fb) < 1e-14:
                    break
                x_new = bounds_proj(x + 1e-2 * p_fb)
                f_new = f_np(x_new)

            # MIS early exit
            chk, mis = MIS_checker_efficient_3(torch.tensor(x_new, dtype=torch.float32), A_t, Acomp_t)
            if chk:
                mis_found = mis
                x, fx = x_new, f_new
                if PRINT_EVERY and ((it % PRINT_EVERY) == 0 or it == 1):
                    print(f"  it {it:5d}: MIS found, f={fx:.4f}")
                break

            g_new = g_np(x_new)

            # curvature update
            s = (x_new - x).astype(np.float32)
            y = (g_new - g).astype(np.float32)
            ys = float(y @ s)
            if np.isfinite(ys) and ys > 1e-10:
                S_list.append(s); Y_list.append(y)
                if len(S_list) > MEMORY_M:
                    S_list.pop(0); Y_list.pop(0)

            x, fx, g = x_new, f_new, g_new

            if PRINT_EVERY and (it % PRINT_EVERY) == 0:
                pg_norm = np.linalg.norm(np.where(free, g, 0.0))
                print(f"  it {it:5d}: f={fx:.6f}, ||proj-grad||={pg_norm:.3e}")

        elapsed = time.time() - start_time
        num_trials_done += 1

        if mis_found is not None:
            size = int(len(mis_found))
            MIS_size.append(size); Iter_NO.append(total_iters); Run_time.append(elapsed)
        # else: no MIS found this trial → we just don’t append

        trial += 1

    trials_per_seed.append(num_trials_done)

    # per-seed summary (store only stats we need for across-seed mean)
    if MIS_size:
        mis_sizes   = np.array(MIS_size)
        runtimes    = np.array(Run_time)
        iter_counts = np.array(Iter_NO)

        best_size = int(mis_sizes.max())
        print("Best Size: ", best_size)
        best_run  = int(mis_sizes.argmax())
        mean_rt   = float(runtimes.mean())
        mean_it   = float(iter_counts.mean())

        best_size_per_seed.append(best_size)
        best_trial_per_seed.append(best_run)
        mean_runtime_per_seed.append(mean_rt)
        mean_iters_per_seed.append(mean_it)
    else:
        # no MIS found within time budget for this seed → skip adding Nones
        pass

# across-seeds summary (match your SciPy style)
print(f"\nER({n}, {p}): Handcrafted projected L-BFGS (no Cauchy), time budget = {time_limit}s")
vals = [v for v in best_size_per_seed if v is not None]
if vals:
    vals = np.array(vals)
    print("=========== Across-seeds summary (best per seed) ===========")
    print(f"Seeds with MIS: {len(vals)}/{len(SEEDS)}")
    print(f"Mean MIS size: {vals.mean():.2f}")
    # If you also want to see how many trials ran (avg), uncomment:
    # print(f"Mean trials per seed (time-limited): {np.mean(trials_per_seed):.1f}")
# Out:
# ================== Seed 0 ==================
# ER(5000, 0.5, seed=0): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  13
#
# ================== Seed 1 ==================
# ER(5000, 0.5, seed=1): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ================== Seed 2 ==================
# ER(5000, 0.5, seed=2): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  13
#
# ================== Seed 3 ==================
# ER(5000, 0.5, seed=3): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  13
#
# ================== Seed 4 ==================
# ER(5000, 0.5, seed=4): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ================== Seed 5 ==================
# ER(5000, 0.5, seed=5): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  15
#
# ================== Seed 6 ==================
# ER(5000, 0.5, seed=6): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ================== Seed 7 ==================
# ER(5000, 0.5, seed=7): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ================== Seed 8 ==================
# ER(5000, 0.5, seed=8): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ================== Seed 9 ==================
# ER(5000, 0.5, seed=9): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# Best Size:  14
#
# ER(5000, 0.5): Handcrafted projected L-BFGS (no Cauchy), time budget = 50s
# =========== Across-seeds summary (best per seed) ===========
# Seeds with MIS: 10/10
# Mean MIS size: 13.80

# %%
import torch
import networkx as nx
import numpy as np
import time

# ===========================
# Helpers & MIS checker
# ===========================
class EarlyExit(Exception):
    pass

def MIS_checker_efficient_3(X_torch, adjacency_matrix_tensor, adjacency_matrix_tensor_comp):
    n_local = X_torch.shape[0]
    X_torch_binarized = X_torch.bool().float()
    X_torch_binarized_update = X_torch_binarized - 0.1*(-torch.ones(n_local) + (n_local*adjacency_matrix_tensor)@X_torch_binarized)
    X_torch_binarized_update = torch.clamp(X_torch_binarized_update, 0, 1)
    if torch.equal(X_torch_binarized, X_torch_binarized_update):
        MIS = torch.nonzero(X_torch_binarized).squeeze()
        return True, MIS
    return False, None

def project_box(x, lo=0.0, hi=1.0):
    return np.minimum(np.maximum(x, lo), hi)

# Build a "free set" mask like L-BFGS-B (who is allowed to move?)
def free_mask(x, g, lo=0.0, hi=1.0, eps=1e-8):
    # free if strictly inside OR at lower bound but gradient wants to go up (g<0 step -g goes up)
    # OR at upper bound but gradient wants to go down (g>0 step -g goes down)
    inside = (x > lo + eps) & (x < hi - eps)
    at_lo_can_increase = (x <= lo + eps) & (g < 0)   # step -g increases x
    at_hi_can_decrease = (x >= hi - eps) & (g > 0)   # step -g decreases x
    return inside | at_lo_can_increase | at_hi_can_decrease

# Two-loop recursion for (approx) -H_k * g restricted to free set
def lbfgs_two_loop_restricted(grad, S_list, Y_list, free):
    # Work only on free coordinates
    g = grad.copy()
    g[~free] = 0.0
    q = g.copy()
    alphas = []
    rhos = []
    # reverse pass
    for s, y in reversed(list(zip(S_list, Y_list))):
        s_f = s.copy(); y_f = y.copy()
        s_f[~free] = 0.0; y_f[~free] = 0.0
        ys = y_f @ s_f
        if ys <= 1e-16 or not np.isfinite(ys):
            alphas.append(0.0); rhos.append(1.0)
            continue
        rho = 1.0 / ys
        rhos.append(rho)
        alpha = rho * (s_f @ q)
        alphas.append(alpha)
        q -= alpha * y_f
    # H0 scaling
    if len(S_list) > 0:
        y_last = Y_list[-1].copy()
        s_last = S_list[-1].copy()
        y_last[~free] = 0.0; s_last[~free] = 0.0
        denom = y_last @ y_last
        num   = s_last @ y_last
        H0 = (num / denom) if (denom > 1e-16 and np.isfinite(num) and np.isfinite(denom)) else 1.0
        if H0 <= 1e-16: H0 = 1.0
    else:
        H0 = 1.0
    r = H0 * q
    # forward pass
    for (s, y), rho, alpha in zip(zip(S_list, Y_list), rhos[::-1], alphas[::-1]):
        s_f = s.copy(); y_f = y.copy()
        s_f[~free] = 0.0; y_f[~free] = 0.0
        ys = y_f @ s_f
        if ys <= 1e-16 or not np.isfinite(ys):
            continue
        beta = rho * (y_f @ r)
        r += s_f * (alpha - beta)
    p = -r
    # never move fixed coords
    p[~free] = 0.0
    return p

def backtracking_armijo_projected(f, x, fx, grad, p, proj_fn, c1=1e-4, tau=0.6, alpha0=1000.0, max_backtracks=80):
    # Use the directional derivative BEFORE projection (L-BFGS-B style)
    gTp = grad @ p
    # If not descent, fall back to steepest descent in free coordinates
    if gTp >= 0:
        p = -grad
        gTp = grad @ p
        if gTp >= 0:
            # gradient is zero or numerical; tiny step
            return 0.0, x, fx
    alpha = alpha0
    for _ in range(max_backtracks):
        x_trial = proj_fn(x + alpha * p)
        f_trial = f(x_trial)
        if f_trial <= fx + c1 * alpha * gTp:
            return alpha, x_trial, f_trial
        alpha *= tau
    return 0.0, x, fx

# ===========================
# Experiment settings
# ===========================
n = 500
p = 0.5
ITERATION_T = 15000
NUM_TRIALS = 10
SEEDS = range(50)

MEMORY_M = 10
ALPHA0   = 900   # aggressive initial step (your Newton used ~900)
TAU      = 0.6       # backtracking factor to match your Newton
PRINT_EVERY = 50     # progress prints

# Across-seed summary
best_size_per_seed = []
best_trial_per_seed = []
mean_runtime_per_seed = []
mean_iters_per_seed = []

for seed in SEEDS:
    # ---- Build graph for this seed ----
    G = nx.gnp_random_graph(n, p, seed=seed)
    complement_G = nx.complement(G)

    num_components = nx.number_connected_components(G)
    print(f"\n================== Seed {seed} ==================")
    print("Number of connected components:", num_components)

    A = nx.adjacency_matrix(G).astype(np.float32)
    A_np = np.asarray(A.todense(), dtype=np.float32)
    A_t = torch.tensor(A_np)

    Acomp = nx.adjacency_matrix(complement_G).astype(np.float32)
    Acomp_np = np.asarray(Acomp.todense(), dtype=np.float32)
    Acomp_t = torch.tensor(Acomp_np)

    # gamma based on complement degree
    degrees_c = dict(complement_G.degree())
    max_degree_c = max(degrees_c.values()) if degrees_c else 0
    gamma = 2 + max_degree_c

    # degree-based init d
    degrees = dict(G.degree())
    max_degree_node = max(degrees.values()) if degrees else 1
    d = torch.zeros(n, dtype=torch.float32)
    for node, deg in G.degree():
        d[node] = 1.0 - (deg / max_degree_node if max_degree_node > 0 else 0.0)
    if d.max() > 0: d = d / d.max()

    # Smooth quadratic (same as your SciPy definition with H = gamma*A)
    H_np = (gamma * A_np).astype(np.float32)

    def f_np(x):
        return float(-np.sum(x) + 0.5 * (x @ (H_np @ x)))

    def grad_np(x):
        return (-np.ones_like(x) + H_np @ x).astype(np.float32)

    bounds_proj = lambda z: project_box(z, 0.0, 1.0)

    # Per-seed collectors
    MIS_size, Iter_NO, Run_time = [], [], []

    # exploration noise
    exploration_parameter_eta = 2.0
    cov = exploration_parameter_eta * torch.eye(len(d))
    print(f"ER({n}, {p}, seed={seed}): Handcrafted projected L-BFGS-B (free-set) with MIS-check")

    for init in range(NUM_TRIALS):
        if init == 0:
            x0_np = d.numpy()
        else:
            torch.manual_seed((seed << 16) + init)
            noise = torch.normal(mean=d, std=torch.sqrt(torch.diag(cov)))
            x0_np = noise.numpy()

        x = bounds_proj(x0_np.astype(np.float32))
        fx = f_np(x)
        g  = grad_np(x)

        S_list, Y_list = [], []
        total_iters = 0
        start_time = time.time()
        mis_found = None

        for it in range(1, ITERATION_T + 1):
            total_iters = it

            # free set and direction
            free = free_mask(x, g, lo=0.0, hi=1.0, eps=1e-10)
            if not np.any(free):
                # everything clamped; try steepest descent anyway
                p_dir = -g
                p_dir[np.abs(p_dir) < 1e-12] = 0.0
            else:
                p_dir = lbfgs_two_loop_restricted(g, S_list, Y_list, free)

            # line search (projected Armijo)
            alpha, x_new, f_new = backtracking_armijo_projected(
                f_np, x, fx, g, p_dir, bounds_proj,
                c1=1e-4, tau=TAU, alpha0=ALPHA0, max_backtracks=80
            )

            # if line search failed to move, try a small steepest-descent nudge
            if alpha == 0.0:
                p_fallback = -g
                p_fallback[~free] = 0.0
                if np.linalg.norm(p_fallback) < 1e-14:
                    # nowhere to go
                    break
                alpha_small = 1e-2
                x_new = bounds_proj(x + alpha_small * p_fallback)
                f_new = f_np(x_new)

            # MIS early exit
            x_t = torch.tensor(x_new, dtype=torch.float32)
            chk, mis = MIS_checker_efficient_3(x_t, A_t, Acomp_t)
            if chk:
                mis_found = mis
                x, fx = x_new, f_new
                if (it % PRINT_EVERY) == 0 or it == 1:
                    print(f"  it {it:5d}: MIS found, f={fx:.4f}")
                break

            g_new = grad_np(x_new)

            # curvature pair with safeguard
            s = (x_new - x).astype(np.float32)
            y = (g_new - g).astype(np.float32)
            ys = float(y @ s)
            if np.isfinite(ys) and ys > 1e-10:
                S_list.append(s)
                Y_list.append(y)
                if len(S_list) > MEMORY_M:
                    S_list.pop(0); Y_list.pop(0)

            x, fx, g = x_new, f_new, g_new

            if (it % PRINT_EVERY) == 0:
                pg_norm = np.linalg.norm(np.where(free, g, 0.0))
                '''print(f"  it {it:5d}: f={fx:.6f}, ||proj-grad||={pg_norm:.3e}")'''

        elapsed = time.time() - start_time

        if mis_found is not None:
            size = int(len(mis_found))
            print(f"init {init:2d} → MIS size {size:3d}, iters {total_iters:5d}, time {elapsed:7.4f}s")
            MIS_size.append(size); Iter_NO.append(total_iters); Run_time.append(elapsed)
        else:
            # final check anyway
            x_t = torch.tensor(x, dtype=torch.float32)
            chk, mis = MIS_checker_efficient_3(x_t, A_t, Acomp_t)
            if chk:
                size = int(len(mis))
                print(f"init {init:2d} → MIS size {size:3d}, iters {total_iters:5d}, time {elapsed:7.4f}s")
                MIS_size.append(size); Iter_NO.append(total_iters); Run_time.append(elapsed)
            else:
                print(f"init {init:2d} → no MIS flagged (iters {total_iters}, time {elapsed:7.4f}s)")

    # Per-seed summary
    if MIS_size:
        mis_sizes   = np.array(MIS_size)
        runtimes    = np.array(Run_time)
        iter_counts = np.array(Iter_NO)

        best_size = int(mis_sizes.max())
        best_run  = int(mis_sizes.argmax())
        mean_rt   = float(runtimes.mean())
        mean_it   = float(iter_counts.mean())

        p2_5_rt, p97_5_rt = np.percentile(runtimes, [2.5, 97.5])
        p2_5_it, p97_5_it = np.percentile(iter_counts, [2.5, 97.5])

        print(f"— Seed {seed} summary —")
        print(f"Best MIS size: {best_size} (trial {best_run})")
        print(f"Runtime (s): mean={mean_rt:.4f}, min={runtimes.min():.4f}, max={runtimes.max():.4f}, "
              f"std={runtimes.std(ddof=1):.4f}, 95% CI=({p2_5_rt:.4f}, {p97_5_rt:.4f})")
        print(f"Iters: mean={mean_it:.1f}, min={iter_counts.min()}, max={iter_counts.max()}, "
              f"std={iter_counts.std(ddof=1):.1f}, 95% CI=({p2_5_it:.1f}, {p97_5_it:.1f})")

        best_size_per_seed.append(best_size)
        best_trial_per_seed.append(best_run)
        mean_runtime_per_seed.append(mean_rt)
        mean_iters_per_seed.append(mean_it)
    else:
        print(f"— Seed {seed} summary — no MIS flagged by checker.")
        best_size_per_seed += [None]; best_trial_per_seed += [None]
        mean_runtime_per_seed += [None]; mean_iters_per_seed += [None]

# Across-seed summary
vals = [v for v in best_size_per_seed if v is not None]
if vals:
    vals = np.array(vals)
    print("\n=========== Across-seeds summary (best per seed) ===========")
    print(f"Seeds with MIS: {len(vals)}/{len(SEEDS)}")
    print(f"Best MIS size: max={vals.max()}, min={vals.min()}, mean={vals.mean():.2f}, std={vals.std(ddof=1):.2f}")
# Out:
# ================== Seed 0 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=0): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    24, time  0.0190s
# init  1 → MIS size  10, iters    15, time  0.0114s
# init  2 → MIS size   9, iters    18, time  0.0134s
# init  3 → MIS size  10, iters    20, time  0.0132s
# init  4 → MIS size  11, iters    14, time  0.0093s
# init  5 → MIS size   8, iters    16, time  0.0132s
# init  6 → MIS size  11, iters    22, time  0.0157s
# init  7 → MIS size   8, iters    26, time  0.0199s
# init  8 → MIS size  10, iters    22, time  0.0146s
# init  9 → MIS size   9, iters    17, time  0.0117s
# — Seed 0 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=0.0141, min=0.0093, max=0.0199, std=0.0033, 95% CI=(0.0097, 0.0197)
# Iters: mean=19.4, min=14, max=26, std=4.0, 95% CI=(14.2, 25.6)
#
# ================== Seed 1 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=1): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    24, time  0.0663s
# init  1 → MIS size  10, iters    17, time  0.0680s
# init  2 → MIS size  10, iters    15, time  0.0107s
# init  3 → MIS size  11, iters    21, time  0.0160s
# init  4 → MIS size  10, iters    19, time  0.0138s
# init  5 → MIS size   9, iters    12, time  0.0075s
# init  6 → MIS size  10, iters    19, time  0.0159s
# init  7 → MIS size   8, iters    17, time  0.0120s
# init  8 → MIS size   9, iters    17, time  0.0117s
# init  9 → MIS size  10, iters    18, time  0.0112s
# — Seed 1 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0233, min=0.0075, max=0.0680, std=0.0232, 95% CI=(0.0082, 0.0676)
# Iters: mean=17.9, min=12, max=24, std=3.2, 95% CI=(12.7, 23.3)
#
# ================== Seed 2 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=2): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    25, time  0.0188s
# init  1 → MIS size  10, iters    18, time  0.0125s
# init  2 → MIS size  11, iters    12, time  0.0074s
# init  3 → MIS size  10, iters    19, time  0.0126s
# init  4 → MIS size  10, iters    21, time  0.0138s
# init  5 → MIS size  10, iters    16, time  0.0106s
# init  6 → MIS size  10, iters    17, time  0.0122s
# init  7 → MIS size   9, iters    21, time  0.0149s
# init  8 → MIS size   9, iters    29, time  0.0234s
# init  9 → MIS size  10, iters    17, time  0.0117s
# — Seed 2 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0138, min=0.0074, max=0.0234, std=0.0045, 95% CI=(0.0081, 0.0224)
# Iters: mean=19.5, min=12, max=29, std=4.8, 95% CI=(12.9, 28.1)
#
# ================== Seed 3 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=3): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    31, time  0.0235s
# init  1 → MIS size  10, iters    14, time  0.0088s
# init  2 → MIS size  10, iters    17, time  0.0111s
# init  3 → MIS size   8, iters    22, time  0.0165s
# init  4 → MIS size  10, iters    17, time  0.0108s
# init  5 → MIS size  10, iters    22, time  0.0156s
# init  6 → MIS size   9, iters    14, time  0.0097s
# init  7 → MIS size   9, iters    18, time  0.0117s
# init  8 → MIS size  10, iters    19, time  0.0125s
# init  9 → MIS size   9, iters    23, time  0.0155s
# — Seed 3 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0136, min=0.0088, max=0.0235, std=0.0044, 95% CI=(0.0090, 0.0219)
# Iters: mean=19.7, min=14, max=31, std=5.1, 95% CI=(14.0, 29.2)
#
# ================== Seed 4 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=4): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    37, time  0.0266s
# init  1 → MIS size   9, iters    25, time  0.0171s
# init  2 → MIS size   9, iters    29, time  0.0229s
# init  3 → MIS size   9, iters    21, time  0.0149s
# init  4 → MIS size   8, iters    20, time  0.0152s
# init  5 → MIS size  10, iters    12, time  0.0077s
# init  6 → MIS size   9, iters    30, time  0.0202s
# init  7 → MIS size  10, iters    19, time  0.0122s
# init  8 → MIS size  10, iters    12, time  0.0076s
# init  9 → MIS size  10, iters    16, time  0.0109s
# — Seed 4 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0155, min=0.0076, max=0.0266, std=0.0063, 95% CI=(0.0076, 0.0258)
# Iters: mean=22.1, min=12, max=37, std=8.1, 95% CI=(12.0, 35.4)
#
# ================== Seed 5 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=5): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    37, time  0.0278s
# init  1 → MIS size   8, iters    19, time  0.0152s
# init  2 → MIS size   9, iters    29, time  0.0216s
# init  3 → MIS size  10, iters    18, time  0.0123s
# init  4 → MIS size  10, iters    31, time  0.0220s
# init  5 → MIS size  10, iters    14, time  0.0099s
# init  6 → MIS size  10, iters    21, time  0.0140s
# init  7 → MIS size  10, iters    15, time  0.0101s
# init  8 → MIS size  10, iters    16, time  0.0109s
# init  9 → no MIS flagged (iters 15000, time 23.4302s)
# — Seed 5 summary —
# Best MIS size: 10 (trial 3)
# Runtime (s): mean=0.0160, min=0.0099, max=0.0278, std=0.0064, 95% CI=(0.0100, 0.0266)
# Iters: mean=22.2, min=14, max=37, std=8.1, 95% CI=(14.2, 35.8)
#
# ================== Seed 6 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=6): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    24, time  0.0187s
# init  1 → MIS size   9, iters    15, time  0.0101s
# init  2 → MIS size   9, iters    19, time  0.0126s
# init  3 → MIS size   8, iters    13, time  0.0085s
# init  4 → MIS size   9, iters    20, time  0.0142s
# init  5 → MIS size  10, iters    15, time  0.0109s
# init  6 → MIS size   9, iters    16, time  0.0108s
# init  7 → MIS size   9, iters    19, time  0.0130s
# init  8 → MIS size  10, iters    26, time  0.0190s
# init  9 → MIS size  10, iters    13, time  0.0082s
# — Seed 6 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0126, min=0.0082, max=0.0190, std=0.0038, 95% CI=(0.0082, 0.0189)
# Iters: mean=18.0, min=13, max=26, std=4.4, 95% CI=(13.0, 25.6)
#
# ================== Seed 7 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=7): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    38, time  0.0290s
# init  1 → MIS size  10, iters    27, time  0.0193s
# init  2 → MIS size  10, iters    14, time  0.0093s
# init  3 → MIS size  10, iters    18, time  0.0135s
# init  4 → MIS size  10, iters    12, time  0.0077s
# init  5 → MIS size   9, iters    15, time  0.0109s
# init  6 → MIS size   9, iters    27, time  0.0200s
# init  7 → MIS size   9, iters    29, time  0.0230s
# init  8 → MIS size  10, iters    20, time  0.0140s
# init  9 → MIS size  10, iters    14, time  0.0090s
# — Seed 7 summary —
# Best MIS size: 10 (trial 1)
# Runtime (s): mean=0.0156, min=0.0077, max=0.0290, std=0.0070, 95% CI=(0.0079, 0.0276)
# Iters: mean=21.4, min=12, max=38, std=8.5, 95% CI=(12.4, 36.0)
#
# ================== Seed 8 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=8): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    42, time  0.0311s
# init  1 → MIS size   9, iters    20, time  0.0144s
# init  2 → MIS size  11, iters    13, time  0.0081s
# init  3 → MIS size  10, iters    23, time  0.0165s
# init  4 → MIS size   9, iters    21, time  0.0152s
# init  5 → MIS size  10, iters    15, time  0.0102s
# init  6 → MIS size  11, iters    20, time  0.0157s
# init  7 → MIS size   9, iters    22, time  0.0149s
# init  8 → MIS size   9, iters    13, time  0.0089s
# init  9 → MIS size   9, iters    16, time  0.0112s
# — Seed 8 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0146, min=0.0081, max=0.0311, std=0.0065, 95% CI=(0.0083, 0.0278)
# Iters: mean=20.5, min=13, max=42, std=8.4, 95% CI=(13.0, 37.7)
#
# ================== Seed 9 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=9): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    28, time  0.0202s
# init  1 → MIS size  10, iters    19, time  0.0115s
# init  2 → MIS size   9, iters    18, time  0.0122s
# init  3 → MIS size  12, iters    14, time  0.0088s
#   it    50: MIS found, f=-7.9275
# init  4 → MIS size   8, iters    50, time  0.0373s
# init  5 → MIS size  10, iters    24, time  0.0175s
# init  6 → MIS size   9, iters    22, time  0.0172s
# init  7 → MIS size  11, iters    20, time  0.0114s
# init  8 → MIS size  10, iters    23, time  0.0172s
# init  9 → MIS size   9, iters    15, time  0.0099s
# — Seed 9 summary —
# Best MIS size: 12 (trial 3)
# Runtime (s): mean=0.0163, min=0.0088, max=0.0373, std=0.0083, 95% CI=(0.0091, 0.0335)
# Iters: mean=23.3, min=14, max=50, std=10.3, 95% CI=(14.2, 45.1)
#
# ================== Seed 10 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=10): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    33, time  0.0245s
# init  1 → MIS size   9, iters    19, time  0.0131s
# init  2 → MIS size   9, iters    17, time  0.0107s
# init  3 → MIS size   9, iters    23, time  0.0152s
# init  4 → MIS size   9, iters    20, time  0.0139s
# init  5 → MIS size   9, iters    24, time  0.0177s
# init  6 → MIS size   7, iters    15, time  0.0100s
# init  7 → MIS size  10, iters    14, time  0.0096s
# init  8 → MIS size   9, iters    31, time  0.0228s
# init  9 → MIS size   9, iters    20, time  0.0136s
# — Seed 10 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0151, min=0.0096, max=0.0245, std=0.0052, 95% CI=(0.0097, 0.0241)
# Iters: mean=21.6, min=14, max=33, std=6.3, 95% CI=(14.2, 32.5)
#
# ================== Seed 11 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=11): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    30, time  0.0223s
# init  1 → MIS size   8, iters    29, time  0.0217s
# init  2 → MIS size  10, iters    17, time  0.0119s
# init  3 → MIS size   9, iters    17, time  0.0126s
# init  4 → MIS size   9, iters    16, time  0.0106s
# init  5 → MIS size   9, iters    18, time  0.0125s
# init  6 → MIS size  10, iters    14, time  0.0102s
# init  7 → MIS size   9, iters    17, time  0.0115s
# init  8 → MIS size   9, iters    17, time  0.0127s
# init  9 → MIS size   8, iters    16, time  0.0112s
# — Seed 11 summary —
# Best MIS size: 10 (trial 2)
# Runtime (s): mean=0.0137, min=0.0102, max=0.0223, std=0.0045, 95% CI=(0.0103, 0.0222)
# Iters: mean=19.1, min=14, max=30, std=5.6, 95% CI=(14.4, 29.8)
#
# ================== Seed 12 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=12): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    25, time  0.0188s
# init  1 → MIS size  10, iters    19, time  0.0137s
# init  2 → MIS size   9, iters    22, time  0.0173s
# init  3 → MIS size   9, iters    18, time  0.0124s
# init  4 → MIS size   9, iters    16, time  0.0111s
# init  5 → MIS size   9, iters    18, time  0.0142s
# init  6 → MIS size   8, iters    21, time  0.0150s
# init  7 → MIS size  11, iters    21, time  0.0166s
# init  8 → MIS size  11, iters    14, time  0.0083s
# init  9 → MIS size  10, iters    24, time  0.0167s
# — Seed 12 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0144, min=0.0083, max=0.0188, std=0.0032, 95% CI=(0.0089, 0.0185)
# Iters: mean=19.8, min=14, max=25, std=3.5, 95% CI=(14.4, 24.8)
#
# ================== Seed 13 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=13): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    30, time  0.0225s
# init  1 → MIS size  10, iters    16, time  0.0107s
# init  2 → MIS size   9, iters    14, time  0.0102s
# init  3 → MIS size   9, iters    16, time  0.0105s
# init  4 → MIS size   9, iters    13, time  0.0084s
# init  5 → MIS size  10, iters    15, time  0.0115s
# init  6 → MIS size  10, iters    19, time  0.0122s
# init  7 → MIS size   9, iters    15, time  0.0110s
# init  8 → MIS size   9, iters    14, time  0.0080s
# init  9 → MIS size   9, iters    17, time  0.0118s
# — Seed 13 summary —
# Best MIS size: 10 (trial 1)
# Runtime (s): mean=0.0117, min=0.0080, max=0.0225, std=0.0041, 95% CI=(0.0081, 0.0202)
# Iters: mean=16.9, min=13, max=30, std=4.9, 95% CI=(13.2, 27.5)
#
# ================== Seed 14 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=14): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    30, time  0.0222s
# init  1 → MIS size   9, iters    14, time  0.0101s
# init  2 → MIS size  10, iters    17, time  0.0115s
# init  3 → MIS size  10, iters    14, time  0.0097s
# init  4 → MIS size   9, iters    18, time  0.0140s
# init  5 → MIS size  10, iters    15, time  0.0096s
# init  6 → MIS size  11, iters    25, time  0.0201s
# init  7 → MIS size   9, iters    21, time  0.0150s
# init  8 → MIS size   9, iters    18, time  0.0122s
# init  9 → MIS size  10, iters    12, time  0.0075s
# — Seed 14 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=0.0132, min=0.0075, max=0.0222, std=0.0047, 95% CI=(0.0080, 0.0217)
# Iters: mean=18.4, min=12, max=30, std=5.6, 95% CI=(12.4, 28.9)
#
# ================== Seed 15 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=15): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    30, time  0.0222s
# init  1 → MIS size   8, iters    15, time  0.0103s
# init  2 → MIS size   9, iters    22, time  0.0158s
# init  3 → MIS size   9, iters    18, time  0.0122s
# init  4 → MIS size  11, iters    17, time  0.0115s
# init  5 → MIS size   9, iters    14, time  0.0094s
# init  6 → MIS size   9, iters    18, time  0.0129s
# init  7 → MIS size  10, iters    17, time  0.0108s
# init  8 → MIS size   8, iters    24, time  0.0173s
# init  9 → MIS size  10, iters    25, time  0.0186s
# — Seed 15 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=0.0141, min=0.0094, max=0.0222, std=0.0042, 95% CI=(0.0096, 0.0214)
# Iters: mean=20.0, min=14, max=30, std=5.1, 95% CI=(14.2, 28.9)
#
# ================== Seed 16 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=16): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    27, time  0.0208s
# init  1 → MIS size  10, iters    21, time  0.0153s
# init  2 → MIS size  10, iters    18, time  0.0117s
# init  3 → MIS size  10, iters    21, time  0.0140s
# init  4 → MIS size   9, iters    15, time  0.0085s
# init  5 → MIS size   9, iters    15, time  0.0114s
# init  6 → MIS size  11, iters    14, time  0.0104s
# init  7 → MIS size  10, iters    27, time  0.0191s
# init  8 → MIS size  11, iters    18, time  0.0120s
# init  9 → MIS size   8, iters    16, time  0.0115s
# — Seed 16 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=0.0135, min=0.0085, max=0.0208, std=0.0039, 95% CI=(0.0090, 0.0204)
# Iters: mean=19.2, min=14, max=27, std=4.8, 95% CI=(14.2, 27.0)
#
# ================== Seed 17 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=17): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    27, time  0.0206s
# init  1 → MIS size   8, iters    23, time  0.0167s
# init  2 → MIS size  11, iters    14, time  0.0093s
# init  3 → MIS size  10, iters    22, time  0.0147s
# init  4 → MIS size  10, iters    15, time  0.0102s
# init  5 → MIS size  11, iters    14, time  0.0084s
# init  6 → MIS size  10, iters    16, time  0.0103s
# init  7 → MIS size  10, iters    16, time  0.0105s
# init  8 → MIS size   9, iters    17, time  0.0118s
# init  9 → MIS size   9, iters    12, time  0.0076s
# — Seed 17 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0120, min=0.0076, max=0.0206, std=0.0041, 95% CI=(0.0078, 0.0197)
# Iters: mean=17.6, min=12, max=27, std=4.8, 95% CI=(12.4, 26.1)
#
# ================== Seed 18 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=18): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    31, time  0.0226s
# init  1 → MIS size   9, iters    14, time  0.0096s
# init  2 → MIS size  11, iters    21, time  0.0153s
# init  3 → MIS size   9, iters    16, time  0.0105s
# init  4 → MIS size  10, iters    22, time  0.0147s
# init  5 → MIS size  10, iters    16, time  0.0115s
# init  6 → MIS size   8, iters    16, time  0.0103s
# init  7 → MIS size   8, iters    19, time  0.0127s
# init  8 → MIS size   9, iters    19, time  0.0135s
# init  9 → MIS size  10, iters    21, time  0.0149s
# — Seed 18 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0136, min=0.0096, max=0.0226, std=0.0038, 95% CI=(0.0098, 0.0210)
# Iters: mean=19.5, min=14, max=31, std=4.8, 95% CI=(14.4, 29.0)
#
# ================== Seed 19 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=19): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    23, time  0.0176s
# init  1 → MIS size  10, iters    10, time  0.0056s
# init  2 → MIS size   9, iters    23, time  0.0161s
# init  3 → MIS size   9, iters    15, time  0.0098s
# init  4 → MIS size   9, iters    22, time  0.0144s
# init  5 → MIS size   9, iters    28, time  0.0199s
# init  6 → MIS size  10, iters    13, time  0.0082s
# init  7 → MIS size  10, iters    28, time  0.0219s
# init  8 → MIS size  11, iters    17, time  0.0127s
# init  9 → MIS size  10, iters    21, time  0.0143s
# — Seed 19 summary —
# Best MIS size: 11 (trial 8)
# Runtime (s): mean=0.0140, min=0.0056, max=0.0219, std=0.0052, 95% CI=(0.0062, 0.0215)
# Iters: mean=20.0, min=10, max=28, std=6.1, 95% CI=(10.7, 28.0)
#
# ================== Seed 20 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=20): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    26, time  0.0188s
# init  1 → MIS size   9, iters    17, time  0.0122s
# init  2 → MIS size   8, iters    26, time  0.0174s
# init  3 → MIS size   8, iters    13, time  0.0094s
# init  4 → MIS size  11, iters    16, time  0.0108s
# init  5 → MIS size   9, iters    21, time  0.0167s
# init  6 → MIS size   9, iters    12, time  0.0081s
# init  7 → MIS size  10, iters    14, time  0.0094s
# init  8 → MIS size  11, iters    14, time  0.0085s
# init  9 → MIS size   9, iters    18, time  0.0125s
# — Seed 20 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=0.0124, min=0.0081, max=0.0188, std=0.0039, 95% CI=(0.0082, 0.0185)
# Iters: mean=17.7, min=12, max=26, std=5.1, 95% CI=(12.2, 26.0)
#
# ================== Seed 21 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=21): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    31, time  0.0230s
# init  1 → MIS size   9, iters    15, time  0.0088s
# init  2 → MIS size   9, iters    12, time  0.0086s
# init  3 → MIS size   9, iters    25, time  0.0178s
# init  4 → MIS size  10, iters    22, time  0.0148s
# init  5 → MIS size  11, iters    14, time  0.0091s
# init  6 → MIS size  10, iters    16, time  0.0111s
# init  7 → MIS size   9, iters    29, time  0.0208s
# init  8 → MIS size  10, iters    19, time  0.0134s
# init  9 → MIS size  10, iters    14, time  0.0091s
# — Seed 21 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0137, min=0.0086, max=0.0230, std=0.0053, 95% CI=(0.0086, 0.0225)
# Iters: mean=19.7, min=12, max=31, std=6.7, 95% CI=(12.4, 30.6)
#
# ================== Seed 22 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=22): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    27, time  0.0200s
# init  1 → MIS size   9, iters    17, time  0.0119s
# init  2 → MIS size  10, iters    20, time  0.0134s
# init  3 → MIS size   9, iters    22, time  0.0166s
# init  4 → MIS size  10, iters    21, time  0.0144s
# init  5 → MIS size   9, iters    16, time  0.0124s
# init  6 → MIS size   9, iters    16, time  0.0112s
# init  7 → MIS size   9, iters    10, time  0.0060s
# init  8 → MIS size  10, iters    18, time  0.0130s
# init  9 → MIS size   9, iters    23, time  0.0161s
# — Seed 22 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0135, min=0.0060, max=0.0200, std=0.0037, 95% CI=(0.0072, 0.0192)
# Iters: mean=19.0, min=10, max=27, std=4.7, 95% CI=(11.3, 26.1)
#
# ================== Seed 23 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=23): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    29, time  0.0210s
# init  1 → MIS size  11, iters    22, time  0.0155s
# init  2 → MIS size   9, iters    22, time  0.0158s
# init  3 → MIS size  11, iters    23, time  0.0170s
# init  4 → MIS size   9, iters    23, time  0.0152s
# init  5 → MIS size  10, iters     9, time  0.0061s
# init  6 → MIS size  10, iters    17, time  0.0112s
# init  7 → MIS size   8, iters    19, time  0.0135s
# init  8 → MIS size  10, iters    19, time  0.0132s
# init  9 → MIS size   9, iters    17, time  0.0116s
# — Seed 23 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0140, min=0.0061, max=0.0210, std=0.0040, 95% CI=(0.0073, 0.0201)
# Iters: mean=20.0, min=9, max=29, std=5.2, 95% CI=(10.8, 27.7)
#
# ================== Seed 24 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=24): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    29, time  0.0226s
# init  1 → MIS size  10, iters    21, time  0.0144s
# init  2 → MIS size  10, iters    16, time  0.0102s
# init  3 → MIS size  10, iters    19, time  0.0142s
# init  4 → MIS size  10, iters    18, time  0.0123s
# init  5 → MIS size   9, iters    17, time  0.0131s
# init  6 → MIS size  10, iters    17, time  0.0104s
# init  7 → MIS size   9, iters    15, time  0.0105s
# init  8 → MIS size  10, iters    12, time  0.0076s
# init  9 → MIS size  10, iters    19, time  0.0139s
# — Seed 24 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0129, min=0.0076, max=0.0226, std=0.0040, 95% CI=(0.0082, 0.0208)
# Iters: mean=18.3, min=12, max=29, std=4.5, 95% CI=(12.7, 27.2)
#
# ================== Seed 25 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=25): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    30, time  0.0232s
# init  1 → MIS size   9, iters    14, time  0.0096s
# init  2 → MIS size   8, iters    25, time  0.0191s
# init  3 → MIS size   9, iters    18, time  0.0131s
# init  4 → MIS size   9, iters    28, time  0.0218s
# init  5 → MIS size  10, iters    25, time  0.0180s
# init  6 → MIS size  11, iters    24, time  0.0159s
# init  7 → MIS size  10, iters    18, time  0.0131s
# init  8 → MIS size  10, iters    25, time  0.0169s
# init  9 → MIS size  10, iters    16, time  0.0106s
# — Seed 25 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=0.0161, min=0.0096, max=0.0232, std=0.0046, 95% CI=(0.0098, 0.0229)
# Iters: mean=22.3, min=14, max=30, std=5.4, 95% CI=(14.4, 29.6)
#
# ================== Seed 26 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=26): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    30, time  0.0220s
# init  1 → MIS size   9, iters    11, time  0.0072s
# init  2 → MIS size  10, iters    14, time  0.0090s
# init  3 → MIS size  10, iters    10, time  0.0061s
# init  4 → MIS size  10, iters    21, time  0.0145s
# init  5 → MIS size  10, iters    19, time  0.0126s
# init  6 → MIS size  10, iters    18, time  0.0134s
# init  7 → MIS size  10, iters    13, time  0.0084s
# init  8 → MIS size  10, iters    26, time  0.0178s
# init  9 → MIS size   8, iters    16, time  0.0113s
# — Seed 26 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0122, min=0.0061, max=0.0220, std=0.0050, 95% CI=(0.0064, 0.0210)
# Iters: mean=17.8, min=10, max=30, std=6.5, 95% CI=(10.2, 29.1)
#
# ================== Seed 27 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=27): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    32, time  0.0239s
# init  1 → MIS size   8, iters    10, time  0.0070s
# init  2 → MIS size  11, iters    17, time  0.0119s
# init  3 → MIS size  10, iters    20, time  0.0130s
# init  4 → MIS size   9, iters    14, time  0.0095s
# init  5 → MIS size   9, iters    19, time  0.0141s
# init  6 → MIS size  10, iters    19, time  0.0132s
# init  7 → MIS size   9, iters    22, time  0.0155s
# init  8 → MIS size   9, iters    20, time  0.0143s
# init  9 → MIS size  10, iters    27, time  0.0204s
# — Seed 27 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0143, min=0.0070, max=0.0239, std=0.0049, 95% CI=(0.0075, 0.0231)
# Iters: mean=20.0, min=10, max=32, std=6.2, 95% CI=(10.9, 30.9)
#
# ================== Seed 28 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=28): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    39, time  0.0289s
# init  1 → MIS size   9, iters    24, time  0.0176s
# init  2 → MIS size  10, iters    19, time  0.0141s
# init  3 → MIS size  11, iters    16, time  0.0096s
# init  4 → MIS size   9, iters    20, time  0.0146s
# init  5 → MIS size  11, iters    19, time  0.0130s
# init  6 → MIS size  10, iters    23, time  0.0175s
# init  7 → MIS size   9, iters    19, time  0.0132s
# init  8 → MIS size   9, iters    15, time  0.0102s
# init  9 → MIS size  10, iters    24, time  0.0172s
# — Seed 28 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0156, min=0.0096, max=0.0289, std=0.0055, 95% CI=(0.0097, 0.0263)
# Iters: mean=21.8, min=15, max=39, std=6.8, 95% CI=(15.2, 35.6)
#
# ================== Seed 29 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=29): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    31, time  0.0229s
# init  1 → MIS size   9, iters    16, time  0.0105s
# init  2 → MIS size  10, iters    19, time  0.0134s
# init  3 → MIS size   9, iters    15, time  0.0101s
# init  4 → MIS size   9, iters    24, time  0.0186s
# init  5 → MIS size  11, iters    19, time  0.0139s
# init  6 → MIS size  10, iters    20, time  0.0134s
# init  7 → MIS size   9, iters    23, time  0.0163s
# init  8 → MIS size   9, iters    26, time  0.0176s
# init  9 → MIS size  10, iters    16, time  0.0103s
# — Seed 29 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0147, min=0.0101, max=0.0229, std=0.0042, 95% CI=(0.0101, 0.0220)
# Iters: mean=20.9, min=15, max=31, std=5.1, 95% CI=(15.2, 29.9)
#
# ================== Seed 30 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=30): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    31, time  0.0243s
# init  1 → MIS size   9, iters    17, time  0.0123s
# init  2 → MIS size  11, iters    11, time  0.0071s
# init  3 → MIS size   9, iters    16, time  0.0120s
# init  4 → MIS size  10, iters    26, time  0.0180s
# init  5 → MIS size   9, iters    16, time  0.0121s
# init  6 → MIS size  10, iters    16, time  0.0106s
# init  7 → MIS size   9, iters    24, time  0.0162s
# init  8 → MIS size   8, iters    13, time  0.0097s
# init  9 → MIS size  11, iters    26, time  0.0174s
# — Seed 30 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0140, min=0.0071, max=0.0243, std=0.0050, 95% CI=(0.0077, 0.0229)
# Iters: mean=19.6, min=11, max=31, std=6.6, 95% CI=(11.4, 29.9)
#
# ================== Seed 31 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=31): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    26, time  0.0202s
# init  1 → MIS size  10, iters    11, time  0.0070s
# init  2 → MIS size  10, iters    23, time  0.0160s
# init  3 → MIS size  10, iters    22, time  0.0162s
# init  4 → MIS size   9, iters    23, time  0.0155s
# init  5 → MIS size  10, iters    11, time  0.0071s
# init  6 → MIS size   8, iters    18, time  0.0128s
# init  7 → MIS size  10, iters    19, time  0.0131s
# init  8 → MIS size  11, iters    12, time  0.0083s
# init  9 → MIS size  11, iters    20, time  0.0135s
# — Seed 31 summary —
# Best MIS size: 11 (trial 8)
# Runtime (s): mean=0.0130, min=0.0070, max=0.0202, std=0.0044, 95% CI=(0.0070, 0.0193)
# Iters: mean=18.5, min=11, max=26, std=5.4, 95% CI=(11.0, 25.3)
#
# ================== Seed 32 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=32): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    37, time  0.0280s
# init  1 → MIS size  11, iters    19, time  0.0134s
# init  2 → MIS size   9, iters    17, time  0.0118s
# init  3 → MIS size   9, iters    21, time  0.0147s
# init  4 → MIS size   9, iters    13, time  0.0082s
# init  5 → MIS size   9, iters    27, time  0.0213s
# init  6 → MIS size   9, iters    16, time  0.0112s
# init  7 → MIS size   8, iters    14, time  0.0092s
# init  8 → MIS size   9, iters    15, time  0.0108s
# init  9 → MIS size   9, iters    18, time  0.0121s
# — Seed 32 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0141, min=0.0082, max=0.0280, std=0.0061, 95% CI=(0.0085, 0.0265)
# Iters: mean=19.7, min=13, max=37, std=7.3, 95% CI=(13.2, 34.8)
#
# ================== Seed 33 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=33): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    28, time  0.0208s
# init  1 → MIS size  10, iters    20, time  0.0154s
# init  2 → MIS size  10, iters    28, time  0.0208s
# init  3 → MIS size   9, iters    19, time  0.0136s
# init  4 → MIS size  10, iters    14, time  0.0097s
# init  5 → MIS size  10, iters    23, time  0.0160s
# init  6 → MIS size   8, iters    22, time  0.0165s
# init  7 → MIS size   8, iters    18, time  0.0135s
# init  8 → MIS size   8, iters    15, time  0.0101s
# init  9 → MIS size  11, iters    19, time  0.0131s
# — Seed 33 summary —
# Best MIS size: 11 (trial 9)
# Runtime (s): mean=0.0149, min=0.0097, max=0.0208, std=0.0038, 95% CI=(0.0098, 0.0208)
# Iters: mean=20.6, min=14, max=28, std=4.8, 95% CI=(14.2, 28.0)
#
# ================== Seed 34 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=34): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    31, time  0.0228s
# init  1 → MIS size   8, iters    19, time  0.0139s
# init  2 → MIS size   8, iters    17, time  0.0118s
# init  3 → MIS size  10, iters    13, time  0.0079s
# init  4 → MIS size   9, iters    11, time  0.0067s
# init  5 → MIS size  10, iters    20, time  0.0141s
# init  6 → MIS size   9, iters    20, time  0.0159s
# init  7 → MIS size   9, iters    19, time  0.0133s
# init  8 → MIS size  11, iters    12, time  0.0075s
# init  9 → MIS size  11, iters    17, time  0.0104s
# — Seed 34 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0124, min=0.0067, max=0.0228, std=0.0048, 95% CI=(0.0069, 0.0213)
# Iters: mean=17.9, min=11, max=31, std=5.7, 95% CI=(11.2, 28.5)
#
# ================== Seed 35 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=35): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    28, time  0.0204s
# init  1 → MIS size   9, iters    17, time  0.0113s
# init  2 → MIS size  10, iters    24, time  0.0169s
# init  3 → MIS size  10, iters    23, time  0.0167s
# init  4 → MIS size   9, iters    16, time  0.0107s
# init  5 → MIS size  10, iters    20, time  0.0130s
# init  6 → MIS size   9, iters    22, time  0.0153s
# init  7 → MIS size  11, iters    14, time  0.0089s
# init  8 → MIS size  11, iters    16, time  0.0114s
# init  9 → MIS size   9, iters    14, time  0.0093s
# — Seed 35 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0134, min=0.0089, max=0.0204, std=0.0038, 95% CI=(0.0090, 0.0196)
# Iters: mean=19.4, min=14, max=28, std=4.7, 95% CI=(14.0, 27.1)
#
# ================== Seed 36 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=36): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    24, time  0.0178s
# init  1 → MIS size   9, iters    18, time  0.0134s
# init  2 → MIS size  10, iters    30, time  0.0222s
# init  3 → MIS size   9, iters    19, time  0.0165s
# init  4 → MIS size  10, iters    18, time  0.0124s
# init  5 → MIS size  11, iters    24, time  0.0196s
# init  6 → MIS size   8, iters    17, time  0.0123s
# init  7 → MIS size   9, iters    19, time  0.0126s
# init  8 → MIS size  10, iters    25, time  0.0177s
# init  9 → MIS size   9, iters    23, time  0.0173s
# — Seed 36 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0162, min=0.0123, max=0.0222, std=0.0034, 95% CI=(0.0123, 0.0217)
# Iters: mean=21.7, min=17, max=30, std=4.2, 95% CI=(17.2, 28.9)
#
# ================== Seed 37 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=37): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    33, time  0.0237s
# init  1 → MIS size  10, iters    21, time  0.0156s
# init  2 → MIS size  10, iters    18, time  0.0123s
# init  3 → MIS size  10, iters    20, time  0.0137s
# init  4 → MIS size  10, iters    16, time  0.0109s
# init  5 → MIS size  10, iters    18, time  0.0131s
# init  6 → MIS size   9, iters    25, time  0.0169s
# init  7 → MIS size  10, iters    17, time  0.0116s
# init  8 → MIS size   9, iters    15, time  0.0104s
# init  9 → MIS size  11, iters    25, time  0.0182s
# — Seed 37 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0146, min=0.0104, max=0.0237, std=0.0041, 95% CI=(0.0105, 0.0225)
# Iters: mean=20.8, min=15, max=33, std=5.5, 95% CI=(15.2, 31.2)
#
# ================== Seed 38 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=38): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    21, time  0.0163s
# init  1 → MIS size   9, iters    17, time  0.0150s
# init  2 → MIS size  10, iters    17, time  0.0120s
# init  3 → MIS size  10, iters    22, time  0.0141s
# init  4 → MIS size   9, iters    29, time  0.0205s
# init  5 → MIS size  10, iters    28, time  0.0193s
# init  6 → MIS size  10, iters    22, time  0.0162s
# init  7 → MIS size  10, iters    14, time  0.0091s
# init  8 → MIS size  11, iters    17, time  0.0124s
# init  9 → MIS size   9, iters    19, time  0.0138s
# — Seed 38 summary —
# Best MIS size: 11 (trial 8)
# Runtime (s): mean=0.0149, min=0.0091, max=0.0205, std=0.0034, 95% CI=(0.0097, 0.0203)
# Iters: mean=20.6, min=14, max=29, std=4.9, 95% CI=(14.7, 28.8)
#
# ================== Seed 39 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=39): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    34, time  0.0261s
# init  1 → MIS size   9, iters    24, time  0.0180s
# init  2 → MIS size  10, iters    33, time  0.0249s
# init  3 → MIS size  10, iters    17, time  0.0108s
# init  4 → MIS size  11, iters    21, time  0.0164s
# init  5 → MIS size  11, iters    13, time  0.0080s
# init  6 → MIS size  10, iters    21, time  0.0156s
# init  7 → MIS size   9, iters    23, time  0.0158s
# init  8 → MIS size  10, iters    15, time  0.0100s
# init  9 → MIS size  10, iters    13, time  0.0083s
# — Seed 39 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=0.0154, min=0.0080, max=0.0261, std=0.0064, 95% CI=(0.0080, 0.0259)
# Iters: mean=21.4, min=13, max=34, std=7.5, 95% CI=(13.0, 33.8)
#
# ================== Seed 40 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=40): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size   9, iters    32, time  0.0246s
# init  1 → MIS size   9, iters    12, time  0.0077s
# init  2 → MIS size   9, iters    21, time  0.0153s
# init  3 → MIS size  11, iters    24, time  0.0169s
# init  4 → MIS size  10, iters    13, time  0.0084s
# init  5 → MIS size   8, iters    19, time  0.0136s
# init  6 → MIS size  10, iters    21, time  0.0152s
# init  7 → MIS size   9, iters    22, time  0.0148s
# init  8 → MIS size   8, iters    18, time  0.0138s
# init  9 → MIS size  10, iters    21, time  0.0147s
# — Seed 40 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0145, min=0.0077, max=0.0246, std=0.0046, 95% CI=(0.0078, 0.0229)
# Iters: mean=20.3, min=12, max=32, std=5.6, 95% CI=(12.2, 30.2)
#
# ================== Seed 41 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=41): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    26, time  0.0195s
# init  1 → MIS size   9, iters    13, time  0.0090s
# init  2 → MIS size  10, iters    17, time  0.0122s
# init  3 → MIS size  11, iters    20, time  0.0141s
# init  4 → MIS size  12, iters    17, time  0.0094s
# init  5 → MIS size   8, iters    27, time  0.0210s
# init  6 → MIS size  10, iters    17, time  0.0122s
# init  7 → MIS size   9, iters    21, time  0.0140s
# init  8 → MIS size  11, iters    19, time  0.0126s
# init  9 → MIS size  10, iters    20, time  0.0144s
# — Seed 41 summary —
# Best MIS size: 12 (trial 4)
# Runtime (s): mean=0.0138, min=0.0090, max=0.0210, std=0.0038, 95% CI=(0.0091, 0.0206)
# Iters: mean=19.7, min=13, max=27, std=4.2, 95% CI=(13.9, 26.8)
#
# ================== Seed 42 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=42): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    32, time  0.0244s
# init  1 → MIS size   9, iters    28, time  0.0199s
# init  2 → MIS size   9, iters    15, time  0.0096s
# init  3 → MIS size   9, iters    12, time  0.0079s
# init  4 → MIS size   9, iters    10, time  0.0066s
# init  5 → MIS size  11, iters    21, time  0.0156s
# init  6 → MIS size   9, iters    20, time  0.0140s
# init  7 → MIS size  10, iters    23, time  0.0176s
# init  8 → MIS size   9, iters    12, time  0.0075s
# init  9 → MIS size   8, iters    20, time  0.0141s
# — Seed 42 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0137, min=0.0066, max=0.0244, std=0.0059, 95% CI=(0.0068, 0.0233)
# Iters: mean=19.3, min=10, max=32, std=7.2, 95% CI=(10.4, 31.1)
#
# ================== Seed 43 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=43): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    31, time  0.0229s
# init  1 → MIS size  10, iters    12, time  0.0066s
# init  2 → MIS size  10, iters    25, time  0.0182s
#   it  1650: MIS found, f=-9.0000
# init  3 → MIS size   9, iters  1650, time  0.6301s
# init  4 → MIS size   9, iters    21, time  0.0145s
# init  5 → MIS size  10, iters    12, time  0.0073s
# init  6 → MIS size   9, iters    24, time  0.0168s
# init  7 → MIS size   9, iters    29, time  0.0221s
# init  8 → MIS size   9, iters    16, time  0.0112s
# init  9 → MIS size  11, iters    13, time  0.0084s
# — Seed 43 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0758, min=0.0066, max=0.6301, std=0.1948, 95% CI=(0.0068, 0.4935)
# Iters: mean=183.3, min=12, max=1650, std=515.4, 95% CI=(12.0, 1285.7)
#
# ================== Seed 44 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=44): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    39, time  0.0258s
# init  1 → MIS size   9, iters    14, time  0.0094s
# init  2 → MIS size  10, iters    14, time  0.0091s
# init  3 → MIS size   9, iters    17, time  0.0105s
# init  4 → MIS size  10, iters    25, time  0.0178s
# init  5 → MIS size   9, iters    16, time  0.0154s
# init  6 → MIS size  10, iters    22, time  0.0154s
# init  7 → MIS size  10, iters    16, time  0.0104s
# init  8 → MIS size  10, iters    20, time  0.0131s
# init  9 → MIS size   9, iters    21, time  0.0163s
# — Seed 44 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0143, min=0.0091, max=0.0258, std=0.0051, 95% CI=(0.0092, 0.0240)
# Iters: mean=20.4, min=14, max=39, std=7.5, 95% CI=(14.0, 35.9)
#
# ================== Seed 45 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=45): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    40, time  0.0305s
# init  1 → MIS size   9, iters    22, time  0.0160s
# init  2 → MIS size   9, iters    14, time  0.0094s
# init  3 → MIS size   9, iters    15, time  0.0102s
# init  4 → MIS size  10, iters    15, time  0.0100s
# init  5 → MIS size   9, iters    19, time  0.0144s
# init  6 → MIS size   8, iters    12, time  0.0078s
# init  7 → MIS size  10, iters    26, time  0.0190s
# init  8 → MIS size   8, iters    21, time  0.0148s
# init  9 → MIS size   8, iters    23, time  0.0163s
# — Seed 45 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0148, min=0.0078, max=0.0305, std=0.0066, 95% CI=(0.0082, 0.0279)
# Iters: mean=20.7, min=12, max=40, std=8.1, 95% CI=(12.4, 36.9)
#
# ================== Seed 46 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=46): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  11, iters    32, time  0.0233s
# init  1 → MIS size  10, iters    19, time  0.0130s
# init  2 → MIS size  10, iters    21, time  0.0146s
# init  3 → MIS size   9, iters    24, time  0.0172s
# init  4 → MIS size   9, iters    20, time  0.0179s
# init  5 → MIS size  10, iters    18, time  0.0131s
# init  6 → MIS size   9, iters    22, time  0.0178s
# init  7 → MIS size   9, iters    18, time  0.0123s
# init  8 → MIS size   9, iters    19, time  0.0127s
# init  9 → MIS size  10, iters    17, time  0.0111s
# — Seed 46 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0153, min=0.0111, max=0.0233, std=0.0037, 95% CI=(0.0114, 0.0221)
# Iters: mean=21.0, min=17, max=32, std=4.4, 95% CI=(17.2, 30.2)
#
# ================== Seed 47 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=47): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  12, iters    26, time  0.0191s
# init  1 → MIS size   9, iters    11, time  0.0071s
# init  2 → MIS size  10, iters    13, time  0.0081s
# init  3 → MIS size  10, iters    30, time  0.0227s
# init  4 → MIS size  10, iters    19, time  0.0145s
# init  5 → MIS size   9, iters    17, time  0.0128s
# init  6 → MIS size  10, iters    14, time  0.0087s
# init  7 → MIS size   9, iters    14, time  0.0091s
# init  8 → MIS size  11, iters    12, time  0.0077s
# init  9 → MIS size   8, iters    25, time  0.0190s
# — Seed 47 summary —
# Best MIS size: 12 (trial 0)
# Runtime (s): mean=0.0129, min=0.0071, max=0.0227, std=0.0057, 95% CI=(0.0072, 0.0219)
# Iters: mean=18.1, min=11, max=30, std=6.7, 95% CI=(11.2, 29.1)
#
# ================== Seed 48 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=48): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    30, time  0.0225s
# init  1 → MIS size   9, iters    15, time  0.0110s
# init  2 → MIS size   9, iters    22, time  0.0163s
# init  3 → MIS size  10, iters    11, time  0.0076s
# init  4 → MIS size   9, iters    15, time  0.0107s
# init  5 → MIS size  10, iters    19, time  0.0130s
# init  6 → MIS size   9, iters    15, time  0.0105s
# init  7 → MIS size  10, iters    12, time  0.0066s
# init  8 → MIS size   9, iters    17, time  0.0114s
# init  9 → MIS size  10, iters    13, time  0.0089s
# — Seed 48 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0118, min=0.0066, max=0.0225, std=0.0046, 95% CI=(0.0068, 0.0211)
# Iters: mean=16.9, min=11, max=30, std=5.6, 95% CI=(11.2, 28.2)
#
# ================== Seed 49 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=49): Handcrafted projected L-BFGS-B (free-set) with MIS-check
# init  0 → MIS size  10, iters    22, time  0.0160s
# init  1 → MIS size  11, iters    23, time  0.0164s
# init  2 → MIS size   8, iters    15, time  0.0099s
# init  3 → MIS size  11, iters    16, time  0.0115s
# init  4 → MIS size  10, iters    19, time  0.0135s
# init  5 → MIS size  10, iters    24, time  0.0175s
# init  6 → MIS size   9, iters    31, time  0.0234s
# init  7 → MIS size  10, iters    14, time  0.0094s
# init  8 → MIS size   9, iters    14, time  0.0097s
# init  9 → MIS size   9, iters    22, time  0.0153s
# — Seed 49 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0143, min=0.0094, max=0.0234, std=0.0044, 95% CI=(0.0095, 0.0221)
# Iters: mean=20.0, min=14, max=31, std=5.5, 95% CI=(14.0, 29.4)
#
# =========== Across-seeds summary (best per seed) ===========
# Seeds with MIS: 50/50
# Best MIS size: max=12, min=10, mean=10.80, std=0.53

# %%
import torch
import networkx as nx
import numpy as np
from scipy.optimize import minimize
import time

# ===== your existing helper stays the same =====
class EarlyExit(Exception):
    pass

def MIS_checker_efficient_3(X_torch, adjacency_matrix_tensor, adjacency_matrix_tensor_comp):
    n_local = X_torch.shape[0]
    X_torch_binarized = X_torch.bool().float()
    X_torch_binarized_update = X_torch_binarized - 0.1*(-torch.ones(n_local) + (n_local*adjacency_matrix_tensor)@X_torch_binarized)
    X_torch_binarized_update = torch.clamp(X_torch_binarized_update, 0, 1)
    if torch.equal(X_torch_binarized, X_torch_binarized_update):
        MIS = torch.nonzero(X_torch_binarized).squeeze()
        return True, MIS
    return False, None

# ===== experiment settings (same as yours) =====
n = 500
p = 0.5
gamma_c = 1
beta = 0.8
alpha = 0.0001
ITERATION_T = 15000
NUM_TRIALS = 10
SEEDS = range(50)   # <- run 50 seeds

# for across-seed summary
best_size_per_seed = []
best_trial_per_seed = []
mean_runtime_per_seed = []
mean_iters_per_seed = []

for seed in SEEDS:
    # ---- build graph for this seed ----
    G = nx.gnp_random_graph(n, p, seed=seed)
    complement_G = nx.complement(G)

    num_components = nx.number_connected_components(G)
    print(f"\n================== Seed {seed} ==================")
    print("Number of connected components:", num_components)

    A = nx.adjacency_matrix(G)
    A_dense = A.todense()
    A_t = torch.tensor(A_dense, dtype=torch.float32)

    Acomp = nx.adjacency_matrix(complement_G)
    Acomp_dense = Acomp.todense()
    Acomp_t = torch.tensor(Acomp_dense, dtype=torch.float32)

    # gamma depends on complement degree
    degrees_c = dict(complement_G.degree())
    max_degree = max(degrees_c.values())
    gamma = 2 + max_degree

    # degree-based init d
    degrees = dict(G.degree())
    max_degree_node = max(degrees.values())
    d = torch.zeros(n)
    for node, degree in G.degree():
        d[node] = 1 - (degree / max_degree_node)
    d = d / d.max()

    # H and smooth objective/grad for SciPy
    H_np = (gamma * A_t - gamma_c * Acomp_t).numpy()
    # H_np = (gamma * A_t).numpy()

    def f_np(x):
        return -np.sum(x) + 0.5 * x.dot(H_np.dot(x))

    def grad_np(x):
        return -np.ones_like(x) + H_np.dot(x)

    bounds = [(0.0, 1.0)] * n

    # per-seed collectors
    MIS_size, Iter_NO, Run_time = [], [], []

    # same exploration noise as before
    exploration_parameter_eta = 2.0
    covariance_matrix = exploration_parameter_eta * torch.eye(len(d))

    print(f"ER({n}, {p}, seed={seed}): L-BFGS-B with MIS-check early exit")
    for init in range(NUM_TRIALS):
        if init == 0:
            x0_np = d.numpy()
        else:
            # make noise depend on (seed, init) so different seeds explore differently
            torch.manual_seed((seed << 16) + init)
            noise = torch.normal(mean=d, std=torch.sqrt(torch.diag(covariance_matrix)))
            x0_np = noise.numpy()

        iter_counter = {"count": 0}
        last_x = {"xk": None}

        def lbfgs_callback(xk):
            iter_counter["count"] += 1
            last_x["xk"] = xk.copy()
            x_t = torch.tensor(xk, dtype=torch.float32)
            checker, mis = MIS_checker_efficient_3(x_t, A_t, Acomp_t)
            if checker:
                raise EarlyExit()

        start_time = time.time()
        try:
            res = minimize(
                fun      = f_np,
                x0       = x0_np,
                method   = "L-BFGS-B",
                jac      = grad_np,
                bounds   = bounds,
                callback = lbfgs_callback,
                options  = {
                    "maxiter": ITERATION_T,
                    "gtol":    0.0,
                    "ftol":    0.0,
                    # "maxcor": 20,  # optional
                }
            )
            total_iters = res.nit
            x_final_np = res.x
        except EarlyExit:
            total_iters = iter_counter["count"]
            x_final_np = last_x["xk"]

        x_final = torch.tensor(x_final_np, dtype=torch.float32)
        checker, mis = MIS_checker_efficient_3(x_final, A_t, Acomp_t)

        elapsed = time.time() - start_time

        if mis is not None:
            print(f"init {init:2d} → MIS size {len(mis):3d}, iters {total_iters:5d}, time {elapsed:7.4f}s")
            MIS_size.append(len(mis))
            Iter_NO.append(total_iters)
            Run_time.append(elapsed)
        else:
            print(f"init {init:2d} → no MIS flagged by checker (iters {total_iters}, time {elapsed:7.4f}s)")

    # per-seed summary (printed before moving to next seed)
    if MIS_size:
        mis_sizes   = np.array(MIS_size)
        runtimes    = np.array(Run_time)
        iter_counts = np.array(Iter_NO)

        best_size = mis_sizes.max()
        best_run  = mis_sizes.argmax()
        mean_rt   = runtimes.mean()
        mean_it   = iter_counts.mean()

        p2_5_rt, p97_5_rt = np.percentile(runtimes, [2.5, 97.5])
        p2_5_it, p97_5_it = np.percentile(iter_counts, [2.5, 97.5])

        print(f"— Seed {seed} summary —")
        print(f"Best MIS size: {best_size} (trial {best_run})")
        print(f"Runtime (s): mean={mean_rt:.4f}, min={runtimes.min():.4f}, max={runtimes.max():.4f}, "
              f"std={runtimes.std(ddof=1):.4f}, 95% CI=({p2_5_rt:.4f}, {p97_5_rt:.4f})")
        print(f"Iters: mean={mean_it:.1f}, min={iter_counts.min()}, max={iter_counts.max()}, "
              f"std={iter_counts.std(ddof=1):.1f}, 95% CI=({p2_5_it:.1f}, {p97_5_it:.1f})")

        # store minimal across-seed info
        best_size_per_seed.append(best_size)
        best_trial_per_seed.append(int(best_run))
        mean_runtime_per_seed.append(float(mean_rt))
        mean_iters_per_seed.append(float(mean_it))
    else:
        print(f"— Seed {seed} summary — no MIS flagged by checker.")
        best_size_per_seed.append(None)
        best_trial_per_seed.append(None)
        mean_runtime_per_seed.append(None)
        mean_iters_per_seed.append(None)

# optional: across-seeds summary
vals = [v for v in best_size_per_seed if v is not None]
if vals:
    vals = np.array(vals)
    print("\n=========== Across-seeds summary (best per seed) ===========")
    print(f"Seeds with MIS: {len(vals)}/{len(SEEDS)}")
    print(f"Best MIS size: max={vals.max()}, min={vals.min()}, mean={vals.mean():.2f}, std={vals.std(ddof=1):.2f}")
# Out:
# ================== Seed 0 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=0): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   149, time  2.3073s
# init  1 → MIS size  10, iters   136, time  1.8556s
# init  2 → MIS size  11, iters   135, time  1.8633s
# init  3 → MIS size  10, iters   172, time  2.3247s
# init  4 → MIS size   9, iters   184, time  2.4829s
# init  5 → MIS size  12, iters   133, time  1.7853s
# init  6 → MIS size  10, iters   161, time  2.1605s
# init  7 → MIS size   9, iters   142, time  1.9173s
# init  8 → MIS size   9, iters   180, time  2.4085s
# init  9 → MIS size  13, iters   194, time  2.6212s
# — Seed 0 summary —
# Best MIS size: 13 (trial 9)
# Runtime (s): mean=2.1727, min=1.7853, max=2.6212, std=0.2992, 95% CI=(1.8011, 2.5901)
# Iters: mean=158.6, min=133, max=194, std=22.7, 95% CI=(133.4, 191.8)
#
# ================== Seed 1 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=1): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   162, time  2.1729s
# init  1 → MIS size   9, iters   167, time  2.2940s
# init  2 → MIS size  10, iters   155, time  2.1010s
# init  3 → MIS size  11, iters   113, time  1.5446s
# init  4 → no MIS flagged by checker (iters 173, time  2.3309s)
# init  5 → MIS size  11, iters   159, time  2.1540s
# init  6 → MIS size   9, iters   139, time  1.8643s
# init  7 → MIS size  10, iters   194, time  2.6224s
# init  8 → MIS size  11, iters   210, time  2.8754s
# init  9 → MIS size  10, iters   268, time  3.7588s
# — Seed 1 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=2.3764, min=1.5446, max=3.7588, std=0.6469, 95% CI=(1.6085, 3.5821)
# Iters: mean=174.1, min=113, max=268, std=45.1, 95% CI=(118.2, 256.4)
#
# ================== Seed 2 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=2): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   159, time  2.1705s
# init  1 → MIS size  10, iters   159, time  2.2042s
# init  2 → MIS size  10, iters   133, time  1.8188s
# init  3 → MIS size  10, iters   162, time  2.5057s
# init  4 → MIS size  10, iters   128, time  1.7396s
# init  5 → MIS size  10, iters   185, time  2.6863s
# init  6 → MIS size  11, iters   151, time  2.0386s
# init  7 → MIS size   8, iters   158, time  2.1629s
# init  8 → MIS size  11, iters   137, time  1.8500s
# init  9 → MIS size  11, iters   139, time  1.9147s
# — Seed 2 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.1091, min=1.7396, max=2.6863, std=0.3049, 95% CI=(1.7574, 2.6457)
# Iters: mean=151.1, min=128, max=185, std=17.1, 95% CI=(129.1, 179.8)
#
# ================== Seed 3 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=3): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   162, time  2.1464s
# init  1 → MIS size  10, iters   195, time  2.7191s
# init  2 → MIS size   9, iters   157, time  2.1130s
# init  3 → MIS size  10, iters   122, time  1.6746s
# init  4 → MIS size   9, iters   140, time  1.8974s
# init  5 → MIS size  10, iters   135, time  1.8833s
# init  6 → MIS size   9, iters   157, time  2.1642s
# init  7 → MIS size   9, iters   134, time  1.8065s
# init  8 → MIS size  10, iters   164, time  2.2302s
# init  9 → MIS size  11, iters   203, time  2.7535s
# — Seed 3 summary —
# Best MIS size: 11 (trial 9)
# Runtime (s): mean=2.1388, min=1.6746, max=2.7535, std=0.3612, 95% CI=(1.7043, 2.7458)
# Iters: mean=156.9, min=122, max=203, std=26.2, 95% CI=(124.7, 201.2)
#
# ================== Seed 4 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=4): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   143, time  1.9133s
# init  1 → MIS size   9, iters    82, time  1.1114s
# init  2 → MIS size  11, iters   143, time  1.9527s
# init  3 → MIS size  10, iters   201, time  2.7360s
# init  4 → MIS size  11, iters   193, time  2.6202s
# init  5 → MIS size  11, iters   134, time  1.8181s
# init  6 → MIS size  11, iters   125, time  1.6850s
# init  7 → MIS size   9, iters   106, time  1.4479s
# init  8 → MIS size  10, iters   154, time  2.1189s
# init  9 → MIS size  10, iters   277, time  3.8341s
# — Seed 4 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=2.1238, min=1.1114, max=3.8341, std=0.7737, 95% CI=(1.1872, 3.5870)
# Iters: mean=155.8, min=82, max=277, std=55.6, 95% CI=(87.4, 259.9)
#
# ================== Seed 5 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=5): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   174, time  2.3259s
# init  1 → MIS size  10, iters   143, time  1.9308s
# init  2 → MIS size  10, iters   158, time  2.1381s
# init  3 → MIS size  10, iters   176, time  2.4071s
# init  4 → MIS size  10, iters   190, time  2.7488s
# init  5 → MIS size  10, iters   194, time  2.9539s
# init  6 → MIS size  10, iters   160, time  2.1664s
# init  7 → MIS size  11, iters   156, time  2.1268s
# init  8 → MIS size   9, iters   191, time  2.6034s
# init  9 → MIS size   9, iters   159, time  2.1440s
# — Seed 5 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=2.3545, min=1.9308, max=2.9539, std=0.3229, 95% CI=(1.9749, 2.9077)
# Iters: mean=170.1, min=143, max=194, std=17.5, 95% CI=(145.9, 193.3)
#
# ================== Seed 6 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=6): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   167, time  2.2298s
# init  1 → MIS size  11, iters   115, time  1.5589s
# init  2 → MIS size  10, iters   164, time  2.2167s
# init  3 → MIS size  10, iters   159, time  2.1541s
# init  4 → MIS size  11, iters   275, time  3.7995s
# init  5 → MIS size  11, iters   184, time  2.4972s
# init  6 → MIS size   9, iters   128, time  1.7386s
# init  7 → MIS size  10, iters   207, time  2.8079s
# init  8 → MIS size   9, iters   159, time  2.1588s
# init  9 → MIS size   9, iters   134, time  1.8076s
# — Seed 6 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.2969, min=1.5589, max=3.7995, std=0.6416, 95% CI=(1.5993, 3.5764)
# Iters: mean=169.2, min=115, max=275, std=45.9, 95% CI=(117.9, 259.7)
#
# ================== Seed 7 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=7): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   152, time  2.0131s
# init  1 → MIS size  10, iters   175, time  2.3629s
# init  2 → MIS size   9, iters   188, time  2.5381s
# init  3 → MIS size  10, iters   141, time  1.9268s
# init  4 → MIS size  11, iters   157, time  2.1194s
# init  5 → MIS size  11, iters   137, time  1.8495s
# init  6 → MIS size  11, iters   200, time  2.7069s
# init  7 → MIS size   9, iters   138, time  1.8755s
# init  8 → MIS size  10, iters   177, time  2.3702s
# init  9 → MIS size  10, iters   107, time  1.4695s
# — Seed 7 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=2.1232, min=1.4695, max=2.7069, std=0.3720, 95% CI=(1.5550, 2.6689)
# Iters: mean=157.2, min=107, max=200, std=28.0, 95% CI=(113.8, 197.3)
#
# ================== Seed 8 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=8): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  12, iters   156, time  2.0759s
# init  1 → MIS size   9, iters   206, time  2.7947s
# init  2 → MIS size  11, iters   161, time  2.1925s
# init  3 → MIS size  10, iters   139, time  1.8823s
# init  4 → MIS size   9, iters   138, time  1.8672s
# init  5 → MIS size   9, iters   127, time  1.7187s
# init  6 → MIS size  10, iters   139, time  1.8733s
# init  7 → MIS size  10, iters   166, time  2.2408s
# init  8 → MIS size  13, iters   134, time  1.8051s
# init  9 → MIS size  11, iters   126, time  1.7185s
# — Seed 8 summary —
# Best MIS size: 13 (trial 8)
# Runtime (s): mean=2.0169, min=1.7185, max=2.7947, std=0.3289, 95% CI=(1.7185, 2.6701)
# Iters: mean=149.2, min=126, max=206, std=24.2, 95% CI=(126.2, 197.0)
#
# ================== Seed 9 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=9): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   189, time  2.5205s
# init  1 → MIS size   9, iters   181, time  2.4545s
# init  2 → MIS size   9, iters   235, time  3.1915s
# init  3 → MIS size   9, iters   164, time  2.2060s
# init  4 → MIS size   9, iters   146, time  1.9777s
# init  5 → MIS size   9, iters   145, time  1.9461s
# init  6 → MIS size   9, iters   149, time  2.0143s
# init  7 → MIS size  11, iters   179, time  2.4219s
# init  8 → MIS size   9, iters   171, time  2.2987s
# init  9 → MIS size  10, iters   124, time  1.6780s
# — Seed 9 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=2.2709, min=1.6780, max=3.1915, std=0.4190, 95% CI=(1.7383, 3.0405)
# Iters: mean=168.3, min=124, max=235, std=30.8, 95% CI=(128.7, 224.7)
#
# ================== Seed 10 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=10): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  12, iters   157, time  2.0956s
# init  1 → MIS size  11, iters   160, time  2.1525s
# init  2 → MIS size   9, iters   233, time  3.1391s
# init  3 → MIS size  10, iters   160, time  2.1524s
# init  4 → MIS size  10, iters   207, time  2.8130s
# init  5 → MIS size  10, iters   111, time  1.5000s
# init  6 → MIS size  10, iters   171, time  2.3060s
# init  7 → MIS size  12, iters   137, time  1.8423s
# init  8 → MIS size  10, iters   174, time  2.3539s
# init  9 → MIS size  11, iters   199, time  2.7441s
# — Seed 10 summary —
# Best MIS size: 12 (trial 0)
# Runtime (s): mean=2.3099, min=1.5000, max=3.1391, std=0.4832, 95% CI=(1.5770, 3.0657)
# Iters: mean=170.9, min=111, max=233, std=35.2, 95% CI=(116.8, 227.2)
#
# ================== Seed 11 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=11): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   151, time  2.0178s
# init  1 → MIS size   9, iters   140, time  1.8919s
# init  2 → MIS size   9, iters   167, time  2.2611s
# init  3 → MIS size   9, iters   168, time  2.2842s
# init  4 → MIS size   9, iters   191, time  2.5794s
# init  5 → MIS size  11, iters   247, time  3.3391s
# init  6 → MIS size  10, iters   173, time  2.4257s
# init  7 → MIS size  10, iters   189, time  2.5746s
# init  8 → MIS size  10, iters   149, time  2.0301s
# init  9 → MIS size  10, iters   171, time  2.3440s
# — Seed 11 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.3748, min=1.8919, max=3.3391, std=0.4104, 95% CI=(1.9203, 3.1682)
# Iters: mean=174.6, min=140, max=247, std=30.3, 95% CI=(142.0, 234.4)
#
# ================== Seed 12 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=12): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   160, time  2.1426s
# init  1 → MIS size   8, iters   149, time  2.0077s
# init  2 → MIS size  11, iters   108, time  1.4651s
# init  3 → MIS size   9, iters   160, time  2.1562s
# init  4 → MIS size  10, iters   197, time  2.7045s
# init  5 → MIS size   9, iters   229, time  3.1182s
# init  6 → MIS size   9, iters   202, time  2.7399s
# init  7 → MIS size  11, iters   141, time  1.9001s
# init  8 → MIS size  11, iters   193, time  2.6326s
# init  9 → MIS size  11, iters   150, time  2.0536s
# — Seed 12 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.2920, min=1.4651, max=3.1182, std=0.4927, 95% CI=(1.5630, 3.0330)
# Iters: mean=168.9, min=108, max=229, std=35.7, 95% CI=(115.4, 222.9)
#
# ================== Seed 13 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=13): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   167, time  2.2145s
# init  1 → MIS size  10, iters   178, time  2.3992s
# init  2 → MIS size  11, iters   144, time  1.9383s
# init  3 → MIS size   9, iters   230, time  3.1767s
# init  4 → MIS size  12, iters   133, time  1.7986s
# init  5 → MIS size  10, iters   129, time  1.7684s
# init  6 → MIS size  10, iters   140, time  1.9040s
# init  7 → MIS size  10, iters   224, time  3.2845s
# init  8 → MIS size   9, iters   149, time  2.0174s
# init  9 → MIS size  10, iters   127, time  1.7150s
# — Seed 13 summary —
# Best MIS size: 12 (trial 4)
# Runtime (s): mean=2.2217, min=1.7150, max=3.2845, std=0.5713, 95% CI=(1.7270, 3.2603)
# Iters: mean=162.1, min=127, max=230, std=37.8, 95% CI=(127.5, 228.7)
#
# ================== Seed 14 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=14): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   144, time  1.9207s
# init  1 → MIS size   9, iters    91, time  1.2311s
# init  2 → MIS size   9, iters   163, time  2.2046s
# init  3 → MIS size  12, iters   160, time  2.1763s
# init  4 → MIS size  10, iters   137, time  1.8785s
# init  5 → MIS size  12, iters   206, time  2.7756s
# init  6 → MIS size  10, iters   152, time  2.0555s
# init  7 → MIS size  11, iters   165, time  2.2282s
# init  8 → MIS size   9, iters   174, time  2.3489s
# init  9 → MIS size   9, iters   138, time  1.8881s
# — Seed 14 summary —
# Best MIS size: 12 (trial 3)
# Runtime (s): mean=2.0708, min=1.2311, max=2.7756, std=0.3980, 95% CI=(1.3768, 2.6796)
# Iters: mean=153.0, min=91, max=206, std=29.7, 95% CI=(101.3, 198.8)
#
# ================== Seed 15 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=15): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   162, time  2.1594s
# init  1 → MIS size  10, iters   168, time  2.2681s
# init  2 → MIS size  10, iters   135, time  1.8079s
# init  3 → MIS size  10, iters   244, time  3.3017s
# init  4 → MIS size  10, iters   136, time  1.8370s
# init  5 → MIS size  10, iters   209, time  2.8031s
# init  6 → MIS size  11, iters   146, time  1.9583s
# init  7 → MIS size  11, iters   144, time  1.9471s
# init  8 → MIS size   9, iters   151, time  2.0321s
# init  9 → MIS size  10, iters   203, time  2.7816s
# — Seed 15 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=2.2896, min=1.8079, max=3.3017, std=0.5031, 95% CI=(1.8145, 3.1895)
# Iters: mean=169.8, min=135, max=244, std=36.7, 95% CI=(135.2, 236.1)
#
# ================== Seed 16 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=16): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   191, time  2.5571s
# init  1 → MIS size  11, iters   150, time  2.0391s
# init  2 → MIS size  10, iters   210, time  2.8446s
# init  3 → MIS size  10, iters   156, time  2.1160s
# init  4 → MIS size  10, iters   137, time  1.8607s
# init  5 → MIS size   9, iters   153, time  2.0724s
# init  6 → MIS size  10, iters   115, time  1.5603s
# init  7 → MIS size  10, iters   146, time  1.9745s
# init  8 → MIS size  11, iters   122, time  1.6500s
# init  9 → MIS size   9, iters   194, time  2.6231s
# — Seed 16 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.1298, min=1.5603, max=2.8446, std=0.4216, 95% CI=(1.5805, 2.7948)
# Iters: mean=157.4, min=115, max=210, std=31.5, 95% CI=(116.6, 206.4)
#
# ================== Seed 17 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=17): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   150, time  2.0049s
# init  1 → MIS size  10, iters   184, time  2.4760s
# init  2 → MIS size  10, iters   222, time  3.0135s
# init  3 → MIS size   9, iters   236, time  3.2130s
# init  4 → MIS size  10, iters   165, time  2.2267s
# init  5 → MIS size   9, iters   191, time  2.5634s
# init  6 → MIS size  11, iters   158, time  2.1292s
# init  7 → MIS size   9, iters   139, time  1.8624s
# init  8 → MIS size  12, iters   141, time  1.9118s
# init  9 → MIS size  10, iters   145, time  1.9582s
# — Seed 17 summary —
# Best MIS size: 12 (trial 8)
# Runtime (s): mean=2.3359, min=1.8624, max=3.2130, std=0.4727, 95% CI=(1.8735, 3.1682)
# Iters: mean=173.1, min=139, max=236, std=34.3, 95% CI=(139.4, 232.8)
#
# ================== Seed 18 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=18): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   155, time  2.0688s
# init  1 → MIS size   9, iters   110, time  1.4798s
# init  2 → MIS size   9, iters   159, time  2.1582s
# init  3 → MIS size  11, iters   183, time  2.4744s
# init  4 → MIS size  10, iters   177, time  2.3822s
# init  5 → MIS size  10, iters   165, time  2.2328s
# init  6 → MIS size  11, iters   124, time  1.6900s
# init  7 → MIS size  10, iters   166, time  2.2392s
# init  8 → MIS size  10, iters   275, time  3.7384s
# init  9 → MIS size   9, iters   178, time  2.4095s
# — Seed 18 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=2.2873, min=1.4798, max=3.7384, std=0.6003, 95% CI=(1.5271, 3.4540)
# Iters: mean=169.2, min=110, max=275, std=44.0, 95% CI=(113.2, 254.3)
#
# ================== Seed 19 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=19): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   151, time  2.0322s
# init  1 → MIS size   9, iters   189, time  2.5498s
# init  2 → MIS size  10, iters   223, time  3.0254s
# init  3 → MIS size  10, iters   157, time  2.1146s
# init  4 → MIS size  10, iters   180, time  2.4359s
# init  5 → MIS size   9, iters   165, time  2.2121s
# init  6 → MIS size   9, iters   170, time  2.2989s
# init  7 → MIS size  10, iters   134, time  1.8164s
# init  8 → MIS size  10, iters   249, time  3.3748s
# init  9 → MIS size  10, iters   152, time  2.0522s
# — Seed 19 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.3912, min=1.8164, max=3.3748, std=0.4817, 95% CI=(1.8650, 3.2962)
# Iters: mean=177.0, min=134, max=249, std=35.3, 95% CI=(137.8, 243.2)
#
# ================== Seed 20 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=20): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   162, time  2.1553s
# init  1 → MIS size  10, iters   152, time  2.0757s
# init  2 → MIS size  10, iters   203, time  2.7761s
# init  3 → MIS size  11, iters   250, time  3.4209s
# init  4 → MIS size   9, iters   127, time  1.7187s
# init  5 → MIS size   9, iters   170, time  2.3104s
# init  6 → MIS size   9, iters   169, time  2.2768s
# init  7 → MIS size  11, iters   151, time  2.0279s
# init  8 → MIS size   9, iters   215, time  2.9412s
# init  9 → MIS size   9, iters   167, time  2.2660s
# — Seed 20 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.3969, min=1.7187, max=3.4209, std=0.5039, 95% CI=(1.7883, 3.3130)
# Iters: mean=176.6, min=127, max=250, std=36.0, 95% CI=(132.4, 242.1)
#
# ================== Seed 21 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=21): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   182, time  2.4138s
# init  1 → MIS size  10, iters   200, time  2.6947s
# init  2 → MIS size   9, iters   131, time  1.7697s
# init  3 → MIS size   9, iters   135, time  1.8208s
# init  4 → MIS size  11, iters   155, time  2.0926s
# init  5 → MIS size  14, iters   138, time  1.8690s
# init  6 → MIS size  10, iters   186, time  2.5160s
# init  7 → MIS size   9, iters   160, time  2.1520s
# init  8 → MIS size  10, iters    95, time  1.2883s
# init  9 → MIS size   8, iters   146, time  1.9860s
# — Seed 21 summary —
# Best MIS size: 14 (trial 5)
# Runtime (s): mean=2.0603, min=1.2883, max=2.6947, std=0.4116, 95% CI=(1.3966, 2.6545)
# Iters: mean=152.8, min=95, max=200, std=31.0, 95% CI=(103.1, 196.8)
#
# ================== Seed 22 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=22): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   160, time  2.1336s
# init  1 → MIS size  10, iters   150, time  2.0218s
# init  2 → MIS size  10, iters   196, time  2.6621s
# init  3 → MIS size  11, iters   155, time  2.0937s
# init  4 → MIS size  11, iters   179, time  2.4190s
# init  5 → MIS size  10, iters   132, time  1.7935s
# init  6 → MIS size  11, iters   142, time  1.9208s
# init  7 → MIS size  10, iters   204, time  2.7554s
# init  8 → MIS size   9, iters   138, time  1.8544s
# init  9 → MIS size  11, iters   215, time  2.9224s
# — Seed 22 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=2.2577, min=1.7935, max=2.9224, std=0.4040, 95% CI=(1.8072, 2.8849)
# Iters: mean=167.1, min=132, max=215, std=29.5, 95% CI=(133.3, 212.5)
#
# ================== Seed 23 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=23): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   146, time  1.9560s
# init  1 → MIS size   9, iters   174, time  2.3541s
# init  2 → MIS size  10, iters   158, time  2.1486s
# init  3 → MIS size  11, iters   168, time  2.3065s
# init  4 → MIS size  10, iters   226, time  3.0680s
# init  5 → MIS size  11, iters   150, time  2.0195s
# init  6 → MIS size  10, iters   193, time  2.6203s
# init  7 → MIS size   9, iters   158, time  2.1297s
# init  8 → MIS size  10, iters   157, time  2.1213s
# init  9 → MIS size   9, iters   190, time  2.5701s
# — Seed 23 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.3294, min=1.9560, max=3.0680, std=0.3400, 95% CI=(1.9703, 2.9673)
# Iters: mean=172.0, min=146, max=226, std=24.7, 95% CI=(146.9, 218.6)
#
# ================== Seed 24 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=24): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   159, time  2.1237s
# init  1 → MIS size   9, iters   148, time  1.9979s
# init  2 → MIS size  10, iters   143, time  1.9344s
# init  3 → MIS size  11, iters   112, time  1.5254s
# init  4 → MIS size   9, iters   152, time  2.0474s
# init  5 → MIS size  10, iters   132, time  1.7812s
# init  6 → MIS size  10, iters   139, time  1.8757s
# init  7 → MIS size  10, iters   141, time  1.9060s
# init  8 → MIS size  10, iters   291, time  3.9400s
# init  9 → MIS size  10, iters   140, time  1.8872s
# — Seed 24 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=2.1019, min=1.5254, max=3.9400, std=0.6660, 95% CI=(1.5829, 3.5314)
# Iters: mean=155.7, min=112, max=291, std=49.2, 95% CI=(116.5, 261.3)
#
# ================== Seed 25 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=25): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   166, time  2.2116s
# init  1 → MIS size  10, iters   184, time  2.4686s
# init  2 → MIS size  10, iters   137, time  1.8440s
# init  3 → MIS size  10, iters   145, time  1.9470s
# init  4 → MIS size  11, iters   230, time  3.1358s
# init  5 → MIS size   9, iters   174, time  2.3532s
# init  6 → MIS size  10, iters   130, time  1.7541s
# init  7 → MIS size  10, iters   151, time  2.0530s
# init  8 → MIS size  10, iters   139, time  1.8781s
# init  9 → MIS size  10, iters   159, time  2.2024s
# — Seed 25 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.1848, min=1.7541, max=3.1358, std=0.4061, 95% CI=(1.7744, 2.9857)
# Iters: mean=161.5, min=130, max=230, std=29.6, 95% CI=(131.6, 219.7)
#
# ================== Seed 26 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=26): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   144, time  1.9249s
# init  1 → MIS size   9, iters   154, time  2.0967s
# init  2 → MIS size  11, iters   236, time  3.2146s
# init  3 → MIS size  10, iters   147, time  1.9942s
# init  4 → MIS size  10, iters   191, time  2.5916s
# init  5 → MIS size  11, iters   209, time  2.8208s
# init  6 → MIS size  11, iters   147, time  1.9792s
# init  7 → MIS size  10, iters   142, time  1.9216s
# init  8 → MIS size   8, iters   144, time  1.9353s
# init  9 → MIS size  11, iters   206, time  2.7929s
# — Seed 26 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=2.3272, min=1.9216, max=3.2146, std=0.4811, 95% CI=(1.9223, 3.1260)
# Iters: mean=172.0, min=142, max=236, std=35.0, 95% CI=(142.4, 229.9)
#
# ================== Seed 27 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=27): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   158, time  2.1155s
# init  1 → MIS size  10, iters   173, time  2.3439s
# init  2 → MIS size   8, iters   150, time  2.0323s
# init  3 → MIS size  10, iters   177, time  2.3908s
# init  4 → MIS size  10, iters   153, time  2.0701s
# init  5 → MIS size  10, iters   174, time  2.3366s
# init  6 → MIS size  10, iters   147, time  1.9793s
# init  7 → MIS size   9, iters   150, time  2.0315s
# init  8 → MIS size  11, iters   146, time  1.9610s
# init  9 → MIS size  10, iters   113, time  1.5311s
# — Seed 27 summary —
# Best MIS size: 11 (trial 8)
# Runtime (s): mean=2.0792, min=1.5311, max=2.3908, std=0.2503, 95% CI=(1.6278, 2.3802)
# Iters: mean=154.1, min=113, max=177, std=18.7, 95% CI=(120.4, 176.3)
#
# ================== Seed 28 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=28): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   174, time  2.3224s
# init  1 → MIS size  10, iters   161, time  2.1873s
# init  2 → MIS size   9, iters   103, time  1.4023s
# init  3 → MIS size   9, iters   142, time  1.9087s
# init  4 → MIS size  11, iters   133, time  1.8006s
# init  5 → MIS size  10, iters   211, time  2.8738s
# init  6 → MIS size  10, iters   147, time  1.9956s
# init  7 → MIS size  10, iters   220, time  2.9934s
# init  8 → MIS size  10, iters   241, time  3.2732s
# init  9 → MIS size  10, iters   125, time  1.6924s
# — Seed 28 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=2.2450, min=1.4023, max=3.2732, std=0.6156, 95% CI=(1.4676, 3.2102)
# Iters: mean=165.7, min=103, max=241, std=45.1, 95% CI=(108.0, 236.3)
#
# ================== Seed 29 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=29): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   155, time  2.0732s
# init  1 → MIS size  11, iters   172, time  2.3318s
# init  2 → MIS size  11, iters   253, time  3.4514s
# init  3 → MIS size  10, iters   147, time  1.9831s
# init  4 → MIS size  10, iters   188, time  2.5727s
# init  5 → MIS size  10, iters   197, time  2.6549s
# init  6 → MIS size  10, iters   302, time  4.1584s
# init  7 → MIS size  10, iters   188, time  2.5381s
# init  8 → MIS size  11, iters   231, time  3.2284s
# init  9 → MIS size  11, iters   193, time  2.6203s
# — Seed 29 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.7612, min=1.9831, max=4.1584, std=0.6689, 95% CI=(2.0034, 3.9994)
# Iters: mean=202.6, min=147, max=302, std=47.2, 95% CI=(148.8, 291.0)
#
# ================== Seed 30 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=30): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   153, time  2.0179s
# init  1 → MIS size  10, iters   167, time  2.2250s
# init  2 → MIS size  11, iters   173, time  2.3351s
# init  3 → MIS size  10, iters   193, time  2.6131s
# init  4 → MIS size  10, iters   176, time  2.3679s
# init  5 → MIS size   9, iters   224, time  3.0340s
# init  6 → MIS size  11, iters   154, time  2.0616s
# init  7 → MIS size  10, iters   182, time  2.4356s
# init  8 → MIS size  10, iters   153, time  2.0538s
# init  9 → MIS size  10, iters   138, time  1.8725s
# — Seed 30 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.3017, min=1.8725, max=3.0340, std=0.3410, 95% CI=(1.9052, 2.9393)
# Iters: mean=171.3, min=138, max=224, std=24.7, 95% CI=(141.4, 217.0)
#
# ================== Seed 31 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=31): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   154, time  2.0592s
# init  1 → MIS size  11, iters   140, time  1.8987s
# init  2 → MIS size   9, iters   251, time  3.4294s
# init  3 → no MIS flagged by checker (iters 236, time  3.1719s)
# init  4 → MIS size  10, iters   188, time  2.5547s
# init  5 → MIS size  10, iters   134, time  1.8078s
# init  6 → MIS size  11, iters   195, time  2.6437s
# init  7 → MIS size   9, iters   233, time  3.1583s
# init  8 → MIS size  10, iters   152, time  2.0594s
# init  9 → MIS size   9, iters   158, time  2.1386s
# — Seed 31 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.4167, min=1.8078, max=3.4294, std=0.5721, 95% CI=(1.8260, 3.3752)
# Iters: mean=178.3, min=134, max=251, std=41.5, 95% CI=(135.2, 247.4)
#
# ================== Seed 32 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=32): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   152, time  2.0329s
# init  1 → MIS size  10, iters   144, time  1.9442s
# init  2 → MIS size  10, iters    83, time  1.1169s
# init  3 → MIS size  10, iters   146, time  1.9717s
# init  4 → MIS size   9, iters   156, time  2.1059s
# init  5 → MIS size  11, iters   210, time  2.8563s
# init  6 → MIS size   9, iters   145, time  1.9633s
# init  7 → MIS size  10, iters   123, time  1.6709s
# init  8 → MIS size  10, iters   136, time  1.8373s
# init  9 → MIS size   9, iters   175, time  2.3674s
# — Seed 32 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=1.9867, min=1.1169, max=2.8563, std=0.4471, 95% CI=(1.2415, 2.7463)
# Iters: mean=147.0, min=83, max=210, std=32.8, 95% CI=(92.0, 202.1)
#
# ================== Seed 33 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=33): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   161, time  2.1554s
# init  1 → MIS size   8, iters   134, time  1.8252s
# init  2 → MIS size  10, iters   180, time  2.4606s
# init  3 → MIS size  10, iters   257, time  3.4779s
# init  4 → MIS size  10, iters   158, time  2.1334s
# init  5 → MIS size  10, iters   164, time  2.2107s
# init  6 → MIS size   9, iters   154, time  2.1124s
# init  7 → MIS size  10, iters   233, time  3.1916s
# init  8 → MIS size  10, iters   125, time  1.6923s
# init  9 → MIS size  10, iters   192, time  2.6423s
# — Seed 33 summary —
# Best MIS size: 10 (trial 2)
# Runtime (s): mean=2.3902, min=1.6923, max=3.4779, std=0.5706, 95% CI=(1.7222, 3.4135)
# Iters: mean=175.8, min=125, max=257, std=41.7, 95% CI=(127.0, 251.6)
#
# ================== Seed 34 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=34): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   161, time  2.1512s
# init  1 → MIS size  10, iters   107, time  1.4555s
# init  2 → MIS size  10, iters   215, time  2.9045s
# init  3 → MIS size  10, iters   204, time  2.7636s
# init  4 → MIS size  11, iters   165, time  2.3005s
# init  5 → MIS size   9, iters   193, time  2.6248s
# init  6 → MIS size  12, iters   120, time  1.6329s
# init  7 → MIS size  10, iters   211, time  2.8886s
# init  8 → MIS size  10, iters   191, time  2.5691s
# init  9 → MIS size   9, iters   164, time  2.2326s
# — Seed 34 summary —
# Best MIS size: 12 (trial 6)
# Runtime (s): mean=2.3523, min=1.4555, max=2.9045, std=0.5014, 95% CI=(1.4954, 2.9009)
# Iters: mean=173.1, min=107, max=215, std=37.0, 95% CI=(109.9, 214.1)
#
# ================== Seed 35 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=35): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   154, time  2.0614s
# init  1 → MIS size   9, iters   151, time  2.0440s
# init  2 → MIS size  11, iters   149, time  2.0113s
# init  3 → MIS size  10, iters   169, time  2.2743s
# init  4 → MIS size  10, iters   133, time  1.7942s
# init  5 → MIS size  11, iters   130, time  1.7614s
# init  6 → MIS size  10, iters   225, time  3.0481s
# init  7 → MIS size  10, iters   188, time  2.5589s
# init  8 → MIS size  11, iters   146, time  1.9678s
# init  9 → MIS size   9, iters   152, time  2.0595s
# — Seed 35 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.1581, min=1.7614, max=3.0481, std=0.3867, 95% CI=(1.7688, 2.9381)
# Iters: mean=159.7, min=130, max=225, std=28.3, 95% CI=(130.7, 216.7)
#
# ================== Seed 36 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=36): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   148, time  1.9784s
# init  1 → MIS size  10, iters   142, time  1.9109s
# init  2 → MIS size  10, iters   178, time  2.4307s
# init  3 → MIS size  10, iters   238, time  3.3145s
# init  4 → MIS size  11, iters   138, time  1.8685s
# init  5 → MIS size  11, iters   193, time  2.6235s
# init  6 → MIS size  12, iters   144, time  1.9370s
# init  7 → MIS size   9, iters   122, time  1.6462s
# init  8 → MIS size  10, iters   136, time  1.8424s
# init  9 → MIS size  10, iters   133, time  1.8006s
# — Seed 36 summary —
# Best MIS size: 12 (trial 6)
# Runtime (s): mean=2.1353, min=1.6462, max=3.3145, std=0.5097, 95% CI=(1.6809, 3.1590)
# Iters: mean=157.2, min=122, max=238, std=35.6, 95% CI=(124.5, 227.9)
#
# ================== Seed 37 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=37): L-BFGS-B with MIS-check early exit
# init  0 → MIS size   9, iters   162, time  2.1361s
# init  1 → MIS size  10, iters   150, time  1.9795s
# init  2 → MIS size   9, iters   218, time  2.9051s
# init  3 → MIS size  10, iters   186, time  2.4852s
# init  4 → MIS size  10, iters   153, time  2.0330s
# init  5 → MIS size  10, iters   166, time  2.2235s
# init  6 → MIS size  12, iters   137, time  1.8180s
# init  7 → MIS size  10, iters   272, time  3.6453s
# init  8 → MIS size  10, iters   168, time  2.2331s
# init  9 → MIS size  10, iters   122, time  1.6208s
# — Seed 37 summary —
# Best MIS size: 12 (trial 6)
# Runtime (s): mean=2.3080, min=1.6208, max=3.6453, std=0.5883, 95% CI=(1.6652, 3.4788)
# Iters: mean=173.4, min=122, max=272, std=43.5, 95% CI=(125.4, 259.9)
#
# ================== Seed 38 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=38): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   149, time  1.9745s
# init  1 → MIS size  10, iters   144, time  1.9197s
# init  2 → MIS size  10, iters   180, time  2.4317s
# init  3 → MIS size  11, iters   134, time  1.7917s
# init  4 → MIS size  10, iters   190, time  2.5573s
# init  5 → MIS size  11, iters   164, time  2.1891s
# init  6 → MIS size  10, iters   198, time  2.6775s
# init  7 → MIS size  10, iters   242, time  3.2656s
# init  8 → MIS size  10, iters   122, time  1.6383s
# init  9 → MIS size  11, iters   134, time  1.7663s
# — Seed 38 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=2.2212, min=1.6383, max=3.2656, std=0.5099, 95% CI=(1.6671, 3.1332)
# Iters: mean=165.7, min=122, max=242, std=37.0, 95% CI=(124.7, 232.1)
#
# ================== Seed 39 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=39): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   153, time  2.0197s
# init  1 → MIS size  11, iters   127, time  1.6929s
# init  2 → MIS size   9, iters   142, time  1.8733s
# init  3 → MIS size  11, iters   142, time  1.9037s
# init  4 → MIS size  12, iters   177, time  2.3399s
# init  5 → MIS size   7, iters   148, time  1.9649s
# init  6 → MIS size  10, iters   260, time  3.5350s
# init  7 → MIS size  11, iters   188, time  2.4989s
# init  8 → MIS size  10, iters   173, time  2.3468s
# init  9 → MIS size   9, iters   291, time  3.9367s
# — Seed 39 summary —
# Best MIS size: 12 (trial 4)
# Runtime (s): mean=2.4112, min=1.6929, max=3.9367, std=0.7470, 95% CI=(1.7335, 3.8463)
# Iters: mean=180.1, min=127, max=291, std=54.1, 95% CI=(130.4, 284.0)
#
# ================== Seed 40 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=40): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   164, time  2.1761s
# init  1 → MIS size  11, iters   168, time  2.2565s
# init  2 → no MIS flagged by checker (iters 188, time  2.4836s)
# init  3 → MIS size  10, iters   117, time  1.5615s
# init  4 → MIS size   9, iters   151, time  2.0231s
# init  5 → MIS size  10, iters   143, time  1.9158s
# init  6 → MIS size  10, iters   143, time  1.9147s
# init  7 → MIS size   9, iters   130, time  1.7350s
# init  8 → MIS size  10, iters   172, time  2.2844s
# init  9 → MIS size   9, iters   168, time  2.2333s
# — Seed 40 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.0112, min=1.5615, max=2.2844, std=0.2521, 95% CI=(1.5962, 2.2788)
# Iters: mean=150.7, min=117, max=172, std=19.1, 95% CI=(119.6, 171.2)
#
# ================== Seed 41 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=41): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   149, time  1.9642s
# init  1 → MIS size  10, iters   174, time  2.3217s
# init  2 → MIS size  10, iters   206, time  2.8046s
# init  3 → MIS size   9, iters   139, time  1.8510s
# init  4 → MIS size   9, iters   186, time  2.4778s
# init  5 → MIS size  10, iters   246, time  3.2874s
# init  6 → MIS size  10, iters   140, time  1.8498s
# init  7 → MIS size   9, iters   188, time  2.5410s
# init  8 → MIS size  10, iters   143, time  1.8996s
# init  9 → MIS size  10, iters   162, time  2.1955s
# — Seed 41 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=2.3193, min=1.8498, max=3.2874, std=0.4719, 95% CI=(1.8501, 3.1787)
# Iters: mean=173.3, min=139, max=246, std=34.4, 95% CI=(139.2, 237.0)
#
# ================== Seed 42 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=42): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   157, time  2.0798s
# init  1 → MIS size  10, iters   180, time  2.4225s
# init  2 → MIS size  10, iters   176, time  2.3940s
# init  3 → MIS size   9, iters   198, time  2.6404s
# init  4 → MIS size  10, iters   145, time  1.9259s
# init  5 → MIS size  10, iters   128, time  1.7185s
# init  6 → MIS size   9, iters   165, time  2.1893s
# init  7 → MIS size  10, iters   156, time  2.1019s
# init  8 → MIS size  10, iters   174, time  2.3315s
# init  9 → MIS size  10, iters   204, time  2.7291s
# — Seed 42 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.2533, min=1.7185, max=2.7291, std=0.3129, 95% CI=(1.7652, 2.7092)
# Iters: mean=168.3, min=128, max=204, std=23.2, 95% CI=(131.8, 202.7)
#
# ================== Seed 43 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=43): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   152, time  1.9944s
# init  1 → MIS size  10, iters   171, time  2.2779s
# init  2 → MIS size   9, iters   196, time  2.6046s
# init  3 → MIS size  10, iters   151, time  2.0182s
# init  4 → MIS size  10, iters   134, time  1.7948s
# init  5 → MIS size  10, iters   216, time  2.9214s
# init  6 → MIS size   9, iters   161, time  2.1903s
# init  7 → MIS size  10, iters   159, time  2.1582s
# init  8 → MIS size   9, iters   166, time  2.2359s
# init  9 → MIS size  10, iters   102, time  1.3883s
# — Seed 43 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=2.1584, min=1.3883, max=2.9214, std=0.4182, 95% CI=(1.4798, 2.8501)
# Iters: mean=160.8, min=102, max=216, std=31.2, 95% CI=(109.2, 211.5)
#
# ================== Seed 44 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=44): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   153, time  2.0399s
# init  1 → MIS size  10, iters   247, time  3.3648s
# init  2 → MIS size  10, iters   179, time  2.4038s
# init  3 → MIS size  10, iters   236, time  3.1634s
# init  4 → MIS size   9, iters   170, time  2.2826s
# init  5 → MIS size   9, iters   190, time  2.5295s
# init  6 → MIS size  11, iters   218, time  2.9265s
# init  7 → MIS size  10, iters   170, time  2.2859s
# init  8 → MIS size   9, iters   177, time  2.3855s
# init  9 → MIS size  10, iters   136, time  1.7993s
# — Seed 44 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=2.5181, min=1.7993, max=3.3648, std=0.4928, 95% CI=(1.8534, 3.3195)
# Iters: mean=187.6, min=136, max=247, std=35.7, 95% CI=(139.8, 244.5)
#
# ================== Seed 45 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=45): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   160, time  2.1171s
# init  1 → MIS size  10, iters   184, time  2.4800s
# init  2 → MIS size  10, iters   191, time  2.6265s
# init  3 → MIS size  10, iters   138, time  1.8675s
# init  4 → MIS size  10, iters   146, time  1.9562s
# init  5 → MIS size   9, iters   234, time  3.1216s
# init  6 → MIS size  12, iters   161, time  2.1579s
# init  7 → MIS size   9, iters   188, time  2.5953s
# init  8 → MIS size   9, iters   157, time  2.0939s
# init  9 → MIS size   9, iters   174, time  2.3353s
# — Seed 45 summary —
# Best MIS size: 12 (trial 6)
# Runtime (s): mean=2.3351, min=1.8675, max=3.1216, std=0.3788, 95% CI=(1.8875, 3.0102)
# Iters: mean=173.3, min=138, max=234, std=27.7, 95% CI=(139.8, 224.3)
#
# ================== Seed 46 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=46): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   154, time  2.0359s
# init  1 → MIS size  12, iters   139, time  1.8731s
# init  2 → MIS size  10, iters   179, time  2.3799s
# init  3 → MIS size   9, iters   197, time  2.6448s
# init  4 → MIS size   9, iters   138, time  1.8541s
# init  5 → MIS size  11, iters   157, time  2.1101s
# init  6 → MIS size   9, iters   290, time  4.0307s
# init  7 → MIS size   9, iters   222, time  2.9761s
# init  8 → MIS size  10, iters   197, time  2.6296s
# init  9 → MIS size  10, iters   131, time  1.7556s
# — Seed 46 summary —
# Best MIS size: 12 (trial 1)
# Runtime (s): mean=2.4290, min=1.7556, max=4.0307, std=0.6915, 95% CI=(1.7777, 3.7934)
# Iters: mean=180.4, min=131, max=290, std=48.9, 95% CI=(132.6, 274.7)
#
# ================== Seed 47 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=47): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   186, time  2.4776s
# init  1 → MIS size  11, iters   140, time  1.8975s
# init  2 → MIS size  10, iters   180, time  2.3943s
# init  3 → MIS size  11, iters   145, time  1.9463s
# init  4 → MIS size  10, iters   163, time  2.1820s
# init  5 → MIS size   9, iters   166, time  2.2172s
# init  6 → MIS size   8, iters   202, time  2.7166s
# init  7 → MIS size   9, iters   124, time  1.6407s
# init  8 → MIS size  10, iters   230, time  3.0758s
# init  9 → MIS size   9, iters   147, time  1.9375s
# — Seed 47 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=2.2486, min=1.6407, max=3.0758, std=0.4299, 95% CI=(1.6985, 2.9950)
# Iters: mean=168.3, min=124, max=230, std=31.9, 95% CI=(127.6, 223.7)
#
# ================== Seed 48 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=48): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  10, iters   150, time  1.9960s
# init  1 → MIS size   8, iters   239, time  3.2413s
# init  2 → MIS size  10, iters   159, time  2.1249s
# init  3 → MIS size  10, iters   186, time  2.5083s
# init  4 → MIS size  10, iters   139, time  1.8656s
# init  5 → MIS size  11, iters   183, time  2.4799s
# init  6 → MIS size  10, iters   171, time  2.2898s
# init  7 → MIS size   9, iters   147, time  1.9627s
# init  8 → MIS size   9, iters   162, time  2.1675s
# init  9 → MIS size   9, iters   141, time  1.8879s
# — Seed 48 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=2.2524, min=1.8656, max=3.2413, std=0.4153, 95% CI=(1.8706, 3.0763)
# Iters: mean=167.7, min=139, max=239, std=29.9, 95% CI=(139.4, 227.1)
#
# ================== Seed 49 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=49): L-BFGS-B with MIS-check early exit
# init  0 → MIS size  11, iters   144, time  1.9028s
# init  1 → MIS size  10, iters   137, time  1.8327s
# init  2 → MIS size  10, iters   176, time  2.3578s
# init  3 → MIS size  11, iters   135, time  1.8126s
# init  4 → MIS size  10, iters   188, time  2.5182s
# init  5 → MIS size   9, iters   176, time  2.3374s
# init  6 → MIS size   9, iters   271, time  3.7288s
# init  7 → MIS size  11, iters   138, time  1.8418s
# init  8 → MIS size  10, iters   139, time  1.8604s
# init  9 → MIS size  11, iters   122, time  1.6321s
# — Seed 49 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=2.1825, min=1.6321, max=3.7288, std=0.6163, 95% CI=(1.6727, 3.4564)
# Iters: mean=162.6, min=122, max=271, std=43.9, 95% CI=(124.9, 252.3)
#
# =========== Across-seeds summary (best per seed) ===========
# Seeds with MIS: 50/50
# Best MIS size: max=14, min=10, mean=11.28, std=0.73

# %% [markdown]
# ## Free Mask Newton ##

# %% [markdown]
# ## Hard Fixing? ##

# %%
# %% [markdown]
# Free-mask Projected Newton for relaxed MIS with fair timing & robust inits
# (PyTorch without `generator=` support on randn_like)

# %%
import torch
import networkx as nx
import numpy as np
import pandas as pd
import time

# ===========================
# Global params
# ===========================
n = 500
p = 0.5
SEEDS = range(10)
N_TRIALS = 10

# Newton params
max_iters = 1500
tol = 1e-8
damping0 = 1e-3
ls_iters_default = 40
alpha0_default = 1.0
beta_default = 0.5
c1_default = 1e-4

# Init sampling
sigma_init = 0.15  # small jitter to avoid clipping collapse

# ===========================
# Problem pieces
# ===========================
def objective(x: torch.Tensor, H: torch.Tensor) -> float:
    # f(x) = -1^T x + 1/2 x^T H x
    return float((-x.sum() + 0.5 * (x @ (H @ x))).item())

def gradient(x: torch.Tensor, H: torch.Tensor) -> torch.Tensor:
    return -torch.ones_like(x) + H @ x

def MIS_checker_efficient_3(X: torch.Tensor, A: torch.Tensor, A_bar: torch.Tensor):
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones_like(Xb) + (n * A) @ Xb)
    Xb_up.clamp_(0, 1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

def sample_init(d_init: torch.Tensor, sigma: float) -> torch.Tensor:
    # No generator kwarg; RNG determinism is controlled by torch.manual_seed(seed) once per seed
    x = d_init + sigma * torch.randn_like(d_init)
    return x.clamp_(0.0, 1.0)

# ===========================
# Free-mask Projected Newton (final)
# ===========================
@torch.no_grad()
def projected_newton_free(
    H: torch.Tensor, A: torch.Tensor, A_bar: torch.Tensor, x0: torch.Tensor,
    max_iters: int = max_iters, tol: float = tol,
    alpha0: float = alpha0_default, beta: float = beta_default,
    ls_iters: int = ls_iters_default, damping0: float = damping0,
    c1: float | None = c1_default
):
    """
    Projected Newton with L-BFGS-B-style free set.
    Solve (H_FF + λ I) d_F = g_F, take descent p = -d on F (zero elsewhere),
    update x_new = clamp(x + α p, 0, 1). Early exit on MIS.
    """
    x = x0.clone()
    damping = damping0
    history = []
    is_MIS = False
    MIS = None

    # Cache for current free set & damping
    cached_free_idx = None
    cached_damping = None
    L_cached = None  # cholesky(H_ff + damping I)
    eye_cache = None  # sized per free set

    for it in range(1, max_iters + 1):
        g = gradient(x, H)
        g_norm = float(g.norm().item())
        f0 = objective(x, H)
        history.append((it - 1, f0, g_norm))

        if g_norm < tol:
            break

        # L-BFGS-B free-set rule
        F_mask = ((x > 0.0 + 1e-10) & (x < 1.0 - 1e-10)) \
                 | ((x <= 0.0 + 1e-10) & (g < 0)) \
                 | ((x >= 1.0 - 1e-10) & (g > 0))
        free_idx = torch.nonzero(F_mask, as_tuple=False).flatten()

        # If nothing free, try a small projected steepest-descent nudge
        if free_idx.numel() == 0:
            p = -g
            p[(x <= 0.0 + 1e-12) & (p < 0)] = 0.0
            p[(x >= 1.0 - 1e-12) & (p > 0)] = 0.0
            if float(p.norm().item()) < 1e-14:
                break

            alpha = alpha0
            accepted = False
            for _ in range(ls_iters):
                x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
                if objective(x_trial, H) < f0:  # simple decrease
                    x = x_trial
                    accepted = True
                    break
                alpha *= beta
            if not accepted:
                break

            is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
            if is_MIS:
                break
            continue

        # Reduced Newton solve on free set: (H_ff + λI) d_f = g_f
        g_f = g[free_idx]

        need_refactor = (
            L_cached is None or
            cached_damping is None or
            cached_free_idx is None or
            (cached_damping != damping) or
            (cached_free_idx.numel() != free_idx.numel()) or
            (not torch.equal(cached_free_idx, free_idx))
        )

        if need_refactor:
            H_ff = H.index_select(0, free_idx).index_select(1, free_idx)
            H_ff = 0.5 * (H_ff + H_ff.T)  # symmetrize
            k = H_ff.shape[0]
            if (eye_cache is None) or (eye_cache.shape[0] != k):
                eye_cache = torch.eye(k, dtype=H_ff.dtype, device=H_ff.device)
            H_ff_damped = H_ff + damping * eye_cache

            # Build/repair Cholesky by adapting damping
            built = False
            for _ in range(10):
                try:
                    L_cached = torch.linalg.cholesky(H_ff_damped)
                    cached_free_idx = free_idx.clone()
                    cached_damping = damping
                    built = True
                    break
                except RuntimeError:
                    damping *= 10.0
                    H_ff_damped = H_ff + damping * eye_cache
            if not built:
                # fallback: projected steepest-descent on free set
                p = torch.zeros_like(g)
                p[free_idx] = -g_f
                alpha = alpha0
                accepted = False
                for _ in range(ls_iters):
                    x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
                    if objective(x_trial, H) < f0:
                        x = x_trial
                        accepted = True
                        break
                    alpha *= beta
                if not accepted:
                    damping = min(max(damping * 2.0, 1e-7), 1e7)
                else:
                    damping = max(damping * 0.5, 1e-7)
                is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
                if is_MIS:
                    break
                continue

        # Solve for d_f, then descent direction p = -d
        d_f = torch.cholesky_solve(g_f.unsqueeze(1), L_cached).squeeze(1)  # d_f = (H_ff + λI)^{-1} g_f
        p = torch.zeros_like(g)
        p[free_idx] = -d_f  # DESCENT direction

        # Guard: ensure descent slope on free set; if not, use -grad on free set
        slope = float((g[free_idx] * p[free_idx]).sum().item())
        if slope >= 0:
            p.zero_()
            p[free_idx] = -g_f

        # Projected backtracking (Armijo if c1 provided, else simple)
        alpha = alpha0
        accepted = False
        for _ in range(ls_iters):
            x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
            f_trial = objective(x_trial, H)
            if c1 is None:
                ok = (f_trial < f0)
            else:
                s = float((g[free_idx] * p[free_idx]).sum().item())
                ok = (s < 0) and (f_trial <= f0 + c1 * alpha * s)  # Armijo on free-set slope
            if ok:
                x = x_trial
                accepted = True
                break
            alpha *= beta

        if not accepted:
            damping = min(max(damping * 10.0, 1e-7), 1e7)
            L_cached = None
            cached_free_idx = None
            cached_damping = None
        else:
            damping = max(damping * 0.5, 1e-7)

        # MIS early exit
        is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
        if is_MIS:
            break

    return x, history, is_MIS, MIS

# ===========================
# Experiment: seeds 0-49, 10 inits each
# ===========================
summaries = []
summaries_fair = []  # exclude init 0 from means (fair method timing)

for seed in SEEDS:
    # Build graph
    g = nx.gnp_random_graph(n, p, seed=seed)
    A = torch.tensor(nx.adjacency_matrix(g).todense(), dtype=torch.float32)
    A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(g)).todense(), dtype=torch.float32)

    # Build H
    # PSD option (recommended to reduce "all max-iters"):
    degrees_c = dict(nx.complement(g).degree())
    gamma = 2 + (max(degrees_c.values()) if degrees_c else 0)
    H = gamma * A  # <-- PSD version
    # To use your original: H = gamma * A - 1.0 * A_bar

    # Degree-based init
    degrees = dict(g.degree())
    max_deg = max(degrees.values()) if degrees else 1
    d = torch.zeros(n, dtype=torch.float32)
    for node, deg in degrees.items():
        d[node] = 1.0 - (deg / max_deg if max_deg > 0 else 0.0)
    d_init = d / (d.max() if float(d.max().item()) > 0 else 1.0)

    # ---- Per-seed RNG & warm-up ----
    torch.manual_seed(seed)  # ensures distinct, deterministic draws per trial within this seed
    _ = projected_newton_free(H, A, A_bar, d_init)  # warm-up call (not timed)

    trial_stats = []
    print(f"\n================== Seed {seed} ==================")
    print("Number of connected components:", nx.number_connected_components(g))
    print(f"ER({n}, {p}, seed={seed}): Projected Newton (free set) with MIS-check")

    for init in range(N_TRIALS):
        if init == 0:
            x0 = d_init.clone()
        else:
            x0 = sample_init(d_init, sigma_init)

        start = time.time()
        x_opt, history, is_MIS, MIS = projected_newton_free(
            H, A, A_bar, x0,
            alpha0=alpha0_default, beta=beta_default,
            ls_iters=ls_iters_default, c1=c1_default
        )
        elapsed = time.time() - start

        MIS_size = int(MIS.numel()) if (is_MIS and hasattr(MIS, "numel")) else (int(MIS.item()) if is_MIS and getattr(MIS, "ndim", 1)==0 else 0)
        print(f"init {init:2d} → MIS size {MIS_size:3d}, iters {len(history):5d}, time {elapsed:7.4f}s")

        trial_stats.append({'iters': len(history), 'time': elapsed, 'MIS_size': MIS_size})

    df = pd.DataFrame(trial_stats)

    # Per-seed summaries
    best_mis = int(df.MIS_size.max())
    best_trial = int(df.MIS_size.idxmax())

    print(f"— Seed {seed} summary —")
    print(f"Best MIS size: {best_mis} (trial {best_trial})")
    print(f"Runtime (s): mean={df.time.mean():.4f}, min={df.time.min():.4f}, max={df.time.max():.4f}, "
          f"std={df.time.std(ddof=1):.4f}")
    print(f"Iters: mean={df.iters.mean():.1f}, min={df.iters.min()}, max={df.iters.max()}, "
          f"std={df.iters.std(ddof=1):.1f}")

    summaries.append({
        'seed': seed,
        'max_MIS_size': best_mis,
        'mean_iters': float(df.iters.mean()),
        'mean_time': float(df.time.mean())
    })

    # Fair (exclude init 0)
    df_fair = df.iloc[1:] if len(df) > 1 else df
    summaries_fair.append({
        'seed': seed,
        'max_MIS_size': best_mis,
        'mean_iters_fair': float(df_fair.iters.mean()),
        'mean_time_fair': float(df_fair.time.mean())
    })

# ===========================
# Aggregate summaries
# ===========================
df_summary = pd.DataFrame(summaries)
df_summary_fair = pd.DataFrame(summaries_fair)

print(f"\nProjected Newton (free set) on ER({n},{p}) over seeds 0-49, {N_TRIALS} trials each, "
      f"alpha0={alpha0_default}, beta={beta_default}, c1={c1_default}")
print("Overall means:")
print(df_summary)

print("\nFair means (exclude init 0 per seed):")
print(df_summary_fair)

# Optional: save CSVs
# df_summary.to_csv('newton_free_mask_summary_overall.csv', index=False)
# df_summary_fair.to_csv('newton_free_mask_summary_fair.csv', index=False)
# Out:
# ================== Seed 0 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=0): Projected Newton (free set) with MIS-check
# init  0 → MIS size   8, iters    35, time  0.0229s
# init  1 → MIS size   9, iters    35, time  0.0224s
# init  2 → MIS size  10, iters    38, time  0.0241s
# init  3 → MIS size  10, iters    38, time  0.0244s
# init  4 → MIS size  10, iters    16, time  0.0162s
# init  5 → MIS size  10, iters    15, time  0.0118s
# init  6 → MIS size   9, iters    12, time  0.0104s
# init  7 → MIS size  10, iters    13, time  0.0112s
# init  8 → MIS size  11, iters    12, time  0.0102s
# init  9 → MIS size  10, iters    16, time  0.0125s
# — Seed 0 summary —
# Best MIS size: 11 (trial 8)
# Runtime (s): mean=0.0166, min=0.0102, max=0.0244, std=0.0061
# Iters: mean=23.0, min=12, max=38, std=11.7
#
# ================== Seed 1 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=1): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    15, time  0.0126s
# init  1 → MIS size   9, iters    16, time  0.0125s
# init  2 → MIS size  10, iters    20, time  0.0155s
# init  3 → MIS size  10, iters    26, time  0.0178s
# init  4 → MIS size  12, iters    31, time  0.0199s
# init  5 → MIS size  11, iters    16, time  0.0128s
# init  6 → MIS size  10, iters    13, time  0.0145s
# init  7 → MIS size  11, iters    13, time  0.0118s
# init  8 → MIS size  11, iters    22, time  0.0158s
# init  9 → MIS size  11, iters    26, time  0.0183s
# — Seed 1 summary —
# Best MIS size: 12 (trial 4)
# Runtime (s): mean=0.0151, min=0.0118, max=0.0199, std=0.0028
# Iters: mean=19.8, min=13, max=31, std=6.3
#
# ================== Seed 2 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=2): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    19, time  0.0155s
# init  1 → MIS size   9, iters    36, time  0.0230s
# init  2 → MIS size  10, iters    16, time  0.0125s
# init  3 → MIS size  10, iters    15, time  0.0117s
# init  4 → MIS size  10, iters    12, time  0.0103s
# init  5 → MIS size  11, iters    13, time  0.0119s
# init  6 → MIS size   0, iters  1500, time  0.8078s
# init  7 → MIS size  11, iters    16, time  0.0131s
# init  8 → MIS size   9, iters    16, time  0.0128s
# init  9 → MIS size   8, iters    12, time  0.0105s
# — Seed 2 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0929, min=0.0103, max=0.8078, std=0.2512
# Iters: mean=165.5, min=12, max=1500, std=468.9
#
# ================== Seed 3 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=3): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    16, time  0.0137s
# init  1 → MIS size  11, iters    15, time  0.0122s
# init  2 → MIS size   9, iters    36, time  0.0227s
# init  3 → MIS size  10, iters    16, time  0.0128s
# init  4 → MIS size   9, iters    21, time  0.0155s
# init  5 → MIS size   9, iters    36, time  0.0223s
# init  6 → MIS size   9, iters    15, time  0.0120s
# init  7 → MIS size  10, iters    14, time  0.0117s
# init  8 → MIS size  11, iters    13, time  0.0107s
# init  9 → MIS size   9, iters    14, time  0.0118s
# — Seed 3 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0146, min=0.0107, max=0.0227, std=0.0044
# Iters: mean=19.6, min=13, max=36, std=8.9
#
# ================== Seed 4 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=4): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    10, time  0.0099s
# init  1 → MIS size  10, iters    13, time  0.0111s
# init  2 → MIS size  10, iters    14, time  0.0114s
# init  3 → MIS size  10, iters    15, time  0.0117s
# init  4 → MIS size  10, iters    14, time  0.0117s
# init  5 → MIS size  11, iters    12, time  0.0100s
# init  6 → MIS size  10, iters    36, time  0.0231s
# init  7 → MIS size   9, iters    15, time  0.0120s
# init  8 → MIS size  11, iters    13, time  0.0106s
# init  9 → MIS size   9, iters    14, time  0.0115s
# — Seed 4 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0123, min=0.0099, max=0.0231, std=0.0039
# Iters: mean=15.6, min=10, max=36, std=7.3
#
# ================== Seed 5 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=5): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    13, time  0.0114s
# init  1 → MIS size  11, iters    15, time  0.0126s
# init  2 → MIS size   9, iters    12, time  0.0104s
# init  3 → MIS size  11, iters     9, time  0.0094s
# init  4 → MIS size   9, iters     8, time  0.0088s
# init  5 → MIS size   9, iters    16, time  0.0125s
# init  6 → MIS size  10, iters    12, time  0.0103s
# init  7 → MIS size  10, iters    13, time  0.0112s
# init  8 → MIS size   9, iters    28, time  0.0186s
# init  9 → MIS size  10, iters    15, time  0.0121s
# — Seed 5 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0117, min=0.0088, max=0.0186, std=0.0027
# Iters: mean=14.1, min=8, max=28, std=5.5
#
# ================== Seed 6 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=6): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    13, time  0.0116s
# init  1 → MIS size  10, iters    14, time  0.0117s
# init  2 → MIS size  10, iters     9, time  0.0118s
# init  3 → MIS size  10, iters    16, time  0.0145s
# init  4 → MIS size   9, iters    12, time  0.0112s
# init  5 → MIS size  11, iters    13, time  0.0109s
# init  6 → MIS size   9, iters    13, time  0.0112s
# init  7 → MIS size   9, iters    11, time  0.0101s
# init  8 → MIS size  10, iters    12, time  0.0101s
# init  9 → MIS size  10, iters    16, time  0.0122s
# — Seed 6 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0115, min=0.0101, max=0.0145, std=0.0013
# Iters: mean=12.9, min=9, max=16, std=2.1
#
# ================== Seed 7 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=7): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    12, time  0.0110s
# init  1 → MIS size  10, iters    59, time  0.0343s
# init  2 → MIS size   9, iters    13, time  0.0107s
# init  3 → MIS size  10, iters    17, time  0.0131s
# init  4 → MIS size  10, iters    12, time  0.0104s
# init  5 → MIS size   9, iters    13, time  0.0109s
# init  6 → MIS size   9, iters    15, time  0.0119s
# init  7 → MIS size  11, iters    36, time  0.0222s
# init  8 → MIS size  10, iters    11, time  0.0096s
# init  9 → MIS size  10, iters    15, time  0.0115s
# — Seed 7 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0146, min=0.0096, max=0.0343, std=0.0078
# Iters: mean=20.3, min=11, max=59, std=15.4
#
# ================== Seed 8 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=8): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    20, time  0.0153s
# init  1 → MIS size   9, iters    15, time  0.0128s
# init  2 → MIS size   9, iters    14, time  0.0119s
# init  3 → MIS size  10, iters    16, time  0.0137s
# init  4 → MIS size   9, iters    13, time  0.0112s
# init  5 → MIS size   9, iters    16, time  0.0125s
# init  6 → MIS size  10, iters    38, time  0.0238s
# init  7 → MIS size  11, iters    23, time  0.0159s
# init  8 → MIS size   9, iters    49, time  0.0286s
# init  9 → MIS size   7, iters    12, time  0.0109s
# — Seed 8 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0157, min=0.0109, max=0.0286, std=0.0059
# Iters: mean=21.6, min=12, max=49, std=12.3
#
# ================== Seed 9 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=9): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    14, time  0.0123s
# init  1 → MIS size   9, iters    40, time  0.0251s
# init  2 → MIS size  10, iters    36, time  0.0228s
# init  3 → MIS size  11, iters    12, time  0.0110s
# init  4 → MIS size   9, iters    12, time  0.0105s
# init  5 → MIS size   9, iters    32, time  0.0208s
# init  6 → MIS size   9, iters    12, time  0.0101s
# init  7 → MIS size  10, iters    16, time  0.0121s
# init  8 → MIS size   8, iters    12, time  0.0104s
# init  9 → MIS size  10, iters    14, time  0.0111s
# — Seed 9 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0146, min=0.0101, max=0.0251, std=0.0058
# Iters: mean=20.0, min=12, max=40, std=11.3
#
# ================== Seed 10 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=10): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    14, time  0.0379s
# init  1 → MIS size  10, iters    33, time  0.0222s
# init  2 → MIS size  11, iters    12, time  0.0115s
# init  3 → MIS size  11, iters    12, time  0.0117s
# init  4 → MIS size  11, iters    15, time  0.0127s
# init  5 → MIS size  11, iters    26, time  0.0219s
# init  6 → MIS size  10, iters    21, time  0.0156s
# init  7 → MIS size   8, iters    12, time  0.0107s
# init  8 → MIS size   8, iters    16, time  0.0125s
# init  9 → MIS size  10, iters    77, time  0.0435s
# — Seed 10 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0200, min=0.0107, max=0.0435, std=0.0117
# Iters: mean=23.8, min=12, max=77, std=19.9
#
# ================== Seed 11 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=11): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    13, time  0.0112s
# init  1 → MIS size  11, iters    15, time  0.0120s
# init  2 → MIS size  10, iters    15, time  0.0119s
# init  3 → MIS size  11, iters    14, time  0.0115s
# init  4 → MIS size   9, iters    15, time  0.0122s
# init  5 → MIS size  11, iters    27, time  0.0178s
# init  6 → MIS size  10, iters     8, time  0.0082s
# init  7 → MIS size  11, iters    15, time  0.0118s
# init  8 → MIS size  11, iters    14, time  0.0113s
# init  9 → MIS size  10, iters    13, time  0.0105s
# — Seed 11 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0118, min=0.0082, max=0.0178, std=0.0024
# Iters: mean=14.9, min=8, max=27, std=4.7
#
# ================== Seed 12 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=12): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    16, time  0.0132s
# init  1 → MIS size  10, iters     9, time  0.0088s
# init  2 → MIS size  10, iters    13, time  0.0110s
# init  3 → MIS size  10, iters    13, time  0.0110s
# init  4 → MIS size  11, iters    13, time  0.0111s
# init  5 → MIS size  11, iters    12, time  0.0113s
# init  6 → MIS size  10, iters    17, time  0.0128s
# init  7 → MIS size  10, iters    15, time  0.0117s
# init  8 → MIS size   9, iters    14, time  0.0118s
# init  9 → MIS size  12, iters    19, time  0.0135s
# — Seed 12 summary —
# Best MIS size: 12 (trial 9)
# Runtime (s): mean=0.0116, min=0.0088, max=0.0135, std=0.0014
# Iters: mean=14.1, min=9, max=19, std=2.8
#
# ================== Seed 13 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=13): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    16, time  0.0131s
# init  1 → MIS size   9, iters    15, time  0.0117s
# init  2 → MIS size   9, iters    11, time  0.0101s
# init  3 → MIS size  12, iters    13, time  0.0114s
# init  4 → MIS size  11, iters    27, time  0.0178s
# init  5 → MIS size  10, iters    17, time  0.0127s
# init  6 → MIS size  10, iters    17, time  0.0135s
# init  7 → MIS size  10, iters    12, time  0.0105s
# init  8 → MIS size   8, iters    12, time  0.0104s
# init  9 → MIS size  10, iters    13, time  0.0106s
# — Seed 13 summary —
# Best MIS size: 12 (trial 3)
# Runtime (s): mean=0.0122, min=0.0101, max=0.0178, std=0.0023
# Iters: mean=15.3, min=11, max=27, std=4.6
#
# ================== Seed 14 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=14): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    18, time  0.0140s
# init  1 → MIS size  10, iters    13, time  0.0106s
# init  2 → MIS size   9, iters    12, time  0.0102s
# init  3 → MIS size  10, iters    14, time  0.0115s
# init  4 → MIS size  10, iters    11, time  0.0101s
# init  5 → MIS size  10, iters    17, time  0.0129s
# init  6 → MIS size  11, iters    12, time  0.0104s
# init  7 → MIS size   9, iters    16, time  0.0120s
# init  8 → MIS size  10, iters    13, time  0.0104s
# init  9 → MIS size   9, iters    16, time  0.0119s
# — Seed 14 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=0.0114, min=0.0101, max=0.0140, std=0.0013
# Iters: mean=14.2, min=11, max=18, std=2.4
#
# ================== Seed 15 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=15): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    12, time  0.0111s
# init  1 → MIS size  10, iters    14, time  0.0116s
# init  2 → MIS size  10, iters    12, time  0.0105s
# init  3 → MIS size  10, iters    15, time  0.0130s
# init  4 → MIS size  10, iters    22, time  0.0156s
# init  5 → MIS size  11, iters    13, time  0.0119s
# init  6 → MIS size  10, iters    12, time  0.0105s
# init  7 → MIS size  10, iters    14, time  0.0121s
# init  8 → MIS size  10, iters    10, time  0.0095s
# init  9 → MIS size  11, iters    13, time  0.0113s
# — Seed 15 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0117, min=0.0095, max=0.0156, std=0.0017
# Iters: mean=13.7, min=10, max=22, std=3.2
#
# ================== Seed 16 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=16): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    16, time  0.0130s
# init  1 → MIS size   9, iters    27, time  0.0186s
# init  2 → MIS size  11, iters    26, time  0.0178s
# init  3 → MIS size  11, iters    20, time  0.0145s
# init  4 → MIS size  10, iters    12, time  0.0106s
# init  5 → MIS size  10, iters    15, time  0.0117s
# init  6 → MIS size  11, iters    12, time  0.0102s
# init  7 → MIS size  10, iters    12, time  0.0098s
# init  8 → MIS size  10, iters    11, time  0.0097s
# init  9 → MIS size   8, iters    12, time  0.0106s
# — Seed 16 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0126, min=0.0097, max=0.0186, std=0.0033
# Iters: mean=16.3, min=11, max=27, std=6.0
#
# ================== Seed 17 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=17): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    15, time  0.0122s
# init  1 → MIS size  10, iters    12, time  0.0102s
# init  2 → MIS size   9, iters    13, time  0.0105s
# init  3 → MIS size   9, iters    15, time  0.0115s
# init  4 → MIS size   9, iters    13, time  0.0105s
# init  5 → MIS size  10, iters    15, time  0.0113s
# init  6 → MIS size  11, iters    21, time  0.0145s
# init  7 → MIS size  10, iters    13, time  0.0110s
# init  8 → MIS size   9, iters    15, time  0.0115s
# init  9 → MIS size   9, iters    15, time  0.0112s
# — Seed 17 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0114, min=0.0102, max=0.0145, std=0.0012
# Iters: mean=14.7, min=12, max=21, std=2.5
#
# ================== Seed 18 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=18): Projected Newton (free set) with MIS-check
# init  0 → MIS size  12, iters    15, time  0.0122s
# init  1 → MIS size  10, iters    28, time  0.0184s
# init  2 → MIS size  11, iters    12, time  0.0104s
# init  3 → MIS size   9, iters    36, time  0.0224s
# init  4 → MIS size  10, iters    16, time  0.0124s
# init  5 → MIS size  10, iters    13, time  0.0109s
# init  6 → MIS size  12, iters    15, time  0.0116s
# init  7 → MIS size  10, iters    14, time  0.0115s
# init  8 → MIS size   9, iters    16, time  0.0122s
# init  9 → MIS size   9, iters    15, time  0.0117s
# — Seed 18 summary —
# Best MIS size: 12 (trial 0)
# Runtime (s): mean=0.0134, min=0.0104, max=0.0224, std=0.0039
# Iters: mean=18.0, min=12, max=36, std=7.7
#
# ================== Seed 19 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=19): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    17, time  0.0137s
# init  1 → MIS size  11, iters    15, time  0.0122s
# init  2 → MIS size  10, iters    13, time  0.0105s
# init  3 → MIS size  10, iters    16, time  0.0122s
# init  4 → MIS size   8, iters    14, time  0.0118s
# init  5 → MIS size  11, iters    14, time  0.0114s
# init  6 → MIS size   9, iters    11, time  0.0097s
# init  7 → MIS size  10, iters    36, time  0.0226s
# init  8 → MIS size   9, iters    14, time  0.0117s
# init  9 → MIS size  10, iters    15, time  0.0119s
# — Seed 19 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0128, min=0.0097, max=0.0226, std=0.0036
# Iters: mean=16.5, min=11, max=36, std=7.0
#
# ================== Seed 20 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=20): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    12, time  0.0105s
# init  1 → MIS size  11, iters    13, time  0.0111s
# init  2 → MIS size  11, iters    16, time  0.0124s
# init  3 → MIS size   9, iters    15, time  0.0122s
# init  4 → MIS size  10, iters    11, time  0.0098s
# init  5 → MIS size  11, iters    16, time  0.0121s
# init  6 → MIS size   9, iters    15, time  0.0115s
# init  7 → MIS size  10, iters    15, time  0.0115s
# init  8 → MIS size  10, iters    12, time  0.0100s
# init  9 → MIS size  10, iters    25, time  0.0168s
# — Seed 20 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0118, min=0.0098, max=0.0168, std=0.0020
# Iters: mean=15.0, min=11, max=25, std=3.9
#
# ================== Seed 21 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=21): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    16, time  0.0130s
# init  1 → MIS size  10, iters    26, time  0.0176s
# init  2 → MIS size   9, iters    16, time  0.0125s
# init  3 → MIS size  10, iters    15, time  0.0119s
# init  4 → MIS size  10, iters    13, time  0.0107s
# init  5 → MIS size  10, iters    16, time  0.0121s
# init  6 → MIS size  10, iters    13, time  0.0109s
# init  7 → MIS size  10, iters    12, time  0.0100s
# init  8 → MIS size  10, iters    12, time  0.0098s
# init  9 → MIS size  10, iters    15, time  0.0113s
# — Seed 21 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0120, min=0.0098, max=0.0176, std=0.0022
# Iters: mean=15.4, min=12, max=26, std=4.1
#
# ================== Seed 22 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=22): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    15, time  0.0139s
# init  1 → MIS size   9, iters    16, time  0.0129s
# init  2 → MIS size   9, iters    15, time  0.0136s
# init  3 → MIS size   9, iters    39, time  0.0244s
# init  4 → MIS size  10, iters    13, time  0.0112s
# init  5 → MIS size  10, iters    14, time  0.0120s
# init  6 → MIS size  10, iters    36, time  0.0228s
# init  7 → MIS size   9, iters    13, time  0.0116s
# init  8 → MIS size   9, iters    21, time  0.0158s
# init  9 → MIS size  10, iters    16, time  0.0124s
# — Seed 22 summary —
# Best MIS size: 10 (trial 0)
# Runtime (s): mean=0.0150, min=0.0112, max=0.0244, std=0.0047
# Iters: mean=19.8, min=13, max=39, std=9.6
#
# ================== Seed 23 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=23): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    12, time  0.0112s
# init  1 → MIS size  11, iters    13, time  0.0113s
# init  2 → MIS size  11, iters    15, time  0.0126s
# init  3 → MIS size  10, iters    13, time  0.0109s
# init  4 → MIS size   9, iters    12, time  0.0106s
# init  5 → MIS size  10, iters    15, time  0.0121s
# init  6 → MIS size   9, iters    26, time  0.0180s
# init  7 → MIS size  10, iters    15, time  0.0118s
# init  8 → MIS size  10, iters    13, time  0.0113s
# init  9 → MIS size  10, iters    16, time  0.0144s
# — Seed 23 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0124, min=0.0106, max=0.0180, std=0.0022
# Iters: mean=15.0, min=12, max=26, std=4.1
#
# ================== Seed 24 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=24): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    17, time  0.0143s
# init  1 → MIS size  10, iters    12, time  0.0105s
# init  2 → MIS size  10, iters    12, time  0.0104s
# init  3 → MIS size  11, iters    12, time  0.0106s
# init  4 → MIS size   9, iters    16, time  0.0122s
# init  5 → MIS size   9, iters    13, time  0.0106s
# init  6 → MIS size  10, iters    15, time  0.0117s
# init  7 → MIS size   9, iters    12, time  0.0100s
# init  8 → MIS size  10, iters    12, time  0.0098s
# init  9 → MIS size   9, iters    16, time  0.0121s
# — Seed 24 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0112, min=0.0098, max=0.0143, std=0.0014
# Iters: mean=13.7, min=12, max=17, std=2.1
#
# ================== Seed 25 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=25): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    10, time  0.0103s
# init  1 → MIS size   9, iters    26, time  0.0179s
# init  2 → MIS size  10, iters    15, time  0.0126s
# init  3 → MIS size  10, iters    15, time  0.0125s
# init  4 → MIS size   8, iters    14, time  0.0113s
# init  5 → MIS size  11, iters    13, time  0.0106s
# init  6 → MIS size  10, iters    12, time  0.0106s
# init  7 → MIS size   9, iters    35, time  0.0220s
# init  8 → MIS size  10, iters    12, time  0.0105s
# init  9 → MIS size  10, iters    16, time  0.0126s
# — Seed 25 summary —
# Best MIS size: 11 (trial 5)
# Runtime (s): mean=0.0131, min=0.0103, max=0.0220, std=0.0039
# Iters: mean=16.8, min=10, max=35, std=7.7
#
# ================== Seed 26 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=26): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    19, time  0.0143s
# init  1 → MIS size  10, iters    13, time  0.0108s
# init  2 → MIS size   9, iters    15, time  0.0117s
# init  3 → MIS size   9, iters    14, time  0.0110s
# init  4 → MIS size  11, iters    15, time  0.0118s
# init  5 → MIS size  10, iters    13, time  0.0117s
# init  6 → MIS size  10, iters    12, time  0.0103s
# init  7 → MIS size  11, iters    18, time  0.0132s
# init  8 → MIS size  10, iters    14, time  0.0112s
# init  9 → MIS size  11, iters    14, time  0.0117s
# — Seed 26 summary —
# Best MIS size: 11 (trial 4)
# Runtime (s): mean=0.0118, min=0.0103, max=0.0143, std=0.0012
# Iters: mean=14.7, min=12, max=19, std=2.2
#
# ================== Seed 27 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=27): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    11, time  0.0106s
# init  1 → MIS size   9, iters    36, time  0.0232s
# init  2 → MIS size   9, iters    12, time  0.0103s
# init  3 → MIS size   9, iters    36, time  0.0236s
# init  4 → MIS size   9, iters    15, time  0.0124s
# init  5 → MIS size  10, iters    30, time  0.0195s
# init  6 → MIS size   9, iters    15, time  0.0118s
# init  7 → MIS size  10, iters    17, time  0.0126s
# init  8 → MIS size   9, iters    36, time  0.0226s
# init  9 → MIS size   9, iters    14, time  0.0115s
# — Seed 27 summary —
# Best MIS size: 10 (trial 5)
# Runtime (s): mean=0.0158, min=0.0103, max=0.0236, std=0.0057
# Iters: mean=22.2, min=11, max=36, std=10.9
#
# ================== Seed 28 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=28): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    36, time  0.0239s
# init  1 → MIS size  10, iters    16, time  0.0127s
# init  2 → MIS size  11, iters    15, time  0.0120s
# init  3 → MIS size   9, iters    12, time  0.0102s
# init  4 → MIS size   9, iters    36, time  0.0223s
# init  5 → MIS size  11, iters    27, time  0.0177s
# init  6 → MIS size   9, iters    12, time  0.0101s
# init  7 → MIS size  10, iters    15, time  0.0116s
# init  8 → MIS size  11, iters    12, time  0.0103s
# init  9 → MIS size   9, iters    13, time  0.0120s
# — Seed 28 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0143, min=0.0101, max=0.0239, std=0.0051
# Iters: mean=19.4, min=12, max=36, std=9.8
#
# ================== Seed 29 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=29): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    15, time  0.0127s
# init  1 → MIS size  10, iters    15, time  0.0122s
# init  2 → MIS size  11, iters    12, time  0.0105s
# init  3 → MIS size  11, iters    16, time  0.0126s
# init  4 → MIS size  10, iters    17, time  0.0127s
# init  5 → MIS size  10, iters    12, time  0.0108s
# init  6 → MIS size  10, iters    13, time  0.0106s
# init  7 → MIS size  11, iters    13, time  0.0107s
# init  8 → MIS size  12, iters    13, time  0.0106s
# init  9 → MIS size  10, iters    14, time  0.0111s
# — Seed 29 summary —
# Best MIS size: 12 (trial 8)
# Runtime (s): mean=0.0115, min=0.0105, max=0.0127, std=0.0010
# Iters: mean=14.0, min=12, max=17, std=1.7
#
# ================== Seed 30 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=30): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    15, time  0.0131s
# init  1 → MIS size  10, iters    16, time  0.0125s
# init  2 → MIS size  11, iters    16, time  0.0125s
# init  3 → MIS size  12, iters    16, time  0.0124s
# init  4 → MIS size  10, iters    12, time  0.0104s
# init  5 → MIS size  11, iters    12, time  0.0102s
# init  6 → MIS size   9, iters    16, time  0.0121s
# init  7 → MIS size  11, iters    21, time  0.0145s
# init  8 → MIS size  10, iters    15, time  0.0119s
# init  9 → MIS size   9, iters    15, time  0.0116s
# — Seed 30 summary —
# Best MIS size: 12 (trial 3)
# Runtime (s): mean=0.0121, min=0.0102, max=0.0145, std=0.0012
# Iters: mean=15.4, min=12, max=21, std=2.5
#
# ================== Seed 31 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=31): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    16, time  0.0132s
# init  1 → MIS size  10, iters    13, time  0.0111s
# init  2 → MIS size  11, iters    36, time  0.0224s
# init  3 → MIS size   9, iters    16, time  0.0132s
# init  4 → MIS size   9, iters    12, time  0.0103s
# init  5 → MIS size  10, iters    12, time  0.0102s
# init  6 → MIS size   9, iters    12, time  0.0103s
# init  7 → MIS size   9, iters    15, time  0.0113s
# init  8 → MIS size   9, iters    38, time  0.0232s
# init  9 → MIS size   9, iters    13, time  0.0111s
# — Seed 31 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0136, min=0.0102, max=0.0232, std=0.0050
# Iters: mean=18.3, min=12, max=38, std=10.0
#
# ================== Seed 32 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=32): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    36, time  0.0234s
# init  1 → MIS size  10, iters    41, time  0.0255s
# init  2 → MIS size   9, iters    12, time  0.0107s
# init  3 → MIS size  10, iters    16, time  0.0127s
# init  4 → MIS size   9, iters    21, time  0.0152s
# init  5 → MIS size  10, iters    16, time  0.0124s
# init  6 → MIS size  11, iters    15, time  0.0121s
# init  7 → MIS size  11, iters    12, time  0.0106s
# init  8 → MIS size   9, iters    36, time  0.0223s
# init  9 → MIS size   9, iters    15, time  0.0118s
# — Seed 32 summary —
# Best MIS size: 11 (trial 6)
# Runtime (s): mean=0.0157, min=0.0106, max=0.0255, std=0.0058
# Iters: mean=22.0, min=12, max=41, std=11.2
#
# ================== Seed 33 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=33): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    15, time  0.0128s
# init  1 → MIS size   9, iters    37, time  0.0242s
# init  2 → MIS size  11, iters    16, time  0.0129s
# init  3 → MIS size   9, iters    15, time  0.0126s
# init  4 → MIS size  10, iters    37, time  0.0232s
# init  5 → MIS size  10, iters    14, time  0.0113s
# init  6 → MIS size  10, iters    42, time  0.0252s
# init  7 → MIS size   9, iters    36, time  0.0221s
# init  8 → MIS size   9, iters    15, time  0.0118s
# init  9 → MIS size   9, iters    12, time  0.0101s
# — Seed 33 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0166, min=0.0101, max=0.0252, std=0.0062
# Iters: mean=23.9, min=12, max=42, std=12.3
#
# ================== Seed 34 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=34): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    15, time  0.0136s
# init  1 → MIS size   9, iters    12, time  0.0107s
# init  2 → MIS size   9, iters    12, time  0.0107s
# init  3 → MIS size   8, iters    12, time  0.0106s
# init  4 → MIS size  10, iters    32, time  0.0209s
# init  5 → MIS size  10, iters    39, time  0.0240s
# init  6 → MIS size  11, iters    47, time  0.0279s
# init  7 → MIS size  11, iters    13, time  0.0106s
# init  8 → MIS size   9, iters    16, time  0.0123s
# init  9 → MIS size  10, iters    15, time  0.0118s
# — Seed 34 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0153, min=0.0106, max=0.0279, std=0.0064
# Iters: mean=21.3, min=12, max=47, std=13.0
#
# ================== Seed 35 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=35): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    12, time  0.0113s
# init  1 → MIS size  11, iters    13, time  0.0108s
# init  2 → MIS size   9, iters    36, time  0.0224s
# init  3 → MIS size  10, iters    36, time  0.0222s
# init  4 → MIS size  11, iters    15, time  0.0115s
# init  5 → MIS size  11, iters    13, time  0.0107s
# init  6 → MIS size  11, iters    13, time  0.0106s
# init  7 → MIS size  10, iters    13, time  0.0106s
# init  8 → MIS size   9, iters     9, time  0.0082s
# init  9 → MIS size  11, iters    52, time  0.0304s
# — Seed 35 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0149, min=0.0082, max=0.0304, std=0.0074
# Iters: mean=21.2, min=9, max=52, std=14.6
#
# ================== Seed 36 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=36): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    14, time  0.0117s
# init  1 → MIS size   9, iters    12, time  0.0102s
# init  2 → MIS size  11, iters    12, time  0.0103s
# init  3 → MIS size  11, iters    16, time  0.0122s
# init  4 → MIS size  10, iters    36, time  0.0219s
# init  5 → MIS size  11, iters    16, time  0.0120s
# init  6 → MIS size   9, iters    15, time  0.0116s
# init  7 → MIS size   9, iters    14, time  0.0109s
# init  8 → MIS size  11, iters    15, time  0.0116s
# init  9 → MIS size   9, iters    12, time  0.0097s
# — Seed 36 summary —
# Best MIS size: 11 (trial 2)
# Runtime (s): mean=0.0122, min=0.0097, max=0.0219, std=0.0035
# Iters: mean=16.2, min=12, max=36, std=7.1
#
# ================== Seed 37 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=37): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    12, time  0.0112s
# init  1 → MIS size  11, iters    11, time  0.0101s
# init  2 → MIS size  10, iters    16, time  0.0123s
# init  3 → MIS size  10, iters    12, time  0.0105s
# init  4 → MIS size  11, iters    12, time  0.0105s
# init  5 → MIS size  10, iters    15, time  0.0115s
# init  6 → MIS size  11, iters    15, time  0.0133s
# init  7 → MIS size  10, iters    17, time  0.0132s
# init  8 → MIS size   9, iters    35, time  0.0222s
# init  9 → MIS size   9, iters    36, time  0.0223s
# — Seed 37 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0137, min=0.0101, max=0.0223, std=0.0046
# Iters: mean=18.1, min=11, max=36, std=9.4
#
# ================== Seed 38 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=38): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    12, time  0.0114s
# init  1 → MIS size  10, iters    11, time  0.0105s
# init  2 → MIS size  10, iters    15, time  0.0119s
# init  3 → MIS size   9, iters    16, time  0.0125s
# init  4 → MIS size   9, iters    16, time  0.0123s
# init  5 → MIS size  10, iters    13, time  0.0112s
# init  6 → MIS size   8, iters    12, time  0.0103s
# init  7 → MIS size  11, iters    11, time  0.0097s
# init  8 → MIS size  10, iters    16, time  0.0127s
# init  9 → MIS size  10, iters     9, time  0.0086s
# — Seed 38 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0111, min=0.0086, max=0.0127, std=0.0013
# Iters: mean=13.1, min=9, max=16, std=2.5
#
# ================== Seed 39 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=39): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    11, time  0.0107s
# init  1 → MIS size  10, iters    41, time  0.0267s
# init  2 → MIS size   9, iters    36, time  0.0231s
# init  3 → MIS size  10, iters    16, time  0.0122s
# init  4 → MIS size   9, iters    12, time  0.0106s
# init  5 → MIS size   9, iters    12, time  0.0104s
# init  6 → MIS size  10, iters    13, time  0.0113s
# init  7 → MIS size  10, iters    16, time  0.0124s
# init  8 → MIS size  11, iters    15, time  0.0116s
# init  9 → MIS size  11, iters    36, time  0.0222s
# — Seed 39 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0151, min=0.0104, max=0.0267, std=0.0063
# Iters: mean=20.8, min=11, max=41, std=11.8
#
# ================== Seed 40 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=40): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    14, time  0.0122s
# init  1 → MIS size  10, iters    15, time  0.0144s
# init  2 → MIS size  10, iters    14, time  0.0126s
# init  3 → MIS size  11, iters    15, time  0.0121s
# init  4 → MIS size   8, iters    14, time  0.0125s
# init  5 → MIS size   9, iters    17, time  0.0134s
# init  6 → MIS size   9, iters    15, time  0.0118s
# init  7 → MIS size  10, iters    14, time  0.0111s
# init  8 → MIS size  10, iters    36, time  0.0223s
# init  9 → MIS size  11, iters    15, time  0.0119s
# — Seed 40 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0134, min=0.0111, max=0.0223, std=0.0033
# Iters: mean=16.9, min=14, max=36, std=6.8
#
# ================== Seed 41 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=41): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    13, time  0.0112s
# init  1 → MIS size  10, iters    27, time  0.0182s
# init  2 → MIS size  10, iters    15, time  0.0122s
# init  3 → MIS size  11, iters    16, time  0.0125s
# init  4 → MIS size  10, iters    11, time  0.0098s
# init  5 → MIS size  10, iters    12, time  0.0102s
# init  6 → MIS size   9, iters    12, time  0.0111s
# init  7 → MIS size  10, iters    12, time  0.0105s
# init  8 → MIS size   9, iters    33, time  0.0212s
# init  9 → MIS size  10, iters    36, time  0.0229s
# — Seed 41 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0140, min=0.0098, max=0.0229, std=0.0049
# Iters: mean=18.7, min=11, max=36, std=9.5
#
# ================== Seed 42 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=42): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    13, time  0.0111s
# init  1 → MIS size  10, iters    15, time  0.0126s
# init  2 → MIS size   8, iters    12, time  0.0103s
# init  3 → MIS size  10, iters    13, time  0.0106s
# init  4 → MIS size   9, iters    68, time  0.0397s
# init  5 → MIS size  10, iters    12, time  0.0104s
# init  6 → MIS size   9, iters    15, time  0.0119s
# init  7 → MIS size  11, iters    38, time  0.0232s
# init  8 → MIS size  10, iters    12, time  0.0101s
# init  9 → MIS size  10, iters    35, time  0.0218s
# — Seed 42 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0162, min=0.0101, max=0.0397, std=0.0096
# Iters: mean=23.3, min=12, max=68, std=18.5
#
# ================== Seed 43 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=43): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    11, time  0.0106s
# init  1 → MIS size  11, iters    21, time  0.0157s
# init  2 → MIS size   9, iters    36, time  0.0235s
# init  3 → MIS size  10, iters    18, time  0.0138s
# init  4 → MIS size   9, iters    36, time  0.0225s
# init  5 → MIS size  10, iters    15, time  0.0119s
# init  6 → MIS size  10, iters    13, time  0.0116s
# init  7 → MIS size  11, iters    13, time  0.0110s
# init  8 → MIS size   8, iters    12, time  0.0109s
# init  9 → MIS size  11, iters    15, time  0.0121s
# — Seed 43 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0144, min=0.0106, max=0.0235, std=0.0048
# Iters: mean=19.0, min=11, max=36, std=9.4
#
# ================== Seed 44 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=44): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    16, time  0.0132s
# init  1 → MIS size  11, iters    13, time  0.0112s
# init  2 → MIS size  10, iters    14, time  0.0115s
# init  3 → MIS size  10, iters    12, time  0.0107s
# init  4 → MIS size  10, iters    21, time  0.0164s
# init  5 → MIS size  10, iters    13, time  0.0107s
# init  6 → MIS size   8, iters    15, time  0.0119s
# init  7 → MIS size   9, iters    12, time  0.0106s
# init  8 → MIS size   9, iters    14, time  0.0111s
# init  9 → MIS size  10, iters    12, time  0.0107s
# — Seed 44 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0118, min=0.0106, max=0.0164, std=0.0018
# Iters: mean=14.2, min=12, max=21, std=2.7
#
# ================== Seed 45 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=45): Projected Newton (free set) with MIS-check
# init  0 → MIS size  11, iters    17, time  0.0136s
# init  1 → MIS size   9, iters    26, time  0.0175s
# init  2 → MIS size  10, iters    16, time  0.0124s
# init  3 → MIS size  11, iters    39, time  0.0238s
# init  4 → MIS size   9, iters    27, time  0.0183s
# init  5 → MIS size  10, iters    12, time  0.0106s
# init  6 → MIS size  10, iters    36, time  0.0228s
# init  7 → MIS size  10, iters    14, time  0.0114s
# init  8 → MIS size   9, iters    15, time  0.0116s
# init  9 → MIS size   9, iters    37, time  0.0226s
# — Seed 45 summary —
# Best MIS size: 11 (trial 0)
# Runtime (s): mean=0.0164, min=0.0106, max=0.0238, std=0.0052
# Iters: mean=23.9, min=12, max=39, std=10.5
#
# ================== Seed 46 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=46): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    22, time  0.0163s
# init  1 → MIS size   9, iters    17, time  0.0134s
# init  2 → MIS size   9, iters    13, time  0.0112s
# init  3 → MIS size  11, iters    15, time  0.0124s
# init  4 → MIS size   9, iters    15, time  0.0135s
# init  5 → MIS size  10, iters    16, time  0.0126s
# init  6 → MIS size  10, iters    11, time  0.0101s
# init  7 → MIS size   8, iters    13, time  0.0117s
# init  8 → MIS size   9, iters    15, time  0.0121s
# init  9 → MIS size  10, iters    16, time  0.0124s
# — Seed 46 summary —
# Best MIS size: 11 (trial 3)
# Runtime (s): mean=0.0126, min=0.0101, max=0.0163, std=0.0016
# Iters: mean=15.3, min=11, max=22, std=2.9
#
# ================== Seed 47 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=47): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    14, time  0.0133s
# init  1 → MIS size   9, iters    16, time  0.0124s
# init  2 → MIS size  10, iters    36, time  0.0228s
# init  3 → MIS size   9, iters    15, time  0.0131s
# init  4 → MIS size  11, iters    17, time  0.0135s
# init  5 → MIS size  12, iters    12, time  0.0105s
# init  6 → MIS size  10, iters    14, time  0.0117s
# init  7 → MIS size  10, iters    13, time  0.0108s
# init  8 → MIS size  11, iters    15, time  0.0955s
# init  9 → MIS size  10, iters    14, time  0.0898s
# — Seed 47 summary —
# Best MIS size: 12 (trial 5)
# Runtime (s): mean=0.0293, min=0.0105, max=0.0955, std=0.0336
# Iters: mean=16.6, min=12, max=36, std=7.0
#
# ================== Seed 48 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=48): Projected Newton (free set) with MIS-check
# init  0 → MIS size   9, iters    16, time  0.0128s
# init  1 → MIS size  11, iters    27, time  0.0178s
# init  2 → MIS size  11, iters    36, time  0.0223s
# init  3 → MIS size   9, iters    12, time  0.0100s
# init  4 → MIS size   8, iters    12, time  0.0100s
# init  5 → MIS size   9, iters    26, time  0.0175s
# init  6 → MIS size  10, iters    17, time  0.0126s
# init  7 → MIS size  10, iters    16, time  0.0122s
# init  8 → MIS size   9, iters    18, time  0.0130s
# init  9 → MIS size  11, iters    16, time  0.0120s
# — Seed 48 summary —
# Best MIS size: 11 (trial 1)
# Runtime (s): mean=0.0140, min=0.0100, max=0.0223, std=0.0039
# Iters: mean=19.6, min=12, max=36, std=7.7
#
# ================== Seed 49 ==================
# Number of connected components: 1
# ER(500, 0.5, seed=49): Projected Newton (free set) with MIS-check
# init  0 → MIS size  10, iters    12, time  0.0110s
# init  1 → MIS size  10, iters    15, time  0.0119s
# init  2 → MIS size  10, iters    15, time  0.0119s
# init  3 → MIS size   9, iters    16, time  0.0126s
# init  4 → MIS size   8, iters    36, time  0.0228s
# init  5 → MIS size   9, iters    22, time  0.0156s
# init  6 → MIS size  10, iters    12, time  0.0100s
# init  7 → MIS size  11, iters    13, time  0.0104s
# init  8 → MIS size  11, iters    13, time  0.0103s
# init  9 → MIS size   9, iters    12, time  0.0098s
# — Seed 49 summary —
# Best MIS size: 11 (trial 7)
# Runtime (s): mean=0.0126, min=0.0098, max=0.0228, std=0.0040
# Iters: mean=16.6, min=12, max=36, std=7.5
#
# Projected Newton (free set) on ER(500,0.5) over seeds 0-49, 10 trials each, alpha0=1.0, beta=0.5, c1=0.0001
# Overall means:
#     seed  max_MIS_size  mean_iters  mean_time
# 0      0            11        23.0   0.016604
# 1      1            12        19.8   0.015136
# 2      2            11       165.5   0.092919
# 3      3            11        19.6   0.014558
# 4      4            11        15.6   0.012304
# 5      5            11        14.1   0.011736
# 6      6            11        12.9   0.011519
# 7      7            11        20.3   0.014551
# 8      8            11        21.6   0.015663
# 9      9            11        20.0   0.014621
# 10    10            11        23.8   0.020015
# 11    11            11        14.9   0.011830
# 12    12            12        14.1   0.011621
# 13    13            12        15.3   0.012177
# 14    14            11        14.2   0.011390
# 15    15            11        13.7   0.011688
# 16    16            11        16.3   0.012645
# 17    17            11        14.7   0.011443
# 18    18            12        18.0   0.013373
# 19    19            11        16.5   0.012775
# 20    20            11        15.0   0.011791
# 21    21            11        15.4   0.011995
# 22    22            10        19.8   0.015039
# 23    23            11        15.0   0.012432
# 24    24            11        13.7   0.011209
# 25    25            11        16.8   0.013093
# 26    26            11        14.7   0.011784
# 27    27            10        22.2   0.015805
# 28    28            11        19.4   0.014280
# 29    29            12        14.0   0.011451
# 30    30            12        15.4   0.012136
# 31    31            11        18.3   0.013627
# 32    32            11        22.0   0.015657
# 33    33            11        23.9   0.016632
# 34    34            11        21.3   0.015316
# 35    35            11        21.2   0.014871
# 36    36            11        16.2   0.012207
# 37    37            11        18.1   0.013706
# 38    38            11        13.1   0.011120
# 39    39            11        20.8   0.015121
# 40    40            11        16.9   0.013441
# 41    41            11        18.7   0.013985
# 42    42            11        23.3   0.016173
# 43    43            11        19.0   0.014362
# 44    44            11        14.2   0.011793
# 45    45            11        23.9   0.016448
# 46    46            11        15.3   0.012566
# 47    47            12        16.6   0.029340
# 48    48            11        19.6   0.014033
# 49    49            11        16.6   0.012639
#
# Fair means (exclude init 0 per seed):
#     seed  max_MIS_size  mean_iters_fair  mean_time_fair
# 0      0            11        21.666667        0.015902
# 1      1            12        20.333333        0.015418
# 2      2            11       181.777778        0.101518
# 3      3            11        20.000000        0.014656
# 4      4            11        16.222222        0.012567
# 5      5            11        14.222222        0.011774
# 6      6            11        12.888889        0.011509
# 7      7            11        21.222222        0.014945
# 8      8            11        21.777778        0.015698
# 9      9            11        20.666667        0.014881
# 10    10            11        24.888889        0.018024
# 11    11            11        15.111111        0.011898
# 12    12            12        13.888889        0.011448
# 13    13            12        15.222222        0.012075
# 14    14            11        13.777778        0.011104
# 15    15            11        13.888889        0.011755
# 16    16            11        16.333333        0.012606
# 17    17            11        14.666667        0.011355
# 18    18            12        18.333333        0.013508
# 19    19            11        16.444444        0.012675
# 20    20            11        15.333333        0.011935
# 21    21            11        15.333333        0.011881
# 22    22            10        20.333333        0.015170
# 23    23            11        15.333333        0.012573
# 24    24            11        13.333333        0.010865
# 25    25            11        17.555556        0.013405
# 26    26            11        14.222222        0.011504
# 27    27            10        23.444444        0.016382
# 28    28            11        17.555556        0.013212
# 29    29            12        13.888889        0.011313
# 30    30            12        15.444444        0.012034
# 31    31            11        18.555556        0.013677
# 32    32            11        20.444444        0.014799
# 33    33            11        24.888889        0.017054
# 34    34            11        22.000000        0.015512
# 35    35            11        22.222222        0.015263
# 36    36            11        16.444444        0.012258
# 37    37            11        18.777778        0.013989
# 38    38            11        13.222222        0.011092
# 39    39            11        21.888889        0.015615
# 40    40            11        17.222222        0.013577
# 41    41            11        19.333333        0.014290
# 42    42            11        24.444444        0.016736
# 43    43            11        19.888889        0.014776
# 44    44            11        14.000000        0.011638
# 45    45            11        24.666667        0.016770
# 46    46            11        14.555556        0.012156
# 47    47            12        16.888889        0.031124
# 48    48            11        20.000000        0.014168
# 49    49            11        17.111111        0.012821

# %%
## Prelim Newton method ##

import torch
import networkx as nx
import numpy as np
import pandas as pd
import time

# Fixed method parameters
n = 500
p = 0.5
gamma_c = 1
exploration_parameter_eta = 2.0
max_iters = 1500
tol = 1e-8
damping0 = 1e-3
ls_iters = 10
alpha0 = 900   # fixed learning rate
beta = 0.6    # fixed backtracking scale
N_TRIALS = 10  # number of random initializations per graph

# Functions
def objective(x, H):
    return -x.sum() + 0.5 * x @ (H @ x)

def gradient(x, H):
    return -torch.ones_like(x) + H @ x

def MIS_checker_efficient_3(X, A, A_bar):
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones_like(Xb) + (n * A) @ Xb)
    Xb_up.clamp_(0,1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

def projected_newton(H, A, A_bar, x0):
    x = x0.clone()
    damping = damping0
    I = torch.eye(n, dtype=H.dtype)
    H_damped = H + damping * I
    history = []
    is_MIS = False
    MIS = None

    for it in range(max_iters):
        g = gradient(x, H)
        g_norm = g.norm().item()
        f0 = objective(x, H).item()
        history.append((it, f0, g_norm))
        if g_norm < tol:
            break

        try:
            p = torch.linalg.solve(H_damped, g)
        except RuntimeError:
            damping *= 10
            H_damped = H + damping * I
            continue

        alpha = alpha0
        accepted = False
        for _ in range(ls_iters):
            x_trial = torch.clamp(x - alpha * p, 0.0, 1.0)
            if objective(x_trial, H).item() < f0:
                x = x_trial
                accepted = True
                break
            alpha *= beta

        if not accepted:
            damping *= 10

        damping = max(damping * 0.5, 1e-7)
        H_damped = H + damping * I

        is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
        if is_MIS:
            break

    return x, history, is_MIS, MIS

# Main batch testing over seeds 0-49
summaries = []
for seed in range(50):
    # Build graph for this seed
    g = nx.gnp_random_graph(n, p, seed=seed)
    A = torch.tensor(nx.adjacency_matrix(g).todense(), dtype=torch.float32)
    A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(g)).todense(), dtype=torch.float32)

    # Build H
    degrees_c = dict(nx.complement(g).degree())
    gamma = 2 + max(degrees_c.values())
    H = gamma * A - gamma_c * A_bar

    # Degree init vector
    degrees = dict(g.degree())
    max_deg = max(degrees.values())
    d = torch.zeros(n)
    for node, deg in degrees.items():
        d[node] = 1 - deg / max_deg
    d_init = d / d.max()

    # Covariance
    cov = exploration_parameter_eta * torch.eye(n)

    # Run multiple trials
    trial_stats = []
    for init in range(N_TRIALS):
        if init == 0:
            x0 = d_init.clone()
        else:
            torch.manual_seed((seed << 16) + init)
            x0 = torch.normal(mean=d_init, std=torch.sqrt(torch.diag(cov)))
            x0 = torch.clamp(x0, 0.0, 1.0)

        start = time.time()
        x_opt, history, is_MIS, MIS = projected_newton(H, A, A_bar, x0)
        elapsed = time.time() - start
        trial_stats.append({
            'iters': len(history),
            'time': elapsed,
            'MIS_size': MIS.numel() if is_MIS else 0
        })

    df = pd.DataFrame(trial_stats)
    summaries.append({
        'seed': seed,
        'max_MIS_size': int(df.MIS_size.max()),
        'mean_iters': df.iters.mean(),
        'mean_time': df.time.mean()
    })

# Aggregate and display results
df_summary = pd.DataFrame(summaries)
print(f"Damped Projected Newton on ER({n},{p}) over seeds 0-49, 10 trials each, alpha={alpha0}, beta={beta}")
print(df_summary)

# Optionally save to CSV
# df_summary.to_csv('newton_seed_summary.csv', index=False)
# Out:
# Damped Projected Newton on ER(500,0.5) over seeds 0-49, 10 trials each, alpha=900, beta=0.6
#     seed  max_MIS_size  mean_iters  mean_time
# 0      0            12        86.5   0.212316
# 1      1            11        72.5   0.156849
# 2      2            11        62.5   0.140046
# 3      3            11        66.5   0.142900
# 4      4            12        67.0   0.144347
# 5      5            10        81.2   0.172164
# 6      6            11        68.9   0.149604
# 7      7            12        96.8   0.278866
# 8      8            11        80.5   0.173906
# 9      9            10        85.2   0.181120
# 10    10            11        71.5   0.153822
# 11    11            11        74.7   0.161315
# 12    12            11       101.3   0.213111
# 13    13            11        67.2   0.144568
# 14    14            11        58.6   0.129787
# 15    15            11        69.5   0.150102
# 16    16            11        71.6   0.155345
# 17    17            12        66.5   0.142915
# 18    18            11        74.2   0.158869
# 19    19            11        76.8   0.166419
# 20    20            11        84.0   0.179679
# 21    21            12        70.1   0.149811
# 22    22            10        82.9   0.177459
# 23    23            11        76.9   0.163574
# 24    24            12        69.0   0.148032
# 25    25            12        89.7   0.190418
# 26    26            12       109.0   0.227006
# 27    27            11        76.2   0.162580
# 28    28            11        59.9   0.129801
# 29    29            11        64.1   0.138070
# 30    30            10        66.3   0.142454
# 31    31            11        91.9   0.193982
# 32    32            11        65.1   0.141260
# 33    33            11        84.2   0.179013
# 34    34            11       116.5   0.240129
# 35    35            11        87.1   0.185198
# 36    36            11        75.8   0.161643
# 37    37            11       129.1   0.266106
# 38    38            11        85.7   0.180377
# 39    39            12        82.4   0.175141
# 40    40            11        65.0   0.140462
# 41    41            12        68.1   0.147359
# 42    42            11        68.8   0.148280
# 43    43            11        68.3   0.146315
# 44    44            11        67.4   0.144104
# 45    45            10        68.5   0.147393
# 46    46            11        67.2   0.145104
# 47    47            11        70.6   0.151708
# 48    48            10        69.7   0.149216
# 49    49            11        66.7   0.143291

# %% [markdown]
# ## Time Limit Testing ##

# %%
# %% [markdown]
# Time-limited Free-set Projected Newton for relaxed MIS (best-within-time per seed)

# %%
import torch
import networkx as nx
import numpy as np
import pandas as pd
import time

# ===========================
# Fixed method parameters
# ===========================
n = 5000
p = 0.5
gamma_c = 1
exploration_parameter_eta = 2.0

max_iters = 150
tol = 1e-8
damping0 = 1e-3

# Free-set Newton line-search defaults (robust)
alpha0 = 1.0     # starting step (smaller is safer with projection)
beta   = 0.5     # backtracking factor
ls_iters = 20    # allow deeper backtracking
c1 = 1e-4        # Armijo sufficient decrease (set to None to use simple decrease)

# Time budget per seed
TIME_LIMIT = 50  # seconds

# ===========================
# Objective, gradient, MIS checker
# ===========================
def objective(x: torch.Tensor, H: torch.Tensor) -> float:
    # f(x) = -1^T x + 1/2 x^T H x
    return float((-x.sum() + 0.5 * (x @ (H @ x))).item())

def gradient(x: torch.Tensor, H: torch.Tensor) -> torch.Tensor:
    return -torch.ones_like(x) + H @ x

def MIS_checker_efficient_3(X: torch.Tensor, A: torch.Tensor, A_bar: torch.Tensor):
    Xb = X.bool().float()
    Xb_up = Xb - 0.1 * (-torch.ones_like(Xb) + (n * A) @ Xb)
    Xb_up.clamp_(0,1)
    if torch.equal(Xb, Xb_up):
        return True, torch.nonzero(Xb).squeeze()
    return False, None

# ===========================
# Free-mask Projected Newton
# ===========================
@torch.no_grad()
def projected_newton_free(
    H: torch.Tensor, A: torch.Tensor, A_bar: torch.Tensor, x0: torch.Tensor,
    max_iters: int = max_iters, tol: float = tol,
    alpha0: float = alpha0, beta: float = beta,
    ls_iters: int = ls_iters, damping0: float = damping0,
    c1: float | None = c1
):
    """
    Projected Newton with L-BFGS-B-style free set.
    Solve (H_FF + λ I) d_F = g_F, take descent p = -d on F (zero elsewhere),
    update x_new = clamp(x + α p, 0, 1). Early exit on MIS.
    """
    x = x0.clone()
    damping = damping0
    history = []
    is_MIS = False
    MIS = None

    cached_free_idx = None
    cached_damping = None
    L_cached = None
    eye_cache = None

    for it in range(1, max_iters + 1):
        g = gradient(x, H)
        g_norm = float(g.norm().item())
        f0 = objective(x, H)
        history.append((it - 1, f0, g_norm))
        if g_norm < tol:
            break

        # L-BFGS-B free-set rule
        F_mask = ((x > 0.0 + 1e-10) & (x < 1.0 - 1e-10)) \
                 | ((x <= 0.0 + 1e-10) & (g < 0)) \
                 | ((x >= 1.0 - 1e-10) & (g > 0))
        free_idx = torch.nonzero(F_mask, as_tuple=False).flatten()

        # If nothing free, take small projected steepest-descent nudge
        if free_idx.numel() == 0:
            p = -g
            p[(x <= 0.0 + 1e-12) & (p < 0)] = 0.0
            p[(x >= 1.0 - 1e-12) & (p > 0)] = 0.0
            if float(p.norm().item()) < 1e-14:
                break

            alpha = alpha0
            accepted = False
            for _ in range(ls_iters):
                x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
                if objective(x_trial, H) < f0:
                    x = x_trial
                    accepted = True
                    break
                alpha *= beta
            if not accepted:
                break

            is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
            if is_MIS:
                break
            continue

        # Reduced Newton solve on free set: (H_ff + λI) d_f = g_f
        g_f = g[free_idx]

        need_refactor = (
            L_cached is None or
            cached_damping is None or
            cached_free_idx is None or
            (cached_damping != damping) or
            (cached_free_idx.numel() != free_idx.numel()) or
            (not torch.equal(cached_free_idx, free_idx))
        )

        if need_refactor:
            H_ff = H.index_select(0, free_idx).index_select(1, free_idx)
            H_ff = 0.5 * (H_ff + H_ff.T)
            k = H_ff.shape[0]
            if (eye_cache is None) or (eye_cache.shape[0] != k):
                eye_cache = torch.eye(k, dtype=H_ff.dtype, device=H_ff.device)
            H_ff_damped = H_ff + damping * eye_cache

            # Build/repair Cholesky by adapting damping
            built = False
            for _ in range(10):
                try:
                    L_cached = torch.linalg.cholesky(H_ff_damped)
                    cached_free_idx = free_idx.clone()
                    cached_damping = damping
                    built = True
                    break
                except RuntimeError:
                    damping *= 10.0
                    H_ff_damped = H_ff + damping * eye_cache
            if not built:
                # fallback: projected steepest-descent on free set
                p = torch.zeros_like(g)
                p[free_idx] = -g_f
                alpha = alpha0
                accepted = False
                for _ in range(ls_iters):
                    x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
                    if objective(x_trial, H) < f0:
                        x = x_trial
                        accepted = True
                        break
                    alpha *= beta
                if not accepted:
                    damping = min(max(damping * 2.0, 1e-7), 1e7)
                else:
                    damping = max(damping * 0.5, 1e-7)
                is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
                if is_MIS:
                    break
                continue

        # Solve for d_f, then descent direction p = -d
        d_f = torch.cholesky_solve(g_f.unsqueeze(1), L_cached).squeeze(1)
        p = torch.zeros_like(g); p[free_idx] = -d_f

        # Guard: ensure descent slope; if not, use -grad on free set
        slope = float((g[free_idx] * p[free_idx]).sum().item())
        if slope >= 0:
            p.zero_(); p[free_idx] = -g_f

        # Projected backtracking (Armijo if c1 else simple)
        alpha = alpha0
        accepted = False
        for _ in range(ls_iters):
            x_trial = torch.clamp(x + alpha * p, 0.0, 1.0)
            f_trial = objective(x_trial, H)
            if c1 is None:
                ok = (f_trial < f0)
            else:
                s = float((g[free_idx] * p[free_idx]).sum().item())
                ok = (s < 0) and (f_trial <= f0 + c1 * alpha * s)
            if ok:
                x = x_trial
                accepted = True
                break
            alpha *= beta

        if not accepted:
            damping = min(max(damping * 10.0, 1e-7), 1e7)
            L_cached = None; cached_free_idx = None; cached_damping = None
        else:
            damping = max(damping * 0.5, 1e-7)

        is_MIS, MIS = MIS_checker_efficient_3(x, A, A_bar)
        if is_MIS:
            break

    return x, history, is_MIS, MIS

# ===========================
# Main batch testing over seeds 0-9 with time-limited trials
# ===========================
summaries = []
for seed in range(10):
    # Build graph for this seed
    g = nx.gnp_random_graph(n, p, seed=seed)
    A = torch.tensor(nx.adjacency_matrix(g).todense(), dtype=torch.float32)
    A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(g)).todense(), dtype=torch.float32)

    # Build H (PSD default for stability; switch to original by uncommenting the second line)
    degrees_c = dict(nx.complement(g).degree())
    gamma = 2 + (max(degrees_c.values()) if degrees_c else 0)
    H = gamma * A             # PSD version (recommended)
    # H = gamma * A - gamma_c * A_bar  # original variant (may be indefinite on free blocks)

    # Degree init vector
    degrees = dict(g.degree())
    max_deg = max(degrees.values())
    d = torch.tensor([1 - degrees[i]/max_deg for i in range(n)], dtype=torch.float32)
    d_init = d / d.max()

    # Covariance
    cov = exploration_parameter_eta * torch.eye(n)

    # Run as many trials as will fit in TIME_LIMIT
    trial = 0
    trial_stats = []
    print(f"ER({n}, {p}, seed {seed}): Free-set Projected Newton (time limit {TIME_LIMIT}s)")

    seed_start = time.time()
    while True:
        if time.time() - seed_start > TIME_LIMIT:
            break

        # prepare init
        if trial == 0:
            x0 = d_init.clone()
        else:
            # deterministic per (seed, trial); matches your baseline style
            torch.manual_seed((seed << 16) + trial)
            x0 = torch.normal(mean=d_init, std=torch.sqrt(torch.diag(cov)))
            x0.clamp_(0.0, 1.0)

        # run Free-set Newton
        t0 = time.time()
        x_opt, history, is_MIS, MIS = projected_newton_free(
            H, A, A_bar, x0,
            alpha0=alpha0, beta=beta, ls_iters=ls_iters, c1=c1
        )
        elapsed = time.time() - t0

        trial_stats.append({
            'iters': len(history),
            'time': elapsed,
            'MIS_size': int(MIS.numel()) if is_MIS else 0
        })
        # print(f" trial {trial:2d} → iters {len(history):4d}, time {elapsed:7.4f}s, MIS_size {trial_stats[-1]['MIS_size']}")
        trial += 1

    # summarize for this seed
    df = pd.DataFrame(trial_stats)
    if not df.empty:
        summaries.append({
            'seed': seed,
            'n_trials':   len(df),
            'max_MIS_size': int(df.MIS_size.max()),
            'mean_iters': float(df.iters.mean()),
            'mean_time':  float(df.time.mean())
        })
    else:
        summaries.append({
            'seed': seed,
            'n_trials':   0,
            'max_MIS_size': 0,
            'mean_iters': 0.0,
            'mean_time':  0.0
        })

# Aggregate and display results
df_summary = pd.DataFrame(summaries)
print("\nFree-set Projected Newton (time-limited) summary:")
print(df_summary)

avg_best = df_summary['max_MIS_size'].mean()
print(f"\nER({n}, {p}): Free-set Newton with MIS-check early exit, up to {TIME_LIMIT}s per seed")
print(f"Average of best MIS size across seeds: {avg_best:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 214
#     211 summaries = []
#     212 for seed in range(10):
#     213     # Build graph for this seed
# --> 214     g = nx.gnp_random_graph(n, p, seed=seed)
#     215     A = torch.tensor(nx.adjacency_matrix(g).todense(), dtype=torch.float32)
#     216     A_bar = torch.tensor(nx.adjacency_matrix(nx.complement(g)).todense(), dtype=torch.float32)
#
# File ~/.conda/envs/pytorch/lib/python3.13/site-packages/networkx/utils/decorators.py:789, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     788 def func(*args, __wrapper=None, **kwargs):
# --> 789     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:4, in argmap_gnp_random_graph_1(n, p, seed, directed, backend, **backend_kwargs)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~/.conda/envs/pytorch/lib/python3.13/site-packages/networkx/utils/backends.py:633, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     628 """Returns the result of the original function, or the backend function if
#     629 the backend is specified and that backend implements `func`."""
#     631 if not backends:
#     632     # Fast path if no backends are installed
# --> 633     return self.orig_func(*args, **kwargs)
#     635 # Use `backend_name` in this function instead of `backend`
#     636 backend_name = backend
#
# File ~/.conda/envs/pytorch/lib/python3.13/site-packages/networkx/generators/random_graphs.py:167, in gnp_random_graph(n, p, seed, directed)
#     165 for e in edges:
#     166     if seed.random() < p:
# --> 167         G.add_edge(*e)
#     168 return G
#
# File ~/.conda/envs/pytorch/lib/python3.13/site-packages/networkx/classes/graph.py:963, in Graph.add_edge(self, u_of_edge, v_of_edge, **attr)
#     961 # add the edge
#     962 datadict = self._adj[u].get(v, self.edge_attr_dict_factory())
# --> 963 datadict.update(attr)
#     964 self._adj[u][v] = datadict
#     965 self._adj[v][u] = datadict
#
# KeyboardInterrupt:

# %%
# With complement 

def build_upper_edge_list_from_graph(G: nx.Graph):
    """
    Store the edges of the undirected graph G as an edge list in upper triangular form (u < v).

    U, V: 1D torch.long tensors (length = number of edges |E|),
    representing the two endpoint indices (u, v) for each edge, where u < v.
    """
    edges = []
    for u, v in G.edges():
        if u == v: # Exclude self-loops
            continue
        if u > v:
            u, v = v, u
        edges.append((u, v))

    if not edges:
        # The case with no edges
        return torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long)

    U = torch.tensor([e[0] for e in edges], dtype=torch.long)
    V = torch.tensor([e[1] for e in edges], dtype=torch.long)
    return U, V


def sample_edge_sublist(U: torch.Tensor, V: torch.Tensor, p_keep: float):
    """
    Perform Bernoulli sampling for each "undirected edge" (u<v) to keep it with probability p_keep.
    Return the selected sub-edge list U_sub, V_sub (still in the u<v upper triangular form).
    """
    assert U.dtype == torch.long and V.dtype == torch.long
    assert U.shape == V.shape

    m = U.numel()
    mask = torch.rand(m) < p_keep
    idx = mask.nonzero(as_tuple=False).squeeze(1)

    if idx.numel() == 0:
        # When no edges are sampled, return an empty sublist.
        return torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long)

    return U.index_select(0, idx), V.index_select(0, idx)


def matrix_free_spmv(U_sub, V_sub, x, n, p_keep):
    """
    Matrix-Free Sparse Matrix-Vector Product
    y = (A_sub / p_keep) @ x
    """
    if U_sub.numel() == 0:
        return torch.zeros(n, dtype=x.dtype)

    y = torch.zeros(n, dtype=x.dtype)
    x_v = x.index_select(0, V_sub)
    x_u = x.index_select(0, U_sub)

    # y[u] += x[v] and y[v] += x[u]
    y.scatter_add_(0, U_sub, x_v)
    y.scatter_add_(0, V_sub, x_u)

    return y / p_keep

def partition_graph_edges(U: torch.Tensor, V: torch.Tensor, num_subgraphs: int):
    """
    Randomly shuffles the graph's edge list and partitions it into a specified number of subgraphs.

    Args:
        U (torch.Tensor): Tensor of source nodes for all edges.
        V (torch.Tensor): Tensor of destination nodes for all edges.
        num_subgraphs (int): The number of partitions to create.

    Returns:
        list: A list of tuples, where each tuple (U_sub, V_sub) represents an edge list
              of a subgraph partition.
    """
    num_edges = U.numel()
    # 处理没有边的情况
    if num_edges == 0:
        empty_subgraph = (torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long))
        return [empty_subgraph] * num_subgraphs

    # 创建一个随机的索引排列
    shuffled_indices = torch.randperm(num_edges)

    # 使用这个排列来打乱整个图的边列表
    U_shuffled = U[shuffled_indices]
    V_shuffled = V[shuffled_indices]

    # 将打乱后的边列表分割成 num_subgraphs个块
    U_chunks = torch.chunk(U_shuffled, num_subgraphs)
    V_chunks = torch.chunk(V_shuffled, num_subgraphs)

    # 将分块后的 (U, V) 对打包成列表并返回
    subgraph_partitions = list(zip(U_chunks, V_chunks))
    return subgraph_partitions


def check_maximal_independent_set(X_torch, n, edges_g_set):
    """
    Check whether a solution is a Maximal Independent Set based on an edge list (hash set).
    """
    # 1. Retrieve the candidate node set
    X_binarized = X_torch.bool()
    S_nodes_tensor = X_binarized.nonzero(as_tuple=False).squeeze(1)
    S_nodes_set = set(S_nodes_tensor.tolist())

    # 2. Check whether S is an independent set:
    # iterate through all node pairs in S, and if any pair is found in the edge hash set, then S is not an IS
    for u in S_nodes_tensor:
        for v in S_nodes_tensor:
            if u >= v: continue
            if (u.item(), v.item()) in edges_g_set:
                return False, None

    # 3. Check whether S is a maximal independent set:
    # iterate through all nodes w not in S, and check whether w can be added to S
    all_nodes = set(range(n))
    outside_nodes = all_nodes - S_nodes_set

    for w in outside_nodes:
        can_be_added = True
        for s_node in S_nodes_set:
            u, v = min(w, s_node), max(w, s_node)
            if (u, v) in edges_g_set:
                can_be_added = False
                break
        if can_be_added:
            # If there exists a node that can be added, then S is not maximal
            return False, None

    # If all checks are passed, then S is a Maximal Independent Set
    return True, S_nodes_tensor

#########################################################################
# Begin
#########################################################################
# node_list = [500, 1000, 2000, 3000, 5000]
node_list = [500, 1000]
# node_list = [2000]
p = 0.5

# num_subgraphs = 5
num_subgraphs = 10

TIME_LIMIT = 5
# TIME_LIMIT = 10

with open("sparse_partition_subgraph_with_complement.txt", "w") as f:
    for n in node_list:
        best_list = []
        conv_iters_all = []
        for seed in range(10):
            print(f"\n===== Running for n = {n}, seed = {seed} =====")
            f.write(f"Number of nodes n = {n}\n")
            f.write(f"Edge probability p = {p}\n")
            f.write(f"Graph Seed = {seed}\n")
            f.write("Results for each epoch:\n")

            G = nx.gnp_random_graph(n, p, seed=seed)

            # Completely remove all adjacency matrix constructions and use only edge lists.
            print(f"Graph has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
            U, V = build_upper_edge_list_from_graph(G)

            # Precompute a hash set of edges for efficient lookup in the MIS checker
            edges_g_set = set(zip(U.tolist(), V.tolist()))

            # Construct the edge list of the complement graph, then discard the complement graph object
            complement_G = nx.complement(G)
            U_comp, V_comp = build_upper_edge_list_from_graph(complement_G)
            del complement_G  # Free up memory

            # --------------------------------------------------------------------------
            ### Here, we set gamma, gamma', and beta.
            gamma_c = 1.01

            # Compute the degree in the complement graph
            degrees_g = dict(G.degree())
            degrees_c = {node: (n - 1) - degree for node, degree in degrees_g.items()}
            max_degree = max(degrees_c.values()) if degrees_c else 0
            gamma = 2 + max_degree
            # --------------------------------------------------------------------------

            beta = 0.8
            alpha = 0.0001

            if (n == 3000 or n == 5000) and num_subgraphs == 10:
                alpha = 0.00001

            ITERATION_T = 150
            if n == 3000 or n == 5000:
                ITERATION_T = 300

            epoch = 50

            # Degree-based initialization
            degrees = dict(G.degree())
            max_degree_node = max(degrees.values()) if degrees else 1
            d = torch.zeros(n)
            for node, degree in G.degree():
                d[node] = 1 - (degree / max_degree_node)
            if max(d) > 0: d = d / max(d)

            input_velocity = torch.zeros(n)
            exploration_parameter_eta = 2.0
            covariance_matrix = exploration_parameter_eta * torch.eye(len(d))
            best_MIS_size = 0
            best_epoch = -1
            best_iter = -1
            conv_iters_seed = []

            # p_keep参数现在用于缩放梯度，其值等于子图中边的比例
            p_keep_for_scaling = 1.0 / num_subgraphs

            # ===============================================================
            # time limit
            start_time = time.time()

            init = -1

            while time.time() - start_time < TIME_LIMIT:
                init = init + 1
                if time.time() - start_time > TIME_LIMIT:
                    break

            # for init in range(epoch):
                if init == 0:
                    input_tensor = d.clone()
                else:
                    torch.manual_seed(init + seed)  # Ensure that each random initialization is different
                    input_tensor = torch.normal(mean=d, std=torch.sqrt(torch.diag(covariance_matrix)))

                input_velocity = torch.zeros(n)
                converged = False
                conv_iter = None
                MIS_size = 0

                # To get the subgraph
                # -----------------------------------------------------------------------
                subgraph_partitions = partition_graph_edges(U, V, num_subgraphs)
                subgraph_partitions_comp = partition_graph_edges(U_comp, V_comp, num_subgraphs)
                # -----------------------------------------------------------------------

                for iteration in range(ITERATION_T):
                    # 从预先生成的子图分区列表中循环选择当前迭代所用的子图
                    U_sub, V_sub = subgraph_partitions[iteration % num_subgraphs]
                    U_comp_sub, V_comp_sub = subgraph_partitions_comp[iteration % num_subgraphs]

                    # Compute gradient components using a matrix-free method
                    ax = matrix_free_spmv(U_sub, V_sub, input_tensor, n, p_keep_for_scaling)
                    acx = matrix_free_spmv(U_comp_sub, V_comp_sub, input_tensor, n, p_keep_for_scaling)

                    # Synthesize the final gradient
                    gradient = -torch.ones(n) + (gamma * ax - gamma_c * acx)
                    # gradient = -torch.ones(n) + gamma * ax
                    # ----------------------------------------

                    input_velocity = beta * input_velocity + alpha * gradient
                    input_tensor = torch.clamp(input_tensor - input_velocity, 0, 1)

                    # Call the new edge-list-based MIS checker
                    Checker, MIS = check_maximal_independent_set(input_tensor, n, edges_g_set)

                    if Checker:
                        MIS_size = MIS.numel()
                        conv_iter = iteration
                        converged = True
                        break

                if converged:
                    conv_iters_seed.append(conv_iter)
                    # f.write(
                    #     f"Epoch {init}, MIS size = {MIS_size}, converged at iteration = {conv_iter}\n"
                    # )
                    if MIS_size > best_MIS_size:
                        best_MIS_size = MIS_size
                        best_epoch = init
                        best_iter = conv_iter
                # else:
                #     f.write(f"Epoch {init}, No convergence (ran {ITERATION_T} iterations)\n")

            best_list.append(best_MIS_size)
            if conv_iters_seed:
                avg_conv_iter = np.mean(conv_iters_seed)
                conv_iters_all.extend(conv_iters_seed)
                f.write(f"\nAverage convergence iteration (this seed) = {avg_conv_iter:.2f}\n")
            else:
                f.write("\nNo epoch converged in this seed.\n")
            f.write(f"\nBest MIS size = {best_MIS_size}\n")
            f.write(f"\n=============================================\n")
            print(f"n={n}, seed={seed}, best MIS size = {best_MIS_size}")

        avg_best = np.mean(best_list) if best_list else 0
        if conv_iters_all:
            avg_conv_all = np.mean(conv_iters_all)
            f.write(
                f"\n=**********************************************************************************************************\n")
            f.write(f"Average Best MIS size over {len(best_list)} seeds = {avg_best:.2f}\n")
            f.write(f"Average convergence iteration over all converged epochs = {avg_conv_all:.2f}\n")
            f.write(
                f"=************************************************************************************************************\n\n")
        else:
            f.write("\nNo convergence across all seeds.\n")
# Out:
# ===== Running for n = 500, seed = 0 =====
# Graph has 500 nodes and 62475 edges.
# n=500, seed=0, best MIS size = 12
#
# ===== Running for n = 500, seed = 1 =====
# Graph has 500 nodes and 62440 edges.
# n=500, seed=1, best MIS size = 13
#
# ===== Running for n = 500, seed = 2 =====
# Graph has 500 nodes and 62205 edges.
# n=500, seed=2, best MIS size = 12
#
# ===== Running for n = 500, seed = 3 =====
# Graph has 500 nodes and 62556 edges.
# n=500, seed=3, best MIS size = 12
#
# ===== Running for n = 500, seed = 4 =====
# Graph has 500 nodes and 62558 edges.
# n=500, seed=4, best MIS size = 12
#
# ===== Running for n = 500, seed = 5 =====
# Graph has 500 nodes and 62598 edges.
# n=500, seed=5, best MIS size = 11
#
# ===== Running for n = 500, seed = 6 =====
# Graph has 500 nodes and 62272 edges.
# n=500, seed=6, best MIS size = 12
#
# ===== Running for n = 500, seed = 7 =====
# Graph has 500 nodes and 62560 edges.
# n=500, seed=7, best MIS size = 13
#
# ===== Running for n = 500, seed = 8 =====
# Graph has 500 nodes and 62663 edges.
# n=500, seed=8, best MIS size = 12
#
# ===== Running for n = 500, seed = 9 =====
# Graph has 500 nodes and 62571 edges.
# n=500, seed=9, best MIS size = 12
#
# ===== Running for n = 1000, seed = 0 =====
# Graph has 1000 nodes and 250082 edges.
# n=1000, seed=0, best MIS size = 13
#
# ===== Running for n = 1000, seed = 1 =====
# Graph has 1000 nodes and 249540 edges.
# n=1000, seed=1, best MIS size = 13
#
# ===== Running for n = 1000, seed = 2 =====
# Graph has 1000 nodes and 249678 edges.
# n=1000, seed=2, best MIS size = 13
#
# ===== Running for n = 1000, seed = 3 =====
# Graph has 1000 nodes and 249522 edges.
# n=1000, seed=3, best MIS size = 13
#
# ===== Running for n = 1000, seed = 4 =====
# Graph has 1000 nodes and 249994 edges.
# n=1000, seed=4, best MIS size = 13
#
# ===== Running for n = 1000, seed = 5 =====
# Graph has 1000 nodes and 250407 edges.
# n=1000, seed=5, best MIS size = 13
#
# ===== Running for n = 1000, seed = 6 =====
# Graph has 1000 nodes and 249328 edges.
# n=1000, seed=6, best MIS size = 13
#
# ===== Running for n = 1000, seed = 7 =====
# Graph has 1000 nodes and 250025 edges.
# n=1000, seed=7, best MIS size = 13
#
# ===== Running for n = 1000, seed = 8 =====
# Graph has 1000 nodes and 250282 edges.
# n=1000, seed=8, best MIS size = 13
#
# ===== Running for n = 1000, seed = 9 =====
# Graph has 1000 nodes and 249765 edges.
# n=1000, seed=9, best MIS size = 13

# %%
# without complement

import torch
import networkx as nx
import numpy as np
import time
import psutil, os


def build_upper_edge_list_from_graph(G: nx.Graph):
    """
    Store the edges of the undirected graph G as an edge list in upper triangular form (u < v).

    U, V: 1D torch.long tensors (length = number of edges |E|),
    representing the two endpoint indices (u, v) for each edge, where u < v.
    """
    edges = []
    for u, v in G.edges():
        if u == v: # Exclude self-loops
            continue
        if u > v:
            u, v = v, u
        edges.append((u, v))

    if not edges:
        # The case with no edges
        return torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long)

    U = torch.tensor([e[0] for e in edges], dtype=torch.long)
    V = torch.tensor([e[1] for e in edges], dtype=torch.long)
    return U, V


def sample_edge_sublist(U: torch.Tensor, V: torch.Tensor, p_keep: float):
    """
    Perform Bernoulli sampling for each "undirected edge" (u<v) to keep it with probability p_keep.
    Return the selected sub-edge list U_sub, V_sub (still in the u<v upper triangular form).
    """
    assert U.dtype == torch.long and V.dtype == torch.long
    assert U.shape == V.shape

    m = U.numel()
    mask = torch.rand(m) < p_keep
    idx = mask.nonzero(as_tuple=False).squeeze(1)

    if idx.numel() == 0:
        # When no edges are sampled, return an empty sublist.
        return torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long)

    return U.index_select(0, idx), V.index_select(0, idx)


def matrix_free_spmv(U_sub, V_sub, x, n, p_keep):
    """
    Matrix-Free Sparse Matrix-Vector Product
    y = (A_sub / p_keep) @ x
    """
    if U_sub.numel() == 0:
        return torch.zeros(n, dtype=x.dtype)

    y = torch.zeros(n, dtype=x.dtype)
    x_v = x.index_select(0, V_sub)
    x_u = x.index_select(0, U_sub)

    # y[u] += x[v] and y[v] += x[u]
    y.scatter_add_(0, U_sub, x_v)
    y.scatter_add_(0, V_sub, x_u)

    return y / p_keep

def partition_graph_edges(U: torch.Tensor, V: torch.Tensor, num_subgraphs: int):
    """
    Randomly shuffles the graph's edge list and partitions it into a specified number of subgraphs.

    Args:
        U (torch.Tensor): Tensor of source nodes for all edges.
        V (torch.Tensor): Tensor of destination nodes for all edges.
        num_subgraphs (int): The number of partitions to create.

    Returns:
        list: A list of tuples, where each tuple (U_sub, V_sub) represents an edge list
              of a subgraph partition.
    """
    num_edges = U.numel()
    # 处理没有边的情况
    if num_edges == 0:
        empty_subgraph = (torch.empty(0, dtype=torch.long), torch.empty(0, dtype=torch.long))
        return [empty_subgraph] * num_subgraphs

    # 创建一个随机的索引排列
    shuffled_indices = torch.randperm(num_edges)

    # 使用这个排列来打乱整个图的边列表
    U_shuffled = U[shuffled_indices]
    V_shuffled = V[shuffled_indices]

    # 将打乱后的边列表分割成 num_subgraphs个块
    U_chunks = torch.chunk(U_shuffled, num_subgraphs)
    V_chunks = torch.chunk(V_shuffled, num_subgraphs)

    # 将分块后的 (U, V) 对打包成列表并返回
    subgraph_partitions = list(zip(U_chunks, V_chunks))
    return subgraph_partitions


def check_maximal_independent_set(X_torch, n, edges_g_set):
    """
    Check whether a solution is a Maximal Independent Set based on an edge list (hash set).
    """
    # 1. Retrieve the candidate node set
    X_binarized = X_torch.bool()
    S_nodes_tensor = X_binarized.nonzero(as_tuple=False).squeeze(1)
    S_nodes_set = set(S_nodes_tensor.tolist())

    # 2. Check whether S is an independent set:
    # iterate through all node pairs in S, and if any pair is found in the edge hash set, then S is not an IS
    for u in S_nodes_tensor:
        for v in S_nodes_tensor:
            if u >= v: continue
            if (u.item(), v.item()) in edges_g_set:
                return False, None

    # 3. Check whether S is a maximal independent set:
    # iterate through all nodes w not in S, and check whether w can be added to S
    all_nodes = set(range(n))
    outside_nodes = all_nodes - S_nodes_set

    for w in outside_nodes:
        can_be_added = True
        for s_node in S_nodes_set:
            u, v = min(w, s_node), max(w, s_node)
            if (u, v) in edges_g_set:
                can_be_added = False
                break
        if can_be_added:
            # If there exists a node that can be added, then S is not maximal
            return False, None

    # If all checks are passed, then S is a Maximal Independent Set
    return True, S_nodes_tensor

#########################################################################
# Begin
#########################################################################
# node_list = [500, 1000, 2000, 3000, 5000]
# node_list = [3000]
node_list = [500, 1000]
p = 0.5

num_subgraphs = 5
# num_subgraphs = 10

# TIME_LIMIT = 20
TIME_LIMIT = 5

with open("sparse_partition_subgraph_without_complement.txt", "w") as f:
    for n in node_list:
        best_list = []
        conv_iters_all = []
        for seed in range(10):
            print(f"\n===== Running for n = {n}, seed = {seed} =====")
            f.write(f"Number of nodes n = {n}\n")
            f.write(f"Edge probability p = {p}\n")
            f.write(f"Graph Seed = {seed}\n")
            f.write("Results for each epoch:\n")

            G = nx.gnp_random_graph(n, p, seed=seed)

            # Completely remove all adjacency matrix constructions and use only edge lists.
            print(f"Graph has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
            U, V = build_upper_edge_list_from_graph(G)

            # Precompute a hash set of edges for efficient lookup in the MIS checker
            edges_g_set = set(zip(U.tolist(), V.tolist()))

            # Construct the edge list of the complement graph, then discard the complement graph object
            # complement_G = nx.complement(G)
            # U_comp, V_comp = build_upper_edge_list_from_graph(complement_G)
            # del complement_G  # Free up memory

            # --------------------------------------------------------------------------
            ### Here, we set gamma, gamma', and beta.
            gamma_c = 1.01

            # Compute the degree in the complement graph
            degrees_g = dict(G.degree())
            degrees_c = {node: (n - 1) - degree for node, degree in degrees_g.items()}
            max_degree = max(degrees_c.values()) if degrees_c else 0
            gamma = 2 + max_degree
            # --------------------------------------------------------------------------

            beta = 0.8
            alpha = 0.0001

            if (n == 3000 or n == 5000) and num_subgraphs == 10:
                alpha = 0.00001

            ITERATION_T = 150
            if n == 3000 or n == 5000:
                ITERATION_T = 300

            epoch = 50

            # Degree-based initialization
            degrees = dict(G.degree())
            max_degree_node = max(degrees.values()) if degrees else 1
            d = torch.zeros(n)
            for node, degree in G.degree():
                d[node] = 1 - (degree / max_degree_node)
            if max(d) > 0: d = d / max(d)

            input_velocity = torch.zeros(n)
            exploration_parameter_eta = 2.0
            covariance_matrix = exploration_parameter_eta * torch.eye(len(d))
            best_MIS_size = 0
            best_epoch = -1
            best_iter = -1
            conv_iters_seed = []

            # p_keep参数现在用于缩放梯度，其值等于子图中边的比例
            p_keep_for_scaling = 1.0 / num_subgraphs
            # ===============================================================
            # time limit
            start_time = time.time()

            init = -1

            while time.time() - start_time < TIME_LIMIT:
                init = init + 1
                if time.time() - start_time > TIME_LIMIT:
                    break

            # for init in range(epoch):
            #     elapsed_time = time.time() - start_time
            #     if elapsed_time > TIME_LIMIT:  # 超过时间限制就退出
            #         print(f"Time limit reached after {init} epochs (elapsed {elapsed_time:.2f}s)")
            #         break

                if init == 0:
                    input_tensor = d.clone()
                else:
                    torch.manual_seed(init + seed)  # Ensure that each random initialization is different
                    input_tensor = torch.normal(mean=d, std=torch.sqrt(torch.diag(covariance_matrix)))

                input_velocity = torch.zeros(n)
                converged = False
                conv_iter = None
                MIS_size = 0

                # To get the subgraph
                # -----------------------------------------------------------------------
                subgraph_partitions = partition_graph_edges(U, V, num_subgraphs)
                # -----------------------------------------------------------------------

                for iteration in range(ITERATION_T):

                    # 从预先生成的子图分区列表中循环选择当前迭代所用的子图
                    U_sub, V_sub = subgraph_partitions[iteration % num_subgraphs]

                    # Compute gradient components using a matrix-free method
                    ax = matrix_free_spmv(U_sub, V_sub, input_tensor, n, p_keep_for_scaling)
                    # acx = matrix_free_spmv(U_comp_sub, V_comp_sub, input_tensor, n, p_keep)

                    # Synthesize the final gradient
                    # gradient = -torch.ones(n) + (gamma * ax - gamma_c * acx)
                    gradient = -torch.ones(n) + gamma * ax
                    # ----------------------------------------

                    input_velocity = beta * input_velocity + alpha * gradient
                    input_tensor = torch.clamp(input_tensor - input_velocity, 0, 1)

                    # Call the new edge-list-based MIS checker
                    Checker, MIS = check_maximal_independent_set(input_tensor, n, edges_g_set)

                    if Checker:
                        MIS_size = MIS.numel()
                        conv_iter = iteration
                        converged = True
                        break


                if converged:
                    conv_iters_seed.append(conv_iter)
                    # f.write(
                    #     f"Epoch {init}, MIS size = {MIS_size}, converged at iteration = {conv_iter}\n"
                    # )
                    if MIS_size > best_MIS_size:
                        best_MIS_size = MIS_size
                        best_epoch = init
                        best_iter = conv_iter
                # else:
                #     f.write(f"Epoch {init}, No convergence (ran {ITERATION_T} iterations)\n")

            best_list.append(best_MIS_size)
            if conv_iters_seed:
                avg_conv_iter = np.mean(conv_iters_seed)
                conv_iters_all.extend(conv_iters_seed)
                f.write(f"\nAverage convergence iteration (this seed) = {avg_conv_iter:.2f}\n")
            else:
                f.write("\nNo epoch converged in this seed.\n")
            f.write(f"\nBest MIS size = {best_MIS_size}\n")
            f.write(f"\n=============================================\n")
            print(f"n={n}, seed={seed}, best MIS size = {best_MIS_size}")

        avg_best = np.mean(best_list) if best_list else 0
        if conv_iters_all:
            avg_conv_all = np.mean(conv_iters_all)
            f.write(
                f"\n=**********************************************************************************************************\n")
            f.write(f"Average Best MIS size over {len(best_list)} seeds = {avg_best:.2f}\n")
            f.write(f"Average convergence iteration over all converged epochs = {avg_conv_all:.2f}\n")
            f.write(
                f"=************************************************************************************************************\n\n")
        else:
            f.write("\nNo convergence across all seeds.\n")
# Out:
# ===== Running for n = 500, seed = 0 =====
# Graph has 500 nodes and 62475 edges.
# n=500, seed=0, best MIS size = 11
#
# ===== Running for n = 500, seed = 1 =====
# Graph has 500 nodes and 62440 edges.
# n=500, seed=1, best MIS size = 11
#
# ===== Running for n = 500, seed = 2 =====
# Graph has 500 nodes and 62205 edges.
# n=500, seed=2, best MIS size = 11
#
# ===== Running for n = 500, seed = 3 =====
# Graph has 500 nodes and 62556 edges.
# n=500, seed=3, best MIS size = 12
#
# ===== Running for n = 500, seed = 4 =====
# Graph has 500 nodes and 62558 edges.
# n=500, seed=4, best MIS size = 11
#
# ===== Running for n = 500, seed = 5 =====
# Graph has 500 nodes and 62598 edges.
# n=500, seed=5, best MIS size = 12
#
# ===== Running for n = 500, seed = 6 =====
# Graph has 500 nodes and 62272 edges.
# n=500, seed=6, best MIS size = 11
#
# ===== Running for n = 500, seed = 7 =====
# Graph has 500 nodes and 62560 edges.
# n=500, seed=7, best MIS size = 11
#
# ===== Running for n = 500, seed = 8 =====
# Graph has 500 nodes and 62663 edges.
# n=500, seed=8, best MIS size = 12
#
# ===== Running for n = 500, seed = 9 =====
# Graph has 500 nodes and 62571 edges.
# n=500, seed=9, best MIS size = 11
#
# ===== Running for n = 1000, seed = 0 =====
# Graph has 1000 nodes and 250082 edges.
# n=1000, seed=0, best MIS size = 12
#
# ===== Running for n = 1000, seed = 1 =====
# Graph has 1000 nodes and 249540 edges.
# n=1000, seed=1, best MIS size = 12
#
# ===== Running for n = 1000, seed = 2 =====
# Graph has 1000 nodes and 249678 edges.
# n=1000, seed=2, best MIS size = 12
#
# ===== Running for n = 1000, seed = 3 =====
# Graph has 1000 nodes and 249522 edges.
# n=1000, seed=3, best MIS size = 13
#
# ===== Running for n = 1000, seed = 4 =====
# Graph has 1000 nodes and 249994 edges.
# n=1000, seed=4, best MIS size = 13
#
# ===== Running for n = 1000, seed = 5 =====
# Graph has 1000 nodes and 250407 edges.
# n=1000, seed=5, best MIS size = 13
#
# ===== Running for n = 1000, seed = 6 =====
# Graph has 1000 nodes and 249328 edges.
# n=1000, seed=6, best MIS size = 13
#
# ===== Running for n = 1000, seed = 7 =====
# Graph has 1000 nodes and 250025 edges.
# n=1000, seed=7, best MIS size = 13
#
# ===== Running for n = 1000, seed = 8 =====
# Graph has 1000 nodes and 250282 edges.
# n=1000, seed=8, best MIS size = 13
#
# ===== Running for n = 1000, seed = 9 =====
# Graph has 1000 nodes and 249765 edges.
# n=1000, seed=9, best MIS size = 12
